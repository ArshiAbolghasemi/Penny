# %% [markdown]
# # Model comparison — trend classification across horizons
#
# Compares the trend classifiers on the **OFI** feature stream over the label
# horizons **k ∈ {10, 20, 50, 100}**:
#
# | tag | class | family |
# |-----|-------|--------|
# | `dla + ofi`            | `DLA`            | attention encoder–decoder |
# | `tlob + ofi`           | `TLOB`           | temporal/spatial transformer |
# | `binctabl + ofi`       | `BINCTABL`       | bilinear + BiN |
# | `ctabl + ofi`          | `CTABL`          | bilinear temporal attention |
# | `deeplob + ofi`        | `DeepLOB`        | CNN + inception + LSTM |
# | `jumpgatelob + ofi`    | `JumpGateLOB`    | jump-diffusion score matching + noise-consistent classifier |
# | `alphastablelob + ofi` | `AlphaStableLOB` | α-stable joint diffusion-classifier |
#
# Every model exposes `predict(batch, device) → (B, 3) logits`, so the metrics
# (accuracy, macro-F1, per-class F1, confusion) are computed identically.
#
# **Sections**
# 1. Setup & checkpoint registry (auto-discovered, editable)
# 2. Load models + build the shared per-horizon test set (incl. per-window realized trend)
# 3. Overall metrics (accuracy / macro-F1 / per-class F1) across horizons
# 4. Confusion matrices
# 5. Metric-vs-horizon curves
# 6. Extreme conditions (jumps) — performance on turbulent windows
# 7. Financial / trading metrics — MCC/κ, signal quality, mid-price prediction
#    overlay, calibration & confidence gating
# 8. Final model comparison table
#
# > Run from the **Penny repo root** so the `data/` cache and `checkpoints/`
# > relative paths resolve.

# %% [markdown]
# ## 1. Setup

# %%
import os
import sys
import json
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import torch.nn.functional as Fn
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.metrics import (
    cohen_kappa_score,
    confusion_matrix,
    f1_score,
    matthews_corrcoef,
    recall_score,
)
from torch.utils.data import DataLoader

warnings.filterwarnings("ignore")
pd.set_option("display.float_format", lambda v: f"{v:.4f}")


# --- locate the repo root and chdir into it -----------------------------------
# Jupyter kernels default their cwd to wherever the server was launched (often
# the notebook's own directory, e.g. `notebooks/`), NOT the repo root. Config
# files store paths like "data/resampled/nobitex" that `build_cache` resolves
# against the *live process cwd* — so if we only add `src/` to sys.path without
# also chdir'ing, imports succeed but data loading fails with a confusing
# "parquet not found" error. Walk up from cwd to find `pyproject.toml` and
# chdir there so every relative path in every config resolves the same way
# regardless of how this notebook was launched.
def _find_repo_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "pyproject.toml").exists() and (p / "src").is_dir():
            return p
    raise RuntimeError(
        f"could not find the Penny repo root (pyproject.toml + src/) above {start}"
    )


REPO = _find_repo_root(Path.cwd())
os.chdir(REPO)
sys.path.insert(0, str(REPO / "src"))
print("repo root:", REPO)

from crypto.dataset import build_datasets  # noqa: E402
from crypto.features import extract_features, n_features  # noqa: E402
from crypto.labels import compute_trend_series  # noqa: E402
from crypto.loader import build_cache  # noqa: E402
from models.alphastablelob import AlphaStableLOB  # noqa: E402
from models.ctabl import CTABL  # noqa: E402
from models.binctabl import BINCTABL  # noqa: E402
from models.deeplob import DeepLOB  # noqa: E402
from models.dla import DLA  # noqa: E402
from models.jumpgatelob import JumpGateLOB  # noqa: E402
from models.tlob import TLOB  # noqa: E402
from models.linvar import LinVAR  # noqa: E402
from models.logreg import LogReg  # noqa: E402
from models.ofsatnet import OFSATNet  # noqa: E402

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", DEVICE)
# Out:
# repo root: /Users/arshia/Projects/Personal/Penny
# device: cpu

# %% [markdown]
# ## 2. Registry & checkpoints
#
# `MODELS` maps each tag to its class. `HORIZONS` are the label-`k` values.
#
# `CHECKPOINTS[model][k]` is a path to a checkpoint **directory** (containing
# `best.pt`) or the `best.pt` file itself. It is auto-populated by scanning
# `CHECKPOINT_ROOT` and reading each run's sibling `config.json` for
# `(feature_mode, label_k, symbol)` — the newest run wins. **Edit the printed dict
# to point at the exact checkpoints you want.**

# %%
FEATURE_MODE = "ofi"
SYMBOL = "BTCIRT"
HORIZONS = [10, 20, 50, 100]
BATCH = 256

# tag -> (class, checkpoint-dir prefix written by the train scripts)
MODELS = {
    "dla": (DLA, "dla_"),
    # "axial": (AxialLOB, "axiallob_"),
    "tlob": (TLOB, "tlob_"),
    "ctabl": (CTABL, "ctabl_"),
    "binctabl": (BINCTABL, "binctabl_"),
    "deeplob": (DeepLOB, "deeplob_"),
    "alphastablelob_1.5": (AlphaStableLOB, "alphastablelob_joint_a1.5_"),
    # "alphastablelob_1.7": (AlphaStableLOB, "alphastablelob_joint_a17"),
    "linvar": (LinVAR, "linvar_"),
    "logreg": (LogReg, "logreg_"),
    "jumpgatelob": (JumpGateLOB, "jumpgatelob_"),
    "ofsatnet": (OFSATNet, "ofsatnet_"),
}
LABELS = ["down", "stationary", "up"]
DISPLAY = {m: f"{m} + {FEATURE_MODE}" for m in MODELS}

# where to scan for runs (change if your checkpoints live elsewhere)
CHECKPOINT_ROOT = REPO / "checkpoints" / "nobitex" / SYMBOL

# JSON config used only to BUILD the shared test set for each horizon.
# Any model's ofi config for that k works (identical data params); jumpgatelob
# ships one per horizon.
DATA_CONFIG = "configs/crypto/nobitex/jumpgatelob/btcirt_{fm}_k{k}.json"


def _run_config(run_dir: Path) -> dict | None:
    """Read a run's sidecar config.json (falls back to best.pt if absent)."""
    cj = run_dir / "config.json"
    if cj.exists():
        try:
            return json.loads(cj.read_text())
        except Exception:
            pass
    bp = run_dir / "best.pt"
    if bp.exists():
        try:
            return torch.load(bp, map_location="cpu", weights_only=False)["config"]
        except Exception:
            pass
    return None


def discover_checkpoints() -> dict:
    """tag -> {k -> newest matching run dir}, matched on prefix + config."""
    found = {m: {} for m in MODELS}
    if not CHECKPOINT_ROOT.exists():
        print(f"! CHECKPOINT_ROOT does not exist: {CHECKPOINT_ROOT}")
        return found
    for run in sorted(CHECKPOINT_ROOT.iterdir()):  # lexical == chronological
        if not run.is_dir():
            continue
        for tag, (_cls, prefix) in MODELS.items():
            if not run.name.startswith(prefix):
                continue
            cfg = _run_config(run)
            if cfg is None:
                continue
            k = cfg.get("label_k")
            if (
                cfg.get("feature_mode") == FEATURE_MODE
                and cfg.get("symbol") == SYMBOL
                and k in HORIZONS
            ):
                found[tag][k] = str(run)  # newest overwrites
    return found


CHECKPOINTS = discover_checkpoints()
print("Auto-discovered checkpoints (edit below if needed):\n")
for m in MODELS:
    row = ", ".join(f"k{k}:{'✓' if k in CHECKPOINTS[m] else '—'}" for k in HORIZONS)
    print(f"  {DISPLAY[m]:<24} {row}")
CHECKPOINTS
# Out:
# Auto-discovered checkpoints (edit below if needed):
#
#   dla + ofi                k10:✓, k20:✓, k50:✓, k100:✓
#   tlob + ofi               k10:✓, k20:✓, k50:✓, k100:✓
#   ctabl + ofi              k10:✓, k20:✓, k50:✓, k100:✓
#   binctabl + ofi           k10:✓, k20:✓, k50:✓, k100:✓
#   deeplob + ofi            k10:✓, k20:✓, k50:✓, k100:✓
#   alphastablelob_1.5 + ofi k10:✓, k20:✓, k50:✓, k100:✓
#   linvar + ofi             k10:✓, k20:✓, k50:✓, k100:✓
#   logreg + ofi             k10:✓, k20:✓, k50:✓, k100:✓
#   jumpgatelob + ofi        k10:✓, k20:✓, k50:✓, k100:✓
#   ofsatnet + ofi           k10:✓, k20:✓, k50:✓, k100:✓
# {'dla': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/dla_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/dla_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/dla_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/dla_BTCIRT_ofi_k50'},
#  'tlob': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/tlob_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/tlob_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/tlob_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/tlob_BTCIRT_ofi_k50'},
#  'ctabl': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/ctabl_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/ctabl_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/ctabl_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/ctabl_BTCIRT_ofi_k50'},
#  'binctabl': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/binctabl_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/binctabl_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/binctabl_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/binctabl_BTCIRT_ofi_k50'},
#  'deeplob': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/deeplob_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/deeplob_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/deeplob_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/deeplob_BTCIRT_ofi_k50'},
#  'alphastablelob_1.5': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/alphastablelob_joint_a1.5_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/alphastablelob_joint_a1.5_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/alphastablelob_joint_a1.5_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/alphastablelob_joint_a1.5_BTCIRT_ofi_k50'},
#  'linvar': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/linvar_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/linvar_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/linvar_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/linvar_BTCIRT_ofi_k50'},
#  'logreg': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/logreg_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/logreg_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/logreg_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/logreg_BTCIRT_ofi_k50'},
#  'jumpgatelob': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/jumpgatelob_levy_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/jumpgatelob_levy_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/jumpgatelob_levy_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/jumpgatelob_levy_BTCIRT_ofi_k50'},
#  'ofsatnet': {10: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/ofsatnet_BTCIRT_ofi_k10',
#   100: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/ofsatnet_BTCIRT_ofi_k100',
#   20: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/ofsatnet_BTCIRT_ofi_k20',
#   50: '/Users/arshia/Projects/Personal/Penny/checkpoints/nobitex/BTCIRT/ofsatnet_BTCIRT_ofi_k50'}}

# %% [markdown]
# ## 3. Load models & evaluate
#
# The test set is built **once per horizon** and shared across all models, so
# every model is scored on the identical windows and labels. For each window we
# also record a **stress score** — the repo's own market-jump measure
# (`_data_jump_flag`): the largest 1-step increment of the level-averaged feature,
# in realized-volatility units. Higher ⇒ more turbulent input.

# %%
def load_ckpt(path: str):
    p = Path(path)
    if p.is_dir():
        p = p / "best.pt"
    return torch.load(p, map_location=DEVICE, weights_only=False)


def build_model(tag: str, ckpt: dict):
    cls, _ = MODELS[tag]
    model = cls(ckpt["config"]).to(DEVICE)
    model.load_state_dict(ckpt["model"])
    model.eval()
    return model


_DS_CACHE: dict[int, tuple] = {}
# META[k] = {"mid", "ts", "centres", "trend", "alpha"} — per-window financial
# ground truth: `centres` indexes each test window's label bin into the full
# `mid`/`ts` series; `trend` is the realized smoothed trend_ratio at that bin
# (the exact quantity the ±alpha label thresholds), used by section 7.
META: dict[int, dict] = {}


def test_set(k: int):
    """(test_ds, y_true, stress) for horizon k — built once, then cached."""
    if k in _DS_CACHE:
        return _DS_CACHE[k]
    cfg_path = REPO / DATA_CONFIG.format(fm=FEATURE_MODE, k=k)
    cfg = json.loads(cfg_path.read_text())
    _, _, test_ds, alpha, meta = build_datasets(cfg)
    loader = DataLoader(test_ds, batch_size=BATCH, shuffle=False)
    ys, ss = [], []
    for b in loader:
        x = b["x"].float()  # (B, 1, T, F)
        agg = x.squeeze(1).mean(-1)  # (B, T) level-averaged stream
        dif = agg[:, 1:] - agg[:, :-1]
        rv = dif.std(dim=1).clamp_min(1e-8)
        ss.append((dif.abs().max(dim=1).values / rv).numpy())
        ys.append(b["label"].numpy())
    y_true = np.concatenate(ys)
    stress = np.concatenate(ss)

    # financial ground truth: mid series + realized trend at each window centre
    feat, mid, ts = build_cache(cfg, extract_features, n_features, tag="lob")
    centres = np.asarray(test_ds.starts) + cfg["T_past"] - 1
    trend = compute_trend_series(mid, k)[centres]
    lab_chk = np.where(trend > alpha, 2, np.where(trend < -alpha, 0, 1))
    mism = float((lab_chk != y_true).mean())
    if mism > 1e-3:
        print(f"  ! label/trend mismatch {mism:.2%} — check alpha/config alignment")
    META[k] = {"mid": mid, "ts": ts, "centres": centres, "trend": trend, "alpha": alpha}

    print(
        f"  k={k:<3} test windows={len(y_true):>6}  "
        f"class balance {np.bincount(y_true, minlength=3) / len(y_true)}  "
        f"mean |trend|={np.abs(trend).mean() * 1e4:.2f} bp"
    )
    _DS_CACHE[k] = (test_ds, y_true, stress)
    return _DS_CACHE[k]


@torch.no_grad()
def evaluate(model, test_ds):
    loader = DataLoader(test_ds, batch_size=BATCH, shuffle=False)
    yt, yp, pr = [], [], []
    for b in loader:
        logits = model.predict(b, DEVICE)
        pr.append(Fn.softmax(logits, dim=1).cpu().numpy())
        yp.append(logits.argmax(dim=1).cpu().numpy())
        yt.append(b["label"].numpy())
    return np.concatenate(yt), np.concatenate(yp), np.concatenate(pr)

# %%
# RESULTS[(tag, k)] = {"y_true", "y_pred", "probs", "stress"}
RESULTS: dict = {}

for k in HORIZONS:
    print(f"horizon k={k}")
    try:
        test_ds, y_true, stress = test_set(k)
    except FileNotFoundError as e:
        print(f"  ! could not build test set for k={k}: {e}")
        print(
            f"    (cwd is {Path.cwd()} — if this looks wrong, re-run the setup "
            f"cell; if the file is genuinely missing, run `uv run dvc pull`)"
        )
        continue
    except Exception as e:
        print(f"  ! could not build test set for k={k}: {e}")
        continue
    for tag in MODELS:
        path = CHECKPOINTS.get(tag, {}).get(k)
        if not path or not Path(path).exists():
            print(f"  {DISPLAY[tag]:<24} — no checkpoint, skipped")
            continue
        ckpt = load_ckpt(path)
        cfg = ckpt["config"]
        if cfg.get("label_k") != k or cfg.get("feature_mode") != FEATURE_MODE:
            print(
                f"  {DISPLAY[tag]:<24} ! config mismatch "
                f"(k={cfg.get('label_k')}, fm={cfg.get('feature_mode')}), skipped"
            )
            continue
        model = build_model(tag, ckpt)
        yt, yp, pr = evaluate(model, test_ds)
        assert np.array_equal(yt, y_true), "window/label misalignment"
        RESULTS[(tag, k)] = {"y_true": yt, "y_pred": yp, "probs": pr, "stress": stress}
        acc = (yt == yp).mean()
        f1 = f1_score(yt, yp, average="macro", labels=[0, 1, 2], zero_division=0)
        print(f"  {DISPLAY[tag]:<24} acc={acc:.4f}  macro_f1={f1:.4f}")
        del model
        if DEVICE.type == "cuda":
            torch.cuda.empty_cache()

print(f"\nevaluated {len(RESULTS)} (model, horizon) pairs")
# Out:
# 2026-07-27 23:07:12.803 | INFO     | crypto.loader:build_cache:115 - loaded cache 'lob': 213,335 rows, 31 features
# horizon k=10
# 2026-07-27 23:07:14.376 | INFO     | crypto.dataset:build_datasets:86 - windows — train:147218 val:31831 test:31932
# 2026-07-27 23:07:14.569 | INFO     | crypto.loader:build_cache:115 - loaded cache 'lob': 213,335 rows, 31 features
#   k=10  test windows= 31932  class balance [0.30959539 0.40035075 0.29005386]  mean |trend|=2.87 bp
#   dla + ofi                acc=0.6987  macro_f1=0.6954
#   tlob + ofi               acc=0.6830  macro_f1=0.6801
#   ctabl + ofi              acc=0.6905  macro_f1=0.6886
#   binctabl + ofi           acc=0.6683  macro_f1=0.6662
#   deeplob + ofi            acc=0.6368  macro_f1=0.6311
#   alphastablelob_1.5 + ofi acc=0.6909  macro_f1=0.6873
#   linvar + ofi             acc=0.6732  macro_f1=0.6708
#   logreg + ofi             acc=0.6613  macro_f1=0.6596
#   jumpgatelob + ofi        acc=0.6811  macro_f1=0.6780
# 2026-07-27 23:08:39.368 | INFO     | crypto.loader:build_cache:115 - loaded cache 'lob': 213,335 rows, 31 features
#   ofsatnet + ofi           acc=0.6851  macro_f1=0.6830
# horizon k=20
# 2026-07-27 23:08:40.893 | INFO     | crypto.dataset:build_datasets:86 - windows — train:147208 val:31821 test:31922
# 2026-07-27 23:08:41.100 | INFO     | crypto.loader:build_cache:115 - loaded cache 'lob': 213,335 rows, 31 features
#   k=20  test windows= 31922  class balance [0.30574525 0.41118978 0.28306497]  mean |trend|=4.11 bp
#   dla + ofi                acc=0.6372  macro_f1=0.6386
#   tlob + ofi               acc=0.6077  macro_f1=0.6098
#   ctabl + ofi              acc=0.6232  macro_f1=0.6255
#   binctabl + ofi           acc=0.6057  macro_f1=0.6074
#   deeplob + ofi            acc=0.5583  macro_f1=0.5583
#   alphastablelob_1.5 + ofi acc=0.6136  macro_f1=0.6158
#   linvar + ofi             acc=0.6197  macro_f1=0.6223
#   logreg + ofi             acc=0.6084  macro_f1=0.6111
#   jumpgatelob + ofi        acc=0.6280  macro_f1=0.6277
# 2026-07-27 23:10:05.975 | INFO     | crypto.loader:build_cache:115 - loaded cache 'lob': 213,335 rows, 31 features
#   ofsatnet + ofi           acc=0.6107  macro_f1=0.6135
# horizon k=50
# 2026-07-27 23:10:07.583 | INFO     | crypto.dataset:build_datasets:86 - windows — train:147178 val:31791 test:31892
# 2026-07-27 23:10:07.792 | INFO     | crypto.loader:build_cache:115 - loaded cache 'lob': 213,335 rows, 31 features
#   k=50  test windows= 31892  class balance [0.29392951 0.43575191 0.27031858]  mean |trend|=6.42 bp
#   dla + ofi                acc=0.6108  macro_f1=0.6148
#   tlob + ofi               acc=0.5715  macro_f1=0.5748
#   ctabl + ofi              acc=0.5848  macro_f1=0.5895
#   binctabl + ofi           acc=0.5744  macro_f1=0.5776
#   deeplob + ofi            acc=0.4901  macro_f1=0.4850
#   alphastablelob_1.5 + ofi acc=0.5835  macro_f1=0.5889
#   linvar + ofi             acc=0.5943  macro_f1=0.5993
#   logreg + ofi             acc=0.5843  macro_f1=0.5895
#   jumpgatelob + ofi        acc=0.5789  macro_f1=0.5841
# 2026-07-27 23:11:31.700 | INFO     | crypto.loader:build_cache:115 - loaded cache 'lob': 213,335 rows, 31 features
#   ofsatnet + ofi           acc=0.6031  macro_f1=0.6015
# horizon k=100
# 2026-07-27 23:11:33.200 | INFO     | crypto.dataset:build_datasets:86 - windows — train:147087 val:31741 test:31842
# 2026-07-27 23:11:33.412 | INFO     | crypto.loader:build_cache:115 - loaded cache 'lob': 213,335 rows, 31 features
#   k=100 test windows= 31842  class balance [0.29008856 0.44048741 0.26942403]  mean |trend|=8.92 bp
#   dla + ofi                acc=0.5658  macro_f1=0.5707
#   tlob + ofi               acc=0.5608  macro_f1=0.5629
#   ctabl + ofi              acc=0.5652  macro_f1=0.5694
#   binctabl + ofi           acc=0.5546  macro_f1=0.5581
#   deeplob + ofi            acc=0.5217  macro_f1=0.5235
#   alphastablelob_1.5 + ofi acc=0.5709  macro_f1=0.5765
#   linvar + ofi             acc=0.5659  macro_f1=0.5718
#   logreg + ofi             acc=0.5523  macro_f1=0.5568
#   jumpgatelob + ofi        acc=0.5425  macro_f1=0.5453
#   ofsatnet + ofi           acc=0.5382  macro_f1=0.5395
#
# evaluated 40 (model, horizon) pairs

# %% [markdown]
# ## 4. Overall metrics

# %%
def metrics_row(yt, yp):
    per_f1 = f1_score(yt, yp, average=None, labels=[0, 1, 2], zero_division=0)
    return {
        "accuracy": (yt == yp).mean(),
        "macro_f1": f1_score(
            yt, yp, average="macro", labels=[0, 1, 2], zero_division=0
        ),
        "f1_down": per_f1[0],
        "f1_stat": per_f1[1],
        "f1_up": per_f1[2],
    }


rows = []
for (tag, k), r in RESULTS.items():
    rows.append(
        {"model": DISPLAY[tag], "k": k, **metrics_row(r["y_true"], r["y_pred"])}
    )

metrics_df = pd.DataFrame(rows).sort_values(["k", "model"]).reset_index(drop=True)
metrics_df
# Out:
#                        model    k  accuracy  macro_f1  f1_down  f1_stat  f1_up
# 0   alphastablelob_1.5 + ofi   10    0.6909    0.6873   0.6705   0.7115 0.6800
# 1             binctabl + ofi   10    0.6683    0.6662   0.6533   0.6824 0.6628
# 2                ctabl + ofi   10    0.6905    0.6886   0.6804   0.7034 0.6820
# 3              deeplob + ofi   10    0.6368    0.6311   0.5990   0.6808 0.6136
# 4                  dla + ofi   10    0.6987    0.6954   0.6800   0.7176 0.6886
# 5          jumpgatelob + ofi   10    0.6811    0.6780   0.6579   0.7019 0.6741
# 6               linvar + ofi   10    0.6732    0.6708   0.6556   0.6881 0.6687
# 7               logreg + ofi   10    0.6613    0.6596   0.6472   0.6727 0.6590
# 8             ofsatnet + ofi   10    0.6851    0.6830   0.6657   0.7005 0.6828
# 9                 tlob + ofi   10    0.6830    0.6801   0.6661   0.7021 0.6721
# 10  alphastablelob_1.5 + ofi   20    0.6136    0.6158   0.6300   0.5881 0.6293
# 11            binctabl + ofi   20    0.6057    0.6074   0.6120   0.5891 0.6211
# 12               ctabl + ofi   20    0.6232    0.6255   0.6391   0.6017 0.6357
# 13             deeplob + ofi   20    0.5583    0.5583   0.5489   0.5582 0.5676
# 14                 dla + ofi   20    0.6372    0.6386   0.6419   0.6271 0.6466
# 15         jumpgatelob + ofi   20    0.6280    0.6277   0.6195   0.6312 0.6324
# 16              linvar + ofi   20    0.6197    0.6223   0.6307   0.5985 0.6378
# 17              logreg + ofi   20    0.6084    0.6111   0.6242   0.5787 0.6306
# 18            ofsatnet + ofi   20    0.6107    0.6135   0.6311   0.5687 0.6406
# 19                tlob + ofi   20    0.6077    0.6098   0.6130   0.5903 0.6262
# 20  alphastablelob_1.5 + ofi   50    0.5835    0.5889   0.6049   0.5389 0.6227
# 21            binctabl + ofi   50    0.5744    0.5776   0.5902   0.5429 0.5998
# 22               ctabl + ofi   50    0.5848    0.5895   0.6286   0.5193 0.6204
# 23             deeplob + ofi   50    0.4901    0.4850   0.5635   0.3338 0.5577
# 24                 dla + ofi   50    0.6108    0.6148   0.6282   0.5810 0.6351
# 25         jumpgatelob + ofi   50    0.5789    0.5841   0.6160   0.5257 0.6106
# 26              linvar + ofi   50    0.5943    0.5993   0.6209   0.5438 0.6331
# 27              logreg + ofi   50    0.5843    0.5895   0.6289   0.5152 0.6243
# 28            ofsatnet + ofi   50    0.6031    0.6015   0.5806   0.6085 0.6154
# 29                tlob + ofi   50    0.5715    0.5748   0.6129   0.4997 0.6119
# 30  alphastablelob_1.5 + ofi  100    0.5709    0.5765   0.6115   0.5268 0.5911
# 31            binctabl + ofi  100    0.5546    0.5581   0.6064   0.5053 0.5626
# 32               ctabl + ofi  100    0.5652    0.5694   0.6326   0.4793 0.5962
# 33             deeplob + ofi  100    0.5217    0.5235   0.5113   0.4945 0.5647
# 34                 dla + ofi  100    0.5658    0.5707   0.6096   0.4979 0.6047
# 35         jumpgatelob + ofi  100    0.5425    0.5453   0.6196   0.4327 0.5837
# 36              linvar + ofi  100    0.5659    0.5718   0.6145   0.4941 0.6068
# 37              logreg + ofi  100    0.5523    0.5568   0.6162   0.4616 0.5924
# 38            ofsatnet + ofi  100    0.5382    0.5395   0.6218   0.4198 0.5770
# 39                tlob + ofi  100    0.5608    0.5629   0.6092   0.5035 0.5759

# %%
# accuracy & macro-F1 pivots (rows = model, cols = horizon)
if not metrics_df.empty:
    order = [DISPLAY[m] for m in MODELS if DISPLAY[m] in set(metrics_df["model"])]
    for metric in ["accuracy", "macro_f1"]:
        piv = metrics_df.pivot(index="model", columns="k", values=metric).reindex(order)
        print(f"\n=== {metric} (rows=model, cols=horizon k) ===")
        display(piv.style.background_gradient(cmap="YlGn", axis=None).format("{:.4f}"))
# Out:
# === accuracy (rows=model, cols=horizon k) ===
# <style type="text/css">
# #T_f4ba3_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_f4ba3_row0_col1, #T_f4ba3_row4_col0 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_f4ba3_row0_col2, #T_f4ba3_row9_col1 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_f4ba3_row0_col3, #T_f4ba3_row2_col3 {
#   background-color: #b2df90;
#   color: #000000;
# }
# #T_f4ba3_row1_col0 {
#   background-color: #005a31;
#   color: #f1f1f1;
# }
# #T_f4ba3_row1_col1 {
#   background-color: #5cb86b;
#   color: #f1f1f1;
# }
# #T_f4ba3_row1_col2, #T_f4ba3_row5_col3 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_f4ba3_row1_col3 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_f4ba3_row2_col0 {
#   background-color: #00502d;
#   color: #f1f1f1;
# }
# #T_f4ba3_row2_col1 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_f4ba3_row2_col2 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_f4ba3_row3_col0 {
#   background-color: #066d39;
#   color: #f1f1f1;
# }
# #T_f4ba3_row3_col1 {
#   background-color: #61bb6d;
#   color: #f1f1f1;
# }
# #T_f4ba3_row3_col2 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_f4ba3_row3_col3 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_f4ba3_row4_col1 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_f4ba3_row4_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f4ba3_row4_col3 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_f4ba3_row5_col0 {
#   background-color: #004f2d;
#   color: #f1f1f1;
# }
# #T_f4ba3_row5_col1 {
#   background-color: #4fb264;
#   color: #f1f1f1;
# }
# #T_f4ba3_row5_col2 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_f4ba3_row6_col0 {
#   background-color: #006737;
#   color: #f1f1f1;
# }
# #T_f4ba3_row6_col1 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_f4ba3_row6_col2 {
#   background-color: #79c679;
#   color: #000000;
# }
# #T_f4ba3_row6_col3 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_f4ba3_row7_col0 {
#   background-color: #0e743c;
#   color: #f1f1f1;
# }
# #T_f4ba3_row7_col1 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
# }
# #T_f4ba3_row7_col2 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_f4ba3_row7_col3 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_f4ba3_row8_col0 {
#   background-color: #005c32;
#   color: #f1f1f1;
# }
# #T_f4ba3_row8_col1 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_f4ba3_row8_col2 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_f4ba3_row8_col3 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_f4ba3_row9_col0 {
#   background-color: #005730;
#   color: #f1f1f1;
# }
# #T_f4ba3_row9_col2 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_f4ba3_row9_col3 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# </style>
# <table id="T_f4ba3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_f4ba3_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_f4ba3_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_f4ba3_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_f4ba3_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4ba3_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_f4ba3_row0_col0" class="data row0 col0" >0.6987</td>
#       <td id="T_f4ba3_row0_col1" class="data row0 col1" >0.6372</td>
#       <td id="T_f4ba3_row0_col2" class="data row0 col2" >0.6108</td>
#       <td id="T_f4ba3_row0_col3" class="data row0 col3" >0.5658</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_f4ba3_row1_col0" class="data row1 col0" >0.6830</td>
#       <td id="T_f4ba3_row1_col1" class="data row1 col1" >0.6077</td>
#       <td id="T_f4ba3_row1_col2" class="data row1 col2" >0.5715</td>
#       <td id="T_f4ba3_row1_col3" class="data row1 col3" >0.5608</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_f4ba3_row2_col0" class="data row2 col0" >0.6905</td>
#       <td id="T_f4ba3_row2_col1" class="data row2 col1" >0.6232</td>
#       <td id="T_f4ba3_row2_col2" class="data row2 col2" >0.5848</td>
#       <td id="T_f4ba3_row2_col3" class="data row2 col3" >0.5652</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_f4ba3_row3_col0" class="data row3 col0" >0.6683</td>
#       <td id="T_f4ba3_row3_col1" class="data row3 col1" >0.6057</td>
#       <td id="T_f4ba3_row3_col2" class="data row3 col2" >0.5744</td>
#       <td id="T_f4ba3_row3_col3" class="data row3 col3" >0.5546</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_f4ba3_row4_col0" class="data row4 col0" >0.6368</td>
#       <td id="T_f4ba3_row4_col1" class="data row4 col1" >0.5583</td>
#       <td id="T_f4ba3_row4_col2" class="data row4 col2" >0.4901</td>
#       <td id="T_f4ba3_row4_col3" class="data row4 col3" >0.5217</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_f4ba3_row5_col0" class="data row5 col0" >0.6909</td>
#       <td id="T_f4ba3_row5_col1" class="data row5 col1" >0.6136</td>
#       <td id="T_f4ba3_row5_col2" class="data row5 col2" >0.5835</td>
#       <td id="T_f4ba3_row5_col3" class="data row5 col3" >0.5709</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_f4ba3_row6_col0" class="data row6 col0" >0.6732</td>
#       <td id="T_f4ba3_row6_col1" class="data row6 col1" >0.6197</td>
#       <td id="T_f4ba3_row6_col2" class="data row6 col2" >0.5943</td>
#       <td id="T_f4ba3_row6_col3" class="data row6 col3" >0.5659</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_f4ba3_row7_col0" class="data row7 col0" >0.6613</td>
#       <td id="T_f4ba3_row7_col1" class="data row7 col1" >0.6084</td>
#       <td id="T_f4ba3_row7_col2" class="data row7 col2" >0.5843</td>
#       <td id="T_f4ba3_row7_col3" class="data row7 col3" >0.5523</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_f4ba3_row8_col0" class="data row8 col0" >0.6811</td>
#       <td id="T_f4ba3_row8_col1" class="data row8 col1" >0.6280</td>
#       <td id="T_f4ba3_row8_col2" class="data row8 col2" >0.5789</td>
#       <td id="T_f4ba3_row8_col3" class="data row8 col3" >0.5425</td>
#     </tr>
#     <tr>
#       <th id="T_f4ba3_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_f4ba3_row9_col0" class="data row9 col0" >0.6851</td>
#       <td id="T_f4ba3_row9_col1" class="data row9 col1" >0.6107</td>
#       <td id="T_f4ba3_row9_col2" class="data row9 col2" >0.6031</td>
#       <td id="T_f4ba3_row9_col3" class="data row9 col3" >0.5382</td>
#     </tr>
#   </tbody>
# </table>
# === macro_f1 (rows=model, cols=horizon k) ===
# <style type="text/css">
# #T_23493_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_23493_row0_col1 {
#   background-color: #288a47;
#   color: #f1f1f1;
# }
# #T_23493_row0_col2 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_23493_row0_col3 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_23493_row1_col0 {
#   background-color: #005931;
#   color: #f1f1f1;
# }
# #T_23493_row1_col1 {
#   background-color: #4fb264;
#   color: #f1f1f1;
# }
# #T_23493_row1_col2 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_23493_row1_col3 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_23493_row2_col0 {
#   background-color: #004e2d;
#   color: #f1f1f1;
# }
# #T_23493_row2_col1 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_23493_row2_col2, #T_23493_row7_col2 {
#   background-color: #79c679;
#   color: #000000;
# }
# #T_23493_row2_col3 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_23493_row3_col0 {
#   background-color: #036b38;
#   color: #f1f1f1;
# }
# #T_23493_row3_col1 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_23493_row3_col2 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_23493_row3_col3 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_23493_row4_col0 {
#   background-color: #30954f;
#   color: #f1f1f1;
# }
# #T_23493_row4_col1 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_23493_row4_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_23493_row4_col3 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_23493_row5_col0 {
#   background-color: #004f2d;
#   color: #f1f1f1;
# }
# #T_23493_row5_col1 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_23493_row5_col2 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_23493_row5_col3 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_23493_row6_col0 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_23493_row6_col1 {
#   background-color: #3aa257;
#   color: #f1f1f1;
# }
# #T_23493_row6_col2 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_23493_row6_col3 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_23493_row7_col0 {
#   background-color: #0c723b;
#   color: #f1f1f1;
# }
# #T_23493_row7_col1 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_23493_row7_col3 {
#   background-color: #b9e294;
#   color: #000000;
# }
# #T_23493_row8_col0 {
#   background-color: #005c32;
#   color: #f1f1f1;
# }
# #T_23493_row8_col1 {
#   background-color: #349a52;
#   color: #f1f1f1;
# }
# #T_23493_row8_col2 {
#   background-color: #84cb7e;
#   color: #000000;
# }
# #T_23493_row8_col3 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_23493_row9_col0 {
#   background-color: #005530;
#   color: #f1f1f1;
# }
# #T_23493_row9_col1 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_23493_row9_col2 {
#   background-color: #61bb6d;
#   color: #f1f1f1;
# }
# #T_23493_row9_col3 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# </style>
# <table id="T_23493">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_23493_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_23493_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_23493_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_23493_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23493_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_23493_row0_col0" class="data row0 col0" >0.6954</td>
#       <td id="T_23493_row0_col1" class="data row0 col1" >0.6386</td>
#       <td id="T_23493_row0_col2" class="data row0 col2" >0.6148</td>
#       <td id="T_23493_row0_col3" class="data row0 col3" >0.5707</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_23493_row1_col0" class="data row1 col0" >0.6801</td>
#       <td id="T_23493_row1_col1" class="data row1 col1" >0.6098</td>
#       <td id="T_23493_row1_col2" class="data row1 col2" >0.5748</td>
#       <td id="T_23493_row1_col3" class="data row1 col3" >0.5629</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_23493_row2_col0" class="data row2 col0" >0.6886</td>
#       <td id="T_23493_row2_col1" class="data row2 col1" >0.6255</td>
#       <td id="T_23493_row2_col2" class="data row2 col2" >0.5895</td>
#       <td id="T_23493_row2_col3" class="data row2 col3" >0.5694</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_23493_row3_col0" class="data row3 col0" >0.6662</td>
#       <td id="T_23493_row3_col1" class="data row3 col1" >0.6074</td>
#       <td id="T_23493_row3_col2" class="data row3 col2" >0.5776</td>
#       <td id="T_23493_row3_col3" class="data row3 col3" >0.5581</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_23493_row4_col0" class="data row4 col0" >0.6311</td>
#       <td id="T_23493_row4_col1" class="data row4 col1" >0.5583</td>
#       <td id="T_23493_row4_col2" class="data row4 col2" >0.4850</td>
#       <td id="T_23493_row4_col3" class="data row4 col3" >0.5235</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_23493_row5_col0" class="data row5 col0" >0.6873</td>
#       <td id="T_23493_row5_col1" class="data row5 col1" >0.6158</td>
#       <td id="T_23493_row5_col2" class="data row5 col2" >0.5889</td>
#       <td id="T_23493_row5_col3" class="data row5 col3" >0.5765</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_23493_row6_col0" class="data row6 col0" >0.6708</td>
#       <td id="T_23493_row6_col1" class="data row6 col1" >0.6223</td>
#       <td id="T_23493_row6_col2" class="data row6 col2" >0.5993</td>
#       <td id="T_23493_row6_col3" class="data row6 col3" >0.5718</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_23493_row7_col0" class="data row7 col0" >0.6596</td>
#       <td id="T_23493_row7_col1" class="data row7 col1" >0.6111</td>
#       <td id="T_23493_row7_col2" class="data row7 col2" >0.5895</td>
#       <td id="T_23493_row7_col3" class="data row7 col3" >0.5568</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_23493_row8_col0" class="data row8 col0" >0.6780</td>
#       <td id="T_23493_row8_col1" class="data row8 col1" >0.6277</td>
#       <td id="T_23493_row8_col2" class="data row8 col2" >0.5841</td>
#       <td id="T_23493_row8_col3" class="data row8 col3" >0.5453</td>
#     </tr>
#     <tr>
#       <th id="T_23493_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_23493_row9_col0" class="data row9 col0" >0.6830</td>
#       <td id="T_23493_row9_col1" class="data row9 col1" >0.6135</td>
#       <td id="T_23493_row9_col2" class="data row9 col2" >0.6015</td>
#       <td id="T_23493_row9_col3" class="data row9 col3" >0.5395</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4b. McNemar's test — accuracy vs every other model (JumpGateLOB & AlphaStableLOB)
#
# Paired significance test on **clean test-set accuracy** for the two diffusion
# models only (`jumpgatelob`, `alphastablelob_1.5`), each compared against every
# other model in the registry. All models are scored on the **same** test windows
# (identical `y_true`, asserted at eval time), so McNemar is the right test: it
# looks only at the **discordant** windows — where exactly one of the two models
# is correct — and asks whether that split departs from 50/50.
#
# - `n01` = target right, other wrong; `n10` = target wrong, other right.
#   `acc_target − acc_other = (n01 − n10)/N`, so `n01 > n10` ⇒ target is the more
#   accurate model.
# - `H0`: the two models have equal accuracy. Small `p` ⇒ the accuracy gap is
#   unlikely to be sampling noise on these windows.
# - Exact binomial when discordant pairs are few (`< 25`), else χ²₁ with Edwards
#   continuity correction — the standard McNemar convention. Self-contained
#   (scipy only), no statsmodels dependency.
#
# BTCIRT only, per the request; not run for the other Nobitex markets.

# %%
from scipy.stats import binom, chi2  # noqa: E402

MCN_TARGETS = ("jumpgatelob", "alphastablelob_1.5")


def mcnemar_accuracy(yp_a, yp_b, yt):
    """Paired McNemar test on per-window correctness of two models scored on the
    SAME test windows. Returns (n01, n10, stat, p, method):
      n01 = A right & B wrong,  n10 = A wrong & B right   (discordant pairs).
    acc_A - acc_B = (n01 - n10)/N, so n01 > n10 ⇒ A more accurate. Exact binomial
    for few discordant pairs (<25), else χ²₁ with Edwards continuity correction.
    """
    a = yp_a == yt
    b = yp_b == yt
    n01 = int(np.sum(a & ~b))
    n10 = int(np.sum(~a & b))
    n = n01 + n10
    if n == 0:
        return n01, n10, 0.0, 1.0, "identical"
    if n < 25:
        p = min(1.0, 2.0 * binom.cdf(min(n01, n10), n, 0.5))
        return n01, n10, float("nan"), float(p), "exact"
    stat = (abs(n01 - n10) - 1.0) ** 2 / n
    return n01, n10, float(stat), float(chi2.sf(stat, 1)), "chi2_cc"


mcn_targets = [t for t in MCN_TARGETS if any((t, k) in RESULTS for k in HORIZONS)]
mcn_others = [m for m in MODELS if m not in MCN_TARGETS]

mcn_rows = []
for tgt in mcn_targets:
    for oth in mcn_others:
        for k in HORIZONS:
            if (tgt, k) not in RESULTS or (oth, k) not in RESULTS:
                continue
            rt, ro = RESULTS[(tgt, k)], RESULTS[(oth, k)]
            yt = rt["y_true"]
            n01, n10, stat, p, method = mcnemar_accuracy(rt["y_pred"], ro["y_pred"], yt)
            acc_t = float((rt["y_pred"] == yt).mean())
            acc_o = float((ro["y_pred"] == yt).mean())
            mcn_rows.append(
                {
                    "target": tgt,
                    "vs": DISPLAY[oth],
                    "k": k,
                    "acc_target": acc_t,
                    "acc_other": acc_o,
                    "d_acc_pp": (acc_t - acc_o) * 100.0,
                    "n01": n01,
                    "n10": n10,
                    "p_value": p,
                    "method": method,
                    "sig": "yes" if p < 0.05 else "no",
                    "better": tgt if n01 > n10 else (oth if n10 > n01 else "tie"),
                }
            )

mcnemar_df = pd.DataFrame(mcn_rows)
if mcnemar_df.empty:
    print("No McNemar results — need jumpgatelob/alphastablelob_1.5 in RESULTS.")
else:
    order = [DISPLAY[o] for o in mcn_others if DISPLAY[o] in set(mcnemar_df["vs"])]
    for tgt in mcn_targets:
        sub = mcnemar_df[mcnemar_df["target"] == tgt]
        if sub.empty:
            continue
        dacc = sub.pivot(index="vs", columns="k", values="d_acc_pp").reindex(order)
        pval = sub.pivot(index="vs", columns="k", values="p_value").reindex(order)
        print(f"\n=== {DISPLAY[tgt]} — McNemar accuracy vs each other model (BTCIRT) ===")
        print("Δaccuracy (percentage points, target − other); + ⇒ target better:")
        display(
            dacc.style.background_gradient(cmap="RdYlGn", axis=None, vmin=-5, vmax=5)
            .format("{:+.2f}")
        )
        print("McNemar p-value (H0: equal accuracy); green ⇒ significant at p<0.05:")
        display(
            pval.style.background_gradient(cmap="RdYlGn_r", axis=None, vmin=0.0, vmax=0.1)
            .format("{:.2e}")
        )
    n_sig = int((mcnemar_df["sig"] == "yes").sum())
    print(f"\n{n_sig}/{len(mcnemar_df)} comparisons significant at p<0.05.")
# Out:
# === jumpgatelob + ofi — McNemar accuracy vs each other model (BTCIRT) ===
# Δaccuracy (percentage points, target − other); + ⇒ target better:
# <style type="text/css">
# #T_6efe9_row0_col0 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_6efe9_row0_col1 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_6efe9_row0_col2 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_6efe9_row0_col3, #T_6efe9_row5_col3 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_6efe9_row1_col0 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_6efe9_row1_col1 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_6efe9_row1_col2 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_6efe9_row1_col3 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_6efe9_row2_col0 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_6efe9_row2_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_6efe9_row2_col2 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_6efe9_row2_col3 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_6efe9_row3_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_6efe9_row3_col1 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_6efe9_row3_col2 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_6efe9_row3_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_6efe9_row4_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_6efe9_row4_col1, #T_6efe9_row4_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6efe9_row4_col3 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_6efe9_row5_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_6efe9_row5_col1 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_6efe9_row5_col2 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_6efe9_row6_col0, #T_6efe9_row6_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_6efe9_row6_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_6efe9_row6_col3 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_6efe9_row7_col0 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_6efe9_row7_col1 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_6efe9_row7_col2 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_6efe9_row7_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# </style>
# <table id="T_6efe9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_6efe9_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_6efe9_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_6efe9_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_6efe9_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vs</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6efe9_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_6efe9_row0_col0" class="data row0 col0" >-1.76</td>
#       <td id="T_6efe9_row0_col1" class="data row0 col1" >-0.92</td>
#       <td id="T_6efe9_row0_col2" class="data row0 col2" >-3.20</td>
#       <td id="T_6efe9_row0_col3" class="data row0 col3" >-2.33</td>
#     </tr>
#     <tr>
#       <th id="T_6efe9_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_6efe9_row1_col0" class="data row1 col0" >-0.19</td>
#       <td id="T_6efe9_row1_col1" class="data row1 col1" >+2.03</td>
#       <td id="T_6efe9_row1_col2" class="data row1 col2" >+0.73</td>
#       <td id="T_6efe9_row1_col3" class="data row1 col3" >-1.83</td>
#     </tr>
#     <tr>
#       <th id="T_6efe9_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_6efe9_row2_col0" class="data row2 col0" >-0.94</td>
#       <td id="T_6efe9_row2_col1" class="data row2 col1" >+0.49</td>
#       <td id="T_6efe9_row2_col2" class="data row2 col2" >-0.60</td>
#       <td id="T_6efe9_row2_col3" class="data row2 col3" >-2.27</td>
#     </tr>
#     <tr>
#       <th id="T_6efe9_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_6efe9_row3_col0" class="data row3 col0" >+1.28</td>
#       <td id="T_6efe9_row3_col1" class="data row3 col1" >+2.23</td>
#       <td id="T_6efe9_row3_col2" class="data row3 col2" >+0.44</td>
#       <td id="T_6efe9_row3_col3" class="data row3 col3" >-1.21</td>
#     </tr>
#     <tr>
#       <th id="T_6efe9_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_6efe9_row4_col0" class="data row4 col0" >+4.43</td>
#       <td id="T_6efe9_row4_col1" class="data row4 col1" >+6.98</td>
#       <td id="T_6efe9_row4_col2" class="data row4 col2" >+8.88</td>
#       <td id="T_6efe9_row4_col3" class="data row4 col3" >+2.07</td>
#     </tr>
#     <tr>
#       <th id="T_6efe9_level0_row5" class="row_heading level0 row5" >linvar + ofi</th>
#       <td id="T_6efe9_row5_col0" class="data row5 col0" >+0.79</td>
#       <td id="T_6efe9_row5_col1" class="data row5 col1" >+0.83</td>
#       <td id="T_6efe9_row5_col2" class="data row5 col2" >-1.55</td>
#       <td id="T_6efe9_row5_col3" class="data row5 col3" >-2.34</td>
#     </tr>
#     <tr>
#       <th id="T_6efe9_level0_row6" class="row_heading level0 row6" >logreg + ofi</th>
#       <td id="T_6efe9_row6_col0" class="data row6 col0" >+1.98</td>
#       <td id="T_6efe9_row6_col1" class="data row6 col1" >+1.97</td>
#       <td id="T_6efe9_row6_col2" class="data row6 col2" >-0.55</td>
#       <td id="T_6efe9_row6_col3" class="data row6 col3" >-0.98</td>
#     </tr>
#     <tr>
#       <th id="T_6efe9_level0_row7" class="row_heading level0 row7" >ofsatnet + ofi</th>
#       <td id="T_6efe9_row7_col0" class="data row7 col0" >-0.40</td>
#       <td id="T_6efe9_row7_col1" class="data row7 col1" >+1.73</td>
#       <td id="T_6efe9_row7_col2" class="data row7 col2" >-2.42</td>
#       <td id="T_6efe9_row7_col3" class="data row7 col3" >+0.43</td>
#     </tr>
#   </tbody>
# </table>
# McNemar p-value (H0: equal accuracy); green ⇒ significant at p<0.05:
# <style type="text/css">
# #T_71243_row0_col0, #T_71243_row0_col1, #T_71243_row0_col2, #T_71243_row0_col3, #T_71243_row1_col1, #T_71243_row1_col3, #T_71243_row2_col0, #T_71243_row2_col3, #T_71243_row3_col0, #T_71243_row3_col1, #T_71243_row3_col3, #T_71243_row4_col0, #T_71243_row4_col1, #T_71243_row4_col2, #T_71243_row4_col3, #T_71243_row5_col0, #T_71243_row5_col1, #T_71243_row5_col2, #T_71243_row5_col3, #T_71243_row6_col0, #T_71243_row6_col1, #T_71243_row6_col3, #T_71243_row7_col1, #T_71243_row7_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_71243_row1_col0, #T_71243_row3_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_71243_row1_col2 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_71243_row2_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_71243_row2_col2 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_71243_row6_col2 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_71243_row7_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_71243_row7_col3 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# </style>
# <table id="T_71243">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_71243_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_71243_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_71243_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_71243_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vs</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71243_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_71243_row0_col0" class="data row0 col0" >5.79e-24</td>
#       <td id="T_71243_row0_col1" class="data row0 col1" >8.09e-06</td>
#       <td id="T_71243_row0_col2" class="data row0 col2" >1.73e-38</td>
#       <td id="T_71243_row0_col3" class="data row0 col3" >2.01e-21</td>
#     </tr>
#     <tr>
#       <th id="T_71243_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_71243_row1_col0" class="data row1 col0" >3.06e-01</td>
#       <td id="T_71243_row1_col1" class="data row1 col1" >5.24e-16</td>
#       <td id="T_71243_row1_col2" class="data row1 col2" >9.53e-03</td>
#       <td id="T_71243_row1_col3" class="data row1 col3" >1.71e-11</td>
#     </tr>
#     <tr>
#       <th id="T_71243_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_71243_row2_col0" class="data row2 col0" >5.60e-08</td>
#       <td id="T_71243_row2_col1" class="data row2 col1" >2.79e-02</td>
#       <td id="T_71243_row2_col2" class="data row2 col2" >2.06e-02</td>
#       <td id="T_71243_row2_col3" class="data row2 col3" >7.13e-21</td>
#     </tr>
#     <tr>
#       <th id="T_71243_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_71243_row3_col0" class="data row3 col0" >1.08e-10</td>
#       <td id="T_71243_row3_col1" class="data row3 col1" >3.41e-20</td>
#       <td id="T_71243_row3_col2" class="data row3 col2" >1.20e-01</td>
#       <td id="T_71243_row3_col3" class="data row3 col3" >1.71e-05</td>
#     </tr>
#     <tr>
#       <th id="T_71243_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_71243_row4_col0" class="data row4 col0" >7.28e-91</td>
#       <td id="T_71243_row4_col1" class="data row4 col1" >3.44e-141</td>
#       <td id="T_71243_row4_col2" class="data row4 col2" >3.13e-180</td>
#       <td id="T_71243_row4_col3" class="data row4 col3" >1.60e-11</td>
#     </tr>
#     <tr>
#       <th id="T_71243_level0_row5" class="row_heading level0 row5" >linvar + ofi</th>
#       <td id="T_71243_row5_col0" class="data row5 col0" >5.93e-06</td>
#       <td id="T_71243_row5_col1" class="data row5 col1" >2.93e-04</td>
#       <td id="T_71243_row5_col2" class="data row5 col2" >1.46e-09</td>
#       <td id="T_71243_row5_col3" class="data row5 col3" >5.25e-21</td>
#     </tr>
#     <tr>
#       <th id="T_71243_level0_row6" class="row_heading level0 row6" >logreg + ofi</th>
#       <td id="T_71243_row6_col0" class="data row6 col0" >2.02e-25</td>
#       <td id="T_71243_row6_col1" class="data row6 col1" >2.04e-17</td>
#       <td id="T_71243_row6_col2" class="data row6 col2" >3.04e-02</td>
#       <td id="T_71243_row6_col3" class="data row6 col3" >3.87e-05</td>
#     </tr>
#     <tr>
#       <th id="T_71243_level0_row7" class="row_heading level0 row7" >ofsatnet + ofi</th>
#       <td id="T_71243_row7_col0" class="data row7 col0" >1.10e-02</td>
#       <td id="T_71243_row7_col1" class="data row7 col1" >9.63e-14</td>
#       <td id="T_71243_row7_col2" class="data row7 col2" >3.43e-20</td>
#       <td id="T_71243_row7_col3" class="data row7 col3" >5.14e-02</td>
#     </tr>
#   </tbody>
# </table>
# === alphastablelob_1.5 + ofi — McNemar accuracy vs each other model (BTCIRT) ===
# Δaccuracy (percentage points, target − other); + ⇒ target better:
# <style type="text/css">
# #T_84d02_row0_col0 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_84d02_row0_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_84d02_row0_col2 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_84d02_row0_col3, #T_84d02_row6_col1 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_84d02_row1_col0, #T_84d02_row3_col1 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_84d02_row1_col1 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_84d02_row1_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_84d02_row1_col3 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_84d02_row2_col0 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_84d02_row2_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_84d02_row2_col2 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_84d02_row2_col3, #T_84d02_row7_col0 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_84d02_row3_col0 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_84d02_row3_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_84d02_row3_col3 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_84d02_row4_col0, #T_84d02_row4_col1, #T_84d02_row4_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_84d02_row4_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_84d02_row5_col0 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_84d02_row5_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_84d02_row5_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_84d02_row5_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_84d02_row6_col0 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_84d02_row6_col2 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_84d02_row6_col3 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_84d02_row7_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_84d02_row7_col2 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_84d02_row7_col3 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_84d02">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_84d02_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_84d02_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_84d02_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_84d02_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vs</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84d02_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_84d02_row0_col0" class="data row0 col0" >-0.78</td>
#       <td id="T_84d02_row0_col1" class="data row0 col1" >-2.36</td>
#       <td id="T_84d02_row0_col2" class="data row0 col2" >-2.73</td>
#       <td id="T_84d02_row0_col3" class="data row0 col3" >+0.51</td>
#     </tr>
#     <tr>
#       <th id="T_84d02_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_84d02_row1_col0" class="data row1 col0" >+0.79</td>
#       <td id="T_84d02_row1_col1" class="data row1 col1" >+0.59</td>
#       <td id="T_84d02_row1_col2" class="data row1 col2" >+1.20</td>
#       <td id="T_84d02_row1_col3" class="data row1 col3" >+1.01</td>
#     </tr>
#     <tr>
#       <th id="T_84d02_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_84d02_row2_col0" class="data row2 col0" >+0.04</td>
#       <td id="T_84d02_row2_col1" class="data row2 col1" >-0.96</td>
#       <td id="T_84d02_row2_col2" class="data row2 col2" >-0.13</td>
#       <td id="T_84d02_row2_col3" class="data row2 col3" >+0.57</td>
#     </tr>
#     <tr>
#       <th id="T_84d02_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_84d02_row3_col0" class="data row3 col0" >+2.26</td>
#       <td id="T_84d02_row3_col1" class="data row3 col1" >+0.79</td>
#       <td id="T_84d02_row3_col2" class="data row3 col2" >+0.91</td>
#       <td id="T_84d02_row3_col3" class="data row3 col3" >+1.63</td>
#     </tr>
#     <tr>
#       <th id="T_84d02_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_84d02_row4_col0" class="data row4 col0" >+5.41</td>
#       <td id="T_84d02_row4_col1" class="data row4 col1" >+5.54</td>
#       <td id="T_84d02_row4_col2" class="data row4 col2" >+9.35</td>
#       <td id="T_84d02_row4_col3" class="data row4 col3" >+4.91</td>
#     </tr>
#     <tr>
#       <th id="T_84d02_level0_row5" class="row_heading level0 row5" >linvar + ofi</th>
#       <td id="T_84d02_row5_col0" class="data row5 col0" >+1.77</td>
#       <td id="T_84d02_row5_col1" class="data row5 col1" >-0.61</td>
#       <td id="T_84d02_row5_col2" class="data row5 col2" >-1.08</td>
#       <td id="T_84d02_row5_col3" class="data row5 col3" >+0.50</td>
#     </tr>
#     <tr>
#       <th id="T_84d02_level0_row6" class="row_heading level0 row6" >logreg + ofi</th>
#       <td id="T_84d02_row6_col0" class="data row6 col0" >+2.96</td>
#       <td id="T_84d02_row6_col1" class="data row6 col1" >+0.53</td>
#       <td id="T_84d02_row6_col2" class="data row6 col2" >-0.08</td>
#       <td id="T_84d02_row6_col3" class="data row6 col3" >+1.86</td>
#     </tr>
#     <tr>
#       <th id="T_84d02_level0_row7" class="row_heading level0 row7" >ofsatnet + ofi</th>
#       <td id="T_84d02_row7_col0" class="data row7 col0" >+0.58</td>
#       <td id="T_84d02_row7_col1" class="data row7 col1" >+0.29</td>
#       <td id="T_84d02_row7_col2" class="data row7 col2" >-1.95</td>
#       <td id="T_84d02_row7_col3" class="data row7 col3" >+3.27</td>
#     </tr>
#   </tbody>
# </table>
# McNemar p-value (H0: equal accuracy); green ⇒ significant at p<0.05:
# <style type="text/css">
# #T_262ba_row0_col0, #T_262ba_row0_col1, #T_262ba_row0_col2, #T_262ba_row1_col0, #T_262ba_row1_col2, #T_262ba_row1_col3, #T_262ba_row2_col1, #T_262ba_row3_col0, #T_262ba_row3_col3, #T_262ba_row4_col0, #T_262ba_row4_col1, #T_262ba_row4_col2, #T_262ba_row4_col3, #T_262ba_row5_col0, #T_262ba_row5_col2, #T_262ba_row6_col0, #T_262ba_row6_col3, #T_262ba_row7_col2, #T_262ba_row7_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_262ba_row0_col3 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_262ba_row1_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_262ba_row2_col0, #T_262ba_row2_col2, #T_262ba_row6_col2, #T_262ba_row7_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_262ba_row2_col3 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_262ba_row3_col1, #T_262ba_row3_col2 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_262ba_row5_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_262ba_row5_col3 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_262ba_row6_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_262ba_row7_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_262ba">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_262ba_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_262ba_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_262ba_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_262ba_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vs</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_262ba_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_262ba_row0_col0" class="data row0 col0" >8.43e-07</td>
#       <td id="T_262ba_row0_col1" class="data row0 col1" >9.28e-30</td>
#       <td id="T_262ba_row0_col2" class="data row0 col2" >1.34e-32</td>
#       <td id="T_262ba_row0_col3" class="data row0 col3" >3.79e-02</td>
#     </tr>
#     <tr>
#       <th id="T_262ba_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_262ba_row1_col0" class="data row1 col0" >2.86e-05</td>
#       <td id="T_262ba_row1_col1" class="data row1 col1" >2.00e-02</td>
#       <td id="T_262ba_row1_col2" class="data row1 col2" >2.13e-05</td>
#       <td id="T_262ba_row1_col3" class="data row1 col3" >3.32e-04</td>
#     </tr>
#     <tr>
#       <th id="T_262ba_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_262ba_row2_col0" class="data row2 col0" >8.36e-01</td>
#       <td id="T_262ba_row2_col1" class="data row2 col1" >2.96e-05</td>
#       <td id="T_262ba_row2_col2" class="data row2 col2" >6.03e-01</td>
#       <td id="T_262ba_row2_col3" class="data row2 col3" >2.18e-02</td>
#     </tr>
#     <tr>
#       <th id="T_262ba_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_262ba_row3_col0" class="data row3 col0" >2.81e-30</td>
#       <td id="T_262ba_row3_col1" class="data row3 col1" >9.85e-04</td>
#       <td id="T_262ba_row3_col2" class="data row3 col2" >1.05e-03</td>
#       <td id="T_262ba_row3_col3" class="data row3 col3" >1.03e-08</td>
#     </tr>
#     <tr>
#       <th id="T_262ba_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_262ba_row4_col0" class="data row4 col0" >1.29e-121</td>
#       <td id="T_262ba_row4_col1" class="data row4 col1" >2.28e-90</td>
#       <td id="T_262ba_row4_col2" class="data row4 col2" >3.24e-199</td>
#       <td id="T_262ba_row4_col3" class="data row4 col3" >1.18e-59</td>
#     </tr>
#     <tr>
#       <th id="T_262ba_level0_row5" class="row_heading level0 row5" >linvar + ofi</th>
#       <td id="T_262ba_row5_col0" class="data row5 col0" >7.64e-22</td>
#       <td id="T_262ba_row5_col1" class="data row5 col1" >8.68e-03</td>
#       <td id="T_262ba_row5_col2" class="data row5 col2" >2.85e-06</td>
#       <td id="T_262ba_row5_col3" class="data row5 col3" >3.57e-02</td>
#     </tr>
#     <tr>
#       <th id="T_262ba_level0_row6" class="row_heading level0 row6" >logreg + ofi</th>
#       <td id="T_262ba_row6_col0" class="data row6 col0" >3.81e-47</td>
#       <td id="T_262ba_row6_col1" class="data row6 col1" >2.42e-02</td>
#       <td id="T_262ba_row6_col2" class="data row6 col2" >7.47e-01</td>
#       <td id="T_262ba_row6_col3" class="data row6 col3" >3.13e-14</td>
#     </tr>
#     <tr>
#       <th id="T_262ba_level0_row7" class="row_heading level0 row7" >ofsatnet + ofi</th>
#       <td id="T_262ba_row7_col0" class="data row7 col0" >5.98e-04</td>
#       <td id="T_262ba_row7_col1" class="data row7 col1" >1.95e-01</td>
#       <td id="T_262ba_row7_col2" class="data row7 col2" >8.34e-15</td>
#       <td id="T_262ba_row7_col3" class="data row7 col3" >1.74e-40</td>
#     </tr>
#   </tbody>
# </table>
# 57/64 comparisons significant at p<0.05.

# %% [markdown]
# ## 5. Confusion matrices
#
# Row-normalized (recall per true class). One row of panels per horizon.

# %%
def plot_confusions(k):
    tags = [t for t in MODELS if (t, k) in RESULTS]
    if not tags:
        return
    fig, axes = plt.subplots(
        1, len(tags), figsize=(3.1 * len(tags), 3.0), squeeze=False
    )
    for ax, tag in zip(axes[0], tags):
        r = RESULTS[(tag, k)]
        cm = confusion_matrix(r["y_true"], r["y_pred"], labels=[0, 1, 2]).astype(float)
        cmn = cm / cm.sum(1, keepdims=True).clip(min=1)
        _ = ax.imshow(cmn, cmap="Blues", vmin=0, vmax=1)
        for i in range(3):
            for j in range(3):
                ax.text(
                    j,
                    i,
                    f"{cmn[i, j]:.2f}",
                    ha="center",
                    va="center",
                    color="white" if cmn[i, j] > 0.5 else "black",
                    fontsize=8,
                )
        ax.set_xticks(range(3), LABELS, rotation=45, ha="right", fontsize=7)
        ax.set_yticks(range(3), LABELS, fontsize=7)
        ax.set_title(DISPLAY[tag], fontsize=8)
        ax.set_xlabel("pred", fontsize=7)
    axes[0][0].set_ylabel("true", fontsize=7)
    fig.suptitle(f"Confusion (row-normalized) — horizon k={k}", y=1.04)
    fig.tight_layout()
    plt.show()


for k in HORIZONS:
    plot_confusions(k)

# %% [markdown]
# ## 6. Metric vs horizon
#
# How each model's accuracy and macro-F1 evolve as the prediction horizon grows.

# %%
if not metrics_df.empty:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4.2))
    cmap = plt.get_cmap("tab10")
    present = [m for m in MODELS if DISPLAY[m] in set(metrics_df["model"])]
    for metric, ax in zip(["accuracy", "macro_f1"], axes):
        for i, tag in enumerate(present):
            sub = metrics_df[metrics_df["model"] == DISPLAY[tag]].sort_values("k")
            ax.plot(sub["k"], sub[metric], "o-", color=cmap(i % 10), label=DISPLAY[tag])
        ax.set_xlabel("horizon k")
        ax.set_ylabel(metric)
        ax.set_title(f"{metric} vs horizon")
        ax.set_xticks(HORIZONS)
        ax.grid(alpha=0.3)
    axes[1].legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ## 7. Extreme conditions (jumps)
#
# Windows are split by their **stress score** (RV-normalized max increment). We
# compare performance on **calm** vs **extreme** windows, where *extreme* = the top
# `EXTREME_Q` quantile of stress **within each horizon** (guarantees non-empty
# buckets). A large `Δ = calm − extreme` means a model degrades under turbulence;
# a small Δ means it is jump-robust.

# %%
EXTREME_Q = 0.90  # top 10% most turbulent windows = "extreme"


def split_metrics(r, thr):
    st = r["stress"]
    calm, extr = st <= thr, st > thr
    out = {}
    for name, mask in [("calm", calm), ("extreme", extr)]:
        if mask.sum() == 0:
            out[name] = {"n": 0, "accuracy": np.nan, "macro_f1": np.nan}
            continue
        yt, yp = r["y_true"][mask], r["y_pred"][mask]
        out[name] = {
            "n": int(mask.sum()),
            "accuracy": (yt == yp).mean(),
            "macro_f1": f1_score(
                yt, yp, average="macro", labels=[0, 1, 2], zero_division=0
            ),
        }
    return out


rows = []
for (tag, k), r in RESULTS.items():
    thr = np.quantile(r["stress"], EXTREME_Q)
    s = split_metrics(r, thr)
    rows.append(
        {
            "model": DISPLAY[tag],
            "k": k,
            "acc_calm": s["calm"]["accuracy"],
            "acc_extreme": s["extreme"]["accuracy"],
            "f1_calm": s["calm"]["macro_f1"],
            "f1_extreme": s["extreme"]["macro_f1"],
            "f1_drop": s["calm"]["macro_f1"] - s["extreme"]["macro_f1"],
            "n_extreme": s["extreme"]["n"],
        }
    )
extreme_df = pd.DataFrame(rows).sort_values(["k", "model"]).reset_index(drop=True)
extreme_df
# Out:
#                        model    k  acc_calm  acc_extreme  f1_calm  f1_extreme  \
# 0   alphastablelob_1.5 + ofi   10    0.6871       0.7248   0.6844      0.7116
# 1             binctabl + ofi   10    0.6656       0.6919   0.6643      0.6795
# 2                ctabl + ofi   10    0.6870       0.7220   0.6858      0.7119
# 3              deeplob + ofi   10    0.6322       0.6788   0.6275      0.6613
# 4                  dla + ofi   10    0.6953       0.7295   0.6928      0.7165
# 5          jumpgatelob + ofi   10    0.6778       0.7110   0.6754      0.6983
# 6               linvar + ofi   10    0.6703       0.7001   0.6686      0.6875
# 7               logreg + ofi   10    0.6580       0.6910   0.6571      0.6788
# 8             ofsatnet + ofi   10    0.6832       0.7029   0.6816      0.6935
# 9                 tlob + ofi   10    0.6789       0.7201   0.6768      0.7075
# 10  alphastablelob_1.5 + ofi   20    0.6085       0.6593   0.6109      0.6554
# 11            binctabl + ofi   20    0.6033       0.6273   0.6052      0.6251
# 12               ctabl + ofi   20    0.6197       0.6546   0.6221      0.6544
# 13             deeplob + ofi   20    0.5529       0.6063   0.5536      0.5894
# 14                 dla + ofi   20    0.6335       0.6702   0.6352      0.6664
# 15         jumpgatelob + ofi   20    0.6238       0.6665   0.6238      0.6616
# 16              linvar + ofi   20    0.6161       0.6517   0.6191      0.6482
# 17              logreg + ofi   20    0.6052       0.6367   0.6081      0.6341
# 18            ofsatnet + ofi   20    0.6092       0.6242   0.6118      0.6260
# 19                tlob + ofi   20    0.6081       0.6044   0.6102      0.6025
# 20  alphastablelob_1.5 + ofi   50    0.5818       0.5987   0.5871      0.6051
# 21            binctabl + ofi   50    0.5739       0.5790   0.5770      0.5836
# 22               ctabl + ofi   50    0.5826       0.6047   0.5872      0.6096
# 23             deeplob + ofi   50    0.4846       0.5395   0.4792      0.5354
# 24                 dla + ofi   50    0.6112       0.6072   0.6151      0.6123
# 25         jumpgatelob + ofi   50    0.5772       0.5937   0.5824      0.6009
# 26              linvar + ofi   50    0.5942       0.5953   0.5990      0.6019
# 27              logreg + ofi   50    0.5834       0.5925   0.5884      0.6000
# 28            ofsatnet + ofi   50    0.6024       0.6091   0.6009      0.6074
# 29                tlob + ofi   50    0.5675       0.6082   0.5708      0.6113
# 30  alphastablelob_1.5 + ofi  100    0.5630       0.6421   0.5686      0.6474
# 31            binctabl + ofi  100    0.5514       0.5830   0.5548      0.5873
# 32               ctabl + ofi  100    0.5575       0.6339   0.5618      0.6366
# 33             deeplob + ofi  100    0.5177       0.5579   0.5194      0.5599
# 34                 dla + ofi  100    0.5619       0.6003   0.5670      0.6052
# 35         jumpgatelob + ofi  100    0.5351       0.6085   0.5382      0.6094
# 36              linvar + ofi  100    0.5615       0.6050   0.5675      0.6099
# 37              logreg + ofi  100    0.5458       0.6100   0.5503      0.6139
# 38            ofsatnet + ofi  100    0.5310       0.6031   0.5323      0.6048
# 39                tlob + ofi  100    0.5573       0.5918   0.5589      0.5986
#
#     f1_drop  n_extreme
# 0   -0.0272       3194
# 1   -0.0152       3194
# 2   -0.0261       3194
# 3   -0.0338       3194
# 4   -0.0236       3194
# 5   -0.0229       3194
# 6   -0.0189       3194
# 7   -0.0217       3194
# 8   -0.0119       3194
# 9   -0.0308       3194
# 10  -0.0445       3193
# 11  -0.0200       3193
# 12  -0.0322       3193
# 13  -0.0358       3193
# 14  -0.0311       3193
# 15  -0.0378       3193
# 16  -0.0291       3193
# 17  -0.0260       3193
# 18  -0.0142       3193
# 19   0.0077       3193
# 20  -0.0180       3190
# 21  -0.0066       3190
# 22  -0.0223       3190
# 23  -0.0562       3190
# 24   0.0028       3190
# 25  -0.0185       3190
# 26  -0.0028       3190
# 27  -0.0116       3190
# 28  -0.0065       3190
# 29  -0.0406       3190
# 30  -0.0789       3185
# 31  -0.0325       3185
# 32  -0.0748       3185
# 33  -0.0406       3185
# 34  -0.0382       3185
# 35  -0.0713       3185
# 36  -0.0424       3185
# 37  -0.0636       3185
# 38  -0.0725       3185
# 39  -0.0397       3185

# %%
# macro-F1 drop under stress (rows=model, cols=horizon) — lower is more robust
if not extreme_df.empty:
    order = [DISPLAY[m] for m in MODELS if DISPLAY[m] in set(extreme_df["model"])]
    piv = extreme_df.pivot(index="model", columns="k", values="f1_drop").reindex(order)
    print("=== macro-F1 drop (calm − extreme); lower = more jump-robust ===")
    display(piv.style.background_gradient(cmap="Reds", axis=None).format("{:.4f}"))
# Out:
# === macro-F1 drop (calm − extreme); lower = more jump-robust ===
# <style type="text/css">
# #T_05601_row0_col0 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_05601_row0_col1 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_05601_row0_col2 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_05601_row0_col3 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_05601_row1_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_05601_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_05601_row1_col2, #T_05601_row4_col3 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_05601_row1_col3 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_05601_row2_col0 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_05601_row2_col1, #T_05601_row3_col3 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_05601_row2_col2 {
#   background-color: #e63328;
#   color: #f1f1f1;
# }
# #T_05601_row2_col3 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_05601_row3_col0 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_05601_row3_col1 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_05601_row3_col2 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_05601_row4_col0 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_05601_row4_col1 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_05601_row4_col2 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_05601_row5_col0 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_05601_row5_col1 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_05601_row5_col2 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_05601_row5_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_05601_row6_col0 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_05601_row6_col1 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_05601_row6_col2 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_05601_row6_col3 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_05601_row7_col0 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_05601_row7_col1 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_05601_row7_col2 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_05601_row7_col3 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_05601_row8_col0 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_05601_row8_col1 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_05601_row8_col2 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_05601_row8_col3 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_05601_row9_col0 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_05601_row9_col1 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_05601_row9_col2 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_05601_row9_col3 {
#   background-color: #fee9df;
#   color: #000000;
# }
# </style>
# <table id="T_05601">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_05601_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_05601_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_05601_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_05601_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05601_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_05601_row0_col0" class="data row0 col0" >-0.0236</td>
#       <td id="T_05601_row0_col1" class="data row0 col1" >-0.0311</td>
#       <td id="T_05601_row0_col2" class="data row0 col2" >0.0028</td>
#       <td id="T_05601_row0_col3" class="data row0 col3" >-0.0382</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_05601_row1_col0" class="data row1 col0" >-0.0308</td>
#       <td id="T_05601_row1_col1" class="data row1 col1" >0.0077</td>
#       <td id="T_05601_row1_col2" class="data row1 col2" >-0.0406</td>
#       <td id="T_05601_row1_col3" class="data row1 col3" >-0.0397</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_05601_row2_col0" class="data row2 col0" >-0.0261</td>
#       <td id="T_05601_row2_col1" class="data row2 col1" >-0.0322</td>
#       <td id="T_05601_row2_col2" class="data row2 col2" >-0.0223</td>
#       <td id="T_05601_row2_col3" class="data row2 col3" >-0.0748</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_05601_row3_col0" class="data row3 col0" >-0.0152</td>
#       <td id="T_05601_row3_col1" class="data row3 col1" >-0.0200</td>
#       <td id="T_05601_row3_col2" class="data row3 col2" >-0.0066</td>
#       <td id="T_05601_row3_col3" class="data row3 col3" >-0.0325</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_05601_row4_col0" class="data row4 col0" >-0.0338</td>
#       <td id="T_05601_row4_col1" class="data row4 col1" >-0.0358</td>
#       <td id="T_05601_row4_col2" class="data row4 col2" >-0.0562</td>
#       <td id="T_05601_row4_col3" class="data row4 col3" >-0.0406</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_05601_row5_col0" class="data row5 col0" >-0.0272</td>
#       <td id="T_05601_row5_col1" class="data row5 col1" >-0.0445</td>
#       <td id="T_05601_row5_col2" class="data row5 col2" >-0.0180</td>
#       <td id="T_05601_row5_col3" class="data row5 col3" >-0.0789</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_05601_row6_col0" class="data row6 col0" >-0.0189</td>
#       <td id="T_05601_row6_col1" class="data row6 col1" >-0.0291</td>
#       <td id="T_05601_row6_col2" class="data row6 col2" >-0.0028</td>
#       <td id="T_05601_row6_col3" class="data row6 col3" >-0.0424</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_05601_row7_col0" class="data row7 col0" >-0.0217</td>
#       <td id="T_05601_row7_col1" class="data row7 col1" >-0.0260</td>
#       <td id="T_05601_row7_col2" class="data row7 col2" >-0.0116</td>
#       <td id="T_05601_row7_col3" class="data row7 col3" >-0.0636</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_05601_row8_col0" class="data row8 col0" >-0.0229</td>
#       <td id="T_05601_row8_col1" class="data row8 col1" >-0.0378</td>
#       <td id="T_05601_row8_col2" class="data row8 col2" >-0.0185</td>
#       <td id="T_05601_row8_col3" class="data row8 col3" >-0.0713</td>
#     </tr>
#     <tr>
#       <th id="T_05601_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_05601_row9_col0" class="data row9 col0" >-0.0119</td>
#       <td id="T_05601_row9_col1" class="data row9 col1" >-0.0142</td>
#       <td id="T_05601_row9_col2" class="data row9 col2" >-0.0065</td>
#       <td id="T_05601_row9_col3" class="data row9 col3" >-0.0725</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Accuracy vs stress decile
#
# Windows binned into stress deciles; per-model accuracy in each bin. The right side of each panel is the turbulent regime.

# %%
def plot_stress_curves(k, n_bins=10):
    tags = [t for t in MODELS if (t, k) in RESULTS]
    if not tags:
        return None
    stress = RESULTS[(tags[0], k)]["stress"]
    edges = np.quantile(stress, np.linspace(0, 1, n_bins + 1))
    edges[-1] += 1e-9
    centers = 0.5 * (edges[:-1] + edges[1:])
    cmap = plt.get_cmap("tab10")
    fig, ax = plt.subplots(figsize=(7, 4))
    for i, tag in enumerate(tags):
        r = RESULTS[(tag, k)]
        correct = (r["y_true"] == r["y_pred"]).astype(float)
        idx = np.clip(np.digitize(r["stress"], edges) - 1, 0, n_bins - 1)
        acc = [
            correct[idx == b].mean() if (idx == b).any() else np.nan
            for b in range(n_bins)
        ]
        ax.plot(centers, acc, "o-", color=cmap(i % 10), label=DISPLAY[tag])
    ax.set_xlabel("window stress (RV units) — decile centers")
    ax.set_ylabel("accuracy")
    ax.set_title(f"Accuracy vs stress — horizon k={k}")
    ax.grid(alpha=0.3)
    ax.legend(fontsize=8)
    fig.tight_layout()
    plt.show()


for k in HORIZONS:
    plot_stress_curves(k)

# %% [markdown]
# ### Catching the big moves
#
# In the extreme bucket, per-class **recall** for `down` and `up` — does the model still flag large directional moves when they happen?

# %%
rows = []
for (tag, k), r in RESULTS.items():
    thr = np.quantile(r["stress"], EXTREME_Q)
    mask = r["stress"] > thr
    if mask.sum() == 0:
        continue
    yt, yp = r["y_true"][mask], r["y_pred"][mask]
    rec = recall_score(yt, yp, average=None, labels=[0, 1, 2], zero_division=0)
    rows.append(
        {"model": DISPLAY[tag], "k": k, "recall_down": rec[0], "recall_up": rec[2]}
    )
recall_df = pd.DataFrame(rows).sort_values(["k", "model"]).reset_index(drop=True)
recall_df
# Out:
#                        model    k  recall_down  recall_up
# 0   alphastablelob_1.5 + ofi   10       0.5664     0.6878
# 1             binctabl + ofi   10       0.5450     0.6878
# 2                ctabl + ofi   10       0.6028     0.7061
# 3              deeplob + ofi   10       0.5589     0.6134
# 4                  dla + ofi   10       0.5803     0.6768
# 5          jumpgatelob + ofi   10       0.5846     0.6683
# 6               linvar + ofi   10       0.5653     0.6341
# 7               logreg + ofi   10       0.5696     0.6293
# 8             ofsatnet + ofi   10       0.5867     0.6976
# 9                 tlob + ofi   10       0.5910     0.6756
# 10  alphastablelob_1.5 + ofi   20       0.5940     0.6727
# 11            binctabl + ofi   20       0.5696     0.6436
# 12               ctabl + ofi   20       0.6174     0.6836
# 13             deeplob + ofi   20       0.4548     0.5842
# 14                 dla + ofi   20       0.5760     0.6776
# 15         jumpgatelob + ofi   20       0.5654     0.6642
# 16              linvar + ofi   20       0.5600     0.6655
# 17              logreg + ofi   20       0.5685     0.6485
# 18            ofsatnet + ofi   20       0.6068     0.6800
# 19                tlob + ofi   20       0.5409     0.6182
# 20  alphastablelob_1.5 + ofi   50       0.5396     0.7400
# 21            binctabl + ofi   50       0.5304     0.6663
# 22               ctabl + ofi   50       0.6667     0.7250
# 23             deeplob + ofi   50       0.7735     0.5650
# 24                 dla + ofi   50       0.5534     0.7425
# 25         jumpgatelob + ofi   50       0.5525     0.7812
# 26              linvar + ofi   50       0.6142     0.7662
# 27              logreg + ofi   50       0.6050     0.7450
# 28            ofsatnet + ofi   50       0.4346     0.6613
# 29                tlob + ofi   50       0.7247     0.6562
# 30  alphastablelob_1.5 + ofi  100       0.6389     0.6545
# 31            binctabl + ofi  100       0.5711     0.5668
# 32               ctabl + ofi  100       0.7272     0.6406
# 33             deeplob + ofi  100       0.5054     0.5882
# 34                 dla + ofi  100       0.6163     0.7080
# 35         jumpgatelob + ofi  100       0.7056     0.7476
# 36              linvar + ofi  100       0.6624     0.7102
# 37              logreg + ofi  100       0.7036     0.6385
# 38            ofsatnet + ofi  100       0.7213     0.7037
# 39                tlob + ofi  100       0.7007     0.5925

# %% [markdown]
# ## 7b. Financial / trading metrics
#
# Classification scores alone don't say whether signals are *tradeable*. Everything
# here is computed against the **realized smoothed trend** `trend_ratio` of each test
# window — the exact quantity the ±α labels threshold — so it is a cost-free proxy for
# signal quality, **not a trading simulation** (no positions, costs, or fills; that
# comes later):
#
# - **MCC & Cohen's κ** — chance-corrected agreement, the headline metrics of recent
#   LOB benchmarks (robust to class imbalance, unlike accuracy).
# - **Signal rate / directional hit rate** — how often a model calls a direction, and
#   the per-signal win rate when it does.
# - **Directional capture** — mean signed trend captured per window (bp):
#   `+trend` on up-calls, `−trend` on down-calls, `0` on flat.
#   `capture_ratio` = captured / oracle (oracle = always right on every window).

# %%
def _positions(yp):
    """Predicted position per window: up → +1, down → −1, flat → 0."""
    return np.where(yp == 2, 1, np.where(yp == 0, -1, 0))


fin_rows = []
for (tag, k), r in RESULTS.items():
    m = META.get(k)
    if m is None:
        continue
    yt, yp = r["y_true"], r["y_pred"]
    tr = np.nan_to_num(m["trend"])
    pos = _positions(yp)
    cap = pos * tr
    d = pos != 0
    fin_rows.append(
        {
            "model": DISPLAY[tag],
            "k": k,
            "mcc": matthews_corrcoef(yt, yp),
            "kappa": cohen_kappa_score(yt, yp),
            "signal_rate": d.mean(),
            "hit_rate": (np.sign(tr[d]) == pos[d]).mean() if d.any() else np.nan,
            "capture_bp_win": cap.mean() * 1e4,
            "capture_bp_signal": cap[d].mean() * 1e4 if d.any() else np.nan,
            "oracle_bp_win": np.abs(tr).mean() * 1e4,
            "capture_ratio": cap.mean() / max(np.abs(tr).mean(), 1e-12),
        }
    )
fin_df = pd.DataFrame(fin_rows).sort_values(["k", "model"]).reset_index(drop=True)
fin_df
# Out:
#                        model    k    mcc  kappa  signal_rate  hit_rate  \
# 0   alphastablelob_1.5 + ofi   10 0.5306 0.5275       0.5389    0.8313
# 1             binctabl + ofi   10 0.4965 0.4952       0.5686    0.8090
# 2                ctabl + ofi   10 0.5301 0.5284       0.5591    0.8292
# 3              deeplob + ofi   10 0.4479 0.4476       0.5766    0.7396
# 4                  dla + ofi   10 0.5419 0.5388       0.5327    0.8428
# 5          jumpgatelob + ofi   10 0.5150 0.5137       0.5575    0.8166
# 6               linvar + ofi   10 0.5026 0.5004       0.5404    0.8235
# 7               logreg + ofi   10 0.4847 0.4838       0.5617    0.8091
# 8             ofsatnet + ofi   10 0.5215 0.5207       0.5680    0.8237
# 9                 tlob + ofi   10 0.5174 0.5161       0.5523    0.8238
# 10  alphastablelob_1.5 + ofi   20 0.4199 0.4181       0.6399    0.7886
# 11            binctabl + ofi   20 0.4050 0.4043       0.6253    0.7802
# 12               ctabl + ofi   20 0.4300 0.4296       0.6149    0.8104
# 13             deeplob + ofi   20 0.3350 0.3339       0.6342    0.7234
# 14                 dla + ofi   20 0.4486 0.4484       0.5899    0.8181
# 15         jumpgatelob + ofi   20 0.4315 0.4310       0.5596    0.8060
# 16              linvar + ofi   20 0.4228 0.4227       0.5986    0.8154
# 17              logreg + ofi   20 0.4098 0.4089       0.6322    0.7968
# 18            ofsatnet + ofi   20 0.4189 0.4159       0.6627    0.7950
# 19                tlob + ofi   20 0.4065 0.4059       0.6179    0.7867
# 20  alphastablelob_1.5 + ofi   50 0.3718 0.3698       0.6278    0.8034
# 21            binctabl + ofi   50 0.3622 0.3590       0.6456    0.7699
# 22               ctabl + ofi   50 0.3850 0.3791       0.6803    0.7981
# 23             deeplob + ofi   50 0.2798 0.2567       0.8106    0.7260
# 24                 dla + ofi   50 0.4108 0.4092       0.6129    0.8247
# 25         jumpgatelob + ofi   50 0.3693 0.3660       0.6494    0.7937
# 26              linvar + ofi   50 0.3929 0.3894       0.6510    0.8120
# 27              logreg + ofi   50 0.3836 0.3780       0.6769    0.8079
# 28            ofsatnet + ofi   50 0.3852 0.3832       0.5121    0.8192
# 29                tlob + ofi   50 0.3731 0.3619       0.7099    0.7778
# 30  alphastablelob_1.5 + ofi  100 0.3508 0.3492       0.6212    0.8140
# 31            binctabl + ofi  100 0.3401 0.3343       0.6814    0.7581
# 32               ctabl + ofi  100 0.3636 0.3544       0.7093    0.7885
# 33             deeplob + ofi  100 0.2827 0.2789       0.6382    0.7478
# 34                 dla + ofi  100 0.3593 0.3520       0.6839    0.7919
# 35         jumpgatelob + ofi  100 0.3378 0.3256       0.7390    0.7772
# 36              linvar + ofi  100 0.3552 0.3499       0.6721    0.8066
# 37              logreg + ofi  100 0.3445 0.3356       0.7105    0.7873
# 38            ofsatnet + ofi  100 0.3370 0.3223       0.7577    0.7630
# 39                tlob + ofi  100 0.3529 0.3432       0.6906    0.7737
#
#     capture_bp_win  capture_bp_signal  oracle_bp_win  capture_ratio
# 0           1.7768             3.2974         2.8727         0.6185
# 1           1.7780             3.1268         2.8727         0.6189
# 2           1.8291             3.2714         2.8727         0.6367
# 3           1.5043             2.6091         2.8727         0.5236
# 4           1.7870             3.3548         2.8727         0.6220
# 5           1.7657             3.1674         2.8727         0.6146
# 6           1.7837             3.3007         2.8727         0.6209
# 7           1.7753             3.1604         2.8727         0.6180
# 8           1.7940             3.1587         2.8727         0.6245
# 9           1.7608             3.1880         2.8727         0.6130
# 10          2.5552             3.9931         4.1085         0.6219
# 11          2.4622             3.9376         4.1085         0.5993
# 12          2.5629             4.1680         4.1085         0.6238
# 13          2.0482             3.2295         4.1085         0.4985
# 14          2.5598             4.3395         4.1085         0.6230
# 15          2.4362             4.3538         4.1085         0.5930
# 16          2.5639             4.2835         4.1085         0.6240
# 17          2.5576             4.0457         4.1085         0.6225
# 18          2.6247             3.9604         4.1085         0.6389
# 19          2.4790             4.0120         4.1085         0.6034
# 20          4.0103             6.3876         6.4235         0.6243
# 21          3.7049             5.7388         6.4235         0.5768
# 22          4.1175             6.0525         6.4235         0.6410
# 23          3.6543             4.5081         6.4235         0.5689
# 24          4.0394             6.5906         6.4235         0.6289
# 25          4.0071             6.1701         6.4235         0.6238
# 26          4.1056             6.3062         6.4235         0.6392
# 27          4.1605             6.1460         6.4235         0.6477
# 28          3.6409             7.1102         6.4235         0.5668
# 29          3.9906             5.6212         6.4235         0.6213
# 30          5.3755             8.6535         8.9249         0.6023
# 31          5.0160             7.3611         8.9249         0.5620
# 32          5.5843             7.8724         8.9249         0.6257
# 33          4.3558             6.8247         8.9249         0.4881
# 34          5.5076             8.0528         8.9249         0.6171
# 35          5.6339             7.6240         8.9249         0.6313
# 36          5.6148             8.3537         8.9249         0.6291
# 37          5.5865             7.8630         8.9249         0.6259
# 38          5.5760             7.3590         8.9249         0.6248
# 39          5.2053             7.5377         8.9249         0.5832

# %%
# MCC and capture-ratio pivots (rows = model, cols = horizon)
if not fin_df.empty:
    order = [DISPLAY[m] for m in MODELS if DISPLAY[m] in set(fin_df["model"])]
    for metric in ["mcc", "capture_ratio", "hit_rate"]:
        piv = fin_df.pivot(index="model", columns="k", values=metric).reindex(order)
        print(f"\n=== {metric} (rows=model, cols=horizon k) ===")
        display(piv.style.background_gradient(cmap="YlGn", axis=None).format("{:.4f}"))
# Out:
# === mcc (rows=model, cols=horizon k) ===
# <style type="text/css">
# #T_21ef5_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_21ef5_row0_col1, #T_21ef5_row4_col0 {
#   background-color: #3da559;
#   color: #f1f1f1;
# }
# #T_21ef5_row0_col2, #T_21ef5_row7_col1 {
#   background-color: #79c679;
#   color: #000000;
# }
# #T_21ef5_row0_col3 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_21ef5_row1_col0 {
#   background-color: #005e33;
#   color: #f1f1f1;
# }
# #T_21ef5_row1_col1 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_21ef5_row1_col2 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_21ef5_row1_col3 {
#   background-color: #cfec9e;
#   color: #000000;
# }
# #T_21ef5_row2_col0, #T_21ef5_row5_col0 {
#   background-color: #00512e;
#   color: #f1f1f1;
# }
# #T_21ef5_row2_col1 {
#   background-color: #58b669;
#   color: #f1f1f1;
# }
# #T_21ef5_row2_col2 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_21ef5_row2_col3 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_21ef5_row3_col0 {
#   background-color: #0d733c;
#   color: #f1f1f1;
# }
# #T_21ef5_row3_col1 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_21ef5_row3_col2 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_21ef5_row3_col3 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_21ef5_row4_col1 {
#   background-color: #e3f4aa;
#   color: #000000;
# }
# #T_21ef5_row4_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_21ef5_row4_col3 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_21ef5_row5_col1 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_21ef5_row5_col2 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_21ef5_row5_col3 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_21ef5_row6_col0 {
#   background-color: #076d39;
#   color: #f1f1f1;
# }
# #T_21ef5_row6_col1 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_21ef5_row6_col2 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_21ef5_row6_col3 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_21ef5_row7_col0 {
#   background-color: #197c40;
#   color: #f1f1f1;
# }
# #T_21ef5_row7_col2 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_21ef5_row7_col3 {
#   background-color: #daf0a4;
#   color: #000000;
# }
# #T_21ef5_row8_col0 {
#   background-color: #006234;
#   color: #f1f1f1;
# }
# #T_21ef5_row8_col1 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_21ef5_row8_col2 {
#   background-color: #b9e294;
#   color: #000000;
# }
# #T_21ef5_row8_col3 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_21ef5_row9_col0 {
#   background-color: #005a31;
#   color: #f1f1f1;
# }
# #T_21ef5_row9_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_21ef5_row9_col2 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_21ef5_row9_col3 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# </style>
# <table id="T_21ef5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_21ef5_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_21ef5_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_21ef5_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_21ef5_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21ef5_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_21ef5_row0_col0" class="data row0 col0" >0.5419</td>
#       <td id="T_21ef5_row0_col1" class="data row0 col1" >0.4486</td>
#       <td id="T_21ef5_row0_col2" class="data row0 col2" >0.4108</td>
#       <td id="T_21ef5_row0_col3" class="data row0 col3" >0.3593</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_21ef5_row1_col0" class="data row1 col0" >0.5174</td>
#       <td id="T_21ef5_row1_col1" class="data row1 col1" >0.4065</td>
#       <td id="T_21ef5_row1_col2" class="data row1 col2" >0.3731</td>
#       <td id="T_21ef5_row1_col3" class="data row1 col3" >0.3529</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_21ef5_row2_col0" class="data row2 col0" >0.5301</td>
#       <td id="T_21ef5_row2_col1" class="data row2 col1" >0.4300</td>
#       <td id="T_21ef5_row2_col2" class="data row2 col2" >0.3850</td>
#       <td id="T_21ef5_row2_col3" class="data row2 col3" >0.3636</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_21ef5_row3_col0" class="data row3 col0" >0.4965</td>
#       <td id="T_21ef5_row3_col1" class="data row3 col1" >0.4050</td>
#       <td id="T_21ef5_row3_col2" class="data row3 col2" >0.3622</td>
#       <td id="T_21ef5_row3_col3" class="data row3 col3" >0.3401</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_21ef5_row4_col0" class="data row4 col0" >0.4479</td>
#       <td id="T_21ef5_row4_col1" class="data row4 col1" >0.3350</td>
#       <td id="T_21ef5_row4_col2" class="data row4 col2" >0.2798</td>
#       <td id="T_21ef5_row4_col3" class="data row4 col3" >0.2827</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_21ef5_row5_col0" class="data row5 col0" >0.5306</td>
#       <td id="T_21ef5_row5_col1" class="data row5 col1" >0.4199</td>
#       <td id="T_21ef5_row5_col2" class="data row5 col2" >0.3718</td>
#       <td id="T_21ef5_row5_col3" class="data row5 col3" >0.3508</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_21ef5_row6_col0" class="data row6 col0" >0.5026</td>
#       <td id="T_21ef5_row6_col1" class="data row6 col1" >0.4228</td>
#       <td id="T_21ef5_row6_col2" class="data row6 col2" >0.3929</td>
#       <td id="T_21ef5_row6_col3" class="data row6 col3" >0.3552</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_21ef5_row7_col0" class="data row7 col0" >0.4847</td>
#       <td id="T_21ef5_row7_col1" class="data row7 col1" >0.4098</td>
#       <td id="T_21ef5_row7_col2" class="data row7 col2" >0.3836</td>
#       <td id="T_21ef5_row7_col3" class="data row7 col3" >0.3445</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_21ef5_row8_col0" class="data row8 col0" >0.5150</td>
#       <td id="T_21ef5_row8_col1" class="data row8 col1" >0.4315</td>
#       <td id="T_21ef5_row8_col2" class="data row8 col2" >0.3693</td>
#       <td id="T_21ef5_row8_col3" class="data row8 col3" >0.3378</td>
#     </tr>
#     <tr>
#       <th id="T_21ef5_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_21ef5_row9_col0" class="data row9 col0" >0.5215</td>
#       <td id="T_21ef5_row9_col1" class="data row9 col1" >0.4189</td>
#       <td id="T_21ef5_row9_col2" class="data row9 col2" >0.3852</td>
#       <td id="T_21ef5_row9_col3" class="data row9 col3" >0.3370</td>
#     </tr>
#   </tbody>
# </table>
# === capture_ratio (rows=model, cols=horizon k) ===
# <style type="text/css">
# #T_6d3d1_row0_col0, #T_6d3d1_row5_col1 {
#   background-color: #0a703a;
#   color: #f1f1f1;
# }
# #T_6d3d1_row0_col1 {
#   background-color: #086e3a;
#   color: #f1f1f1;
# }
# #T_6d3d1_row0_col2 {
#   background-color: #006636;
#   color: #f1f1f1;
# }
# #T_6d3d1_row0_col3 {
#   background-color: #13773d;
#   color: #f1f1f1;
# }
# #T_6d3d1_row1_col0 {
#   background-color: #197c40;
#   color: #f1f1f1;
# }
# #T_6d3d1_row1_col1 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_6d3d1_row1_col2, #T_6d3d1_row6_col0 {
#   background-color: #0b713b;
#   color: #f1f1f1;
# }
# #T_6d3d1_row1_col3 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_6d3d1_row2_col0 {
#   background-color: #005830;
#   color: #f1f1f1;
# }
# #T_6d3d1_row2_col1, #T_6d3d1_row8_col2 {
#   background-color: #076d39;
#   color: #f1f1f1;
# }
# #T_6d3d1_row2_col2 {
#   background-color: #00502d;
#   color: #f1f1f1;
# }
# #T_6d3d1_row2_col3 {
#   background-color: #036b38;
#   color: #f1f1f1;
# }
# #T_6d3d1_row3_col0, #T_6d3d1_row5_col0 {
#   background-color: #10743c;
#   color: #f1f1f1;
# }
# #T_6d3d1_row3_col1 {
#   background-color: #2f944e;
#   color: #f1f1f1;
# }
# #T_6d3d1_row3_col2 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_6d3d1_row3_col3 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_6d3d1_row4_col0 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_6d3d1_row4_col1 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_6d3d1_row4_col2 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_6d3d1_row4_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6d3d1_row5_col2, #T_6d3d1_row6_col1, #T_6d3d1_row9_col0 {
#   background-color: #066d39;
#   color: #f1f1f1;
# }
# #T_6d3d1_row5_col3 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_6d3d1_row6_col2 {
#   background-color: #00532f;
#   color: #f1f1f1;
# }
# #T_6d3d1_row6_col3 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_6d3d1_row7_col0 {
#   background-color: #11753d;
#   color: #f1f1f1;
# }
# #T_6d3d1_row7_col1 {
#   background-color: #096f3a;
#   color: #f1f1f1;
# }
# #T_6d3d1_row7_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_6d3d1_row7_col3 {
#   background-color: #026a38;
#   color: #f1f1f1;
# }
# #T_6d3d1_row8_col0 {
#   background-color: #167a3f;
#   color: #f1f1f1;
# }
# #T_6d3d1_row8_col1 {
#   background-color: #39a056;
#   color: #f1f1f1;
# }
# #T_6d3d1_row8_col3 {
#   background-color: #006234;
#   color: #f1f1f1;
# }
# #T_6d3d1_row9_col1 {
#   background-color: #00542f;
#   color: #f1f1f1;
# }
# #T_6d3d1_row9_col2 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_6d3d1_row9_col3 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6d3d1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_6d3d1_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_6d3d1_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_6d3d1_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_6d3d1_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d3d1_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_6d3d1_row0_col0" class="data row0 col0" >0.6220</td>
#       <td id="T_6d3d1_row0_col1" class="data row0 col1" >0.6230</td>
#       <td id="T_6d3d1_row0_col2" class="data row0 col2" >0.6289</td>
#       <td id="T_6d3d1_row0_col3" class="data row0 col3" >0.6171</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_6d3d1_row1_col0" class="data row1 col0" >0.6130</td>
#       <td id="T_6d3d1_row1_col1" class="data row1 col1" >0.6034</td>
#       <td id="T_6d3d1_row1_col2" class="data row1 col2" >0.6213</td>
#       <td id="T_6d3d1_row1_col3" class="data row1 col3" >0.5832</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_6d3d1_row2_col0" class="data row2 col0" >0.6367</td>
#       <td id="T_6d3d1_row2_col1" class="data row2 col1" >0.6238</td>
#       <td id="T_6d3d1_row2_col2" class="data row2 col2" >0.6410</td>
#       <td id="T_6d3d1_row2_col3" class="data row2 col3" >0.6257</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_6d3d1_row3_col0" class="data row3 col0" >0.6189</td>
#       <td id="T_6d3d1_row3_col1" class="data row3 col1" >0.5993</td>
#       <td id="T_6d3d1_row3_col2" class="data row3 col2" >0.5768</td>
#       <td id="T_6d3d1_row3_col3" class="data row3 col3" >0.5620</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_6d3d1_row4_col0" class="data row4 col0" >0.5236</td>
#       <td id="T_6d3d1_row4_col1" class="data row4 col1" >0.4985</td>
#       <td id="T_6d3d1_row4_col2" class="data row4 col2" >0.5689</td>
#       <td id="T_6d3d1_row4_col3" class="data row4 col3" >0.4881</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_6d3d1_row5_col0" class="data row5 col0" >0.6185</td>
#       <td id="T_6d3d1_row5_col1" class="data row5 col1" >0.6219</td>
#       <td id="T_6d3d1_row5_col2" class="data row5 col2" >0.6243</td>
#       <td id="T_6d3d1_row5_col3" class="data row5 col3" >0.6023</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_6d3d1_row6_col0" class="data row6 col0" >0.6209</td>
#       <td id="T_6d3d1_row6_col1" class="data row6 col1" >0.6240</td>
#       <td id="T_6d3d1_row6_col2" class="data row6 col2" >0.6392</td>
#       <td id="T_6d3d1_row6_col3" class="data row6 col3" >0.6291</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_6d3d1_row7_col0" class="data row7 col0" >0.6180</td>
#       <td id="T_6d3d1_row7_col1" class="data row7 col1" >0.6225</td>
#       <td id="T_6d3d1_row7_col2" class="data row7 col2" >0.6477</td>
#       <td id="T_6d3d1_row7_col3" class="data row7 col3" >0.6259</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_6d3d1_row8_col0" class="data row8 col0" >0.6146</td>
#       <td id="T_6d3d1_row8_col1" class="data row8 col1" >0.5930</td>
#       <td id="T_6d3d1_row8_col2" class="data row8 col2" >0.6238</td>
#       <td id="T_6d3d1_row8_col3" class="data row8 col3" >0.6313</td>
#     </tr>
#     <tr>
#       <th id="T_6d3d1_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_6d3d1_row9_col0" class="data row9 col0" >0.6245</td>
#       <td id="T_6d3d1_row9_col1" class="data row9 col1" >0.6389</td>
#       <td id="T_6d3d1_row9_col2" class="data row9 col2" >0.5668</td>
#       <td id="T_6d3d1_row9_col3" class="data row9 col3" >0.6248</td>
#     </tr>
#   </tbody>
# </table>
# === hit_rate (rows=model, cols=horizon k) ===
# <style type="text/css">
# #T_d14aa_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_d14aa_row0_col1 {
#   background-color: #177b3f;
#   color: #f1f1f1;
# }
# #T_d14aa_row0_col2 {
#   background-color: #076d39;
#   color: #f1f1f1;
# }
# #T_d14aa_row0_col3 {
#   background-color: #58b669;
#   color: #f1f1f1;
# }
# #T_d14aa_row1_col0 {
#   background-color: #096f3a;
#   color: #f1f1f1;
# }
# #T_d14aa_row1_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_d14aa_row1_col2 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_d14aa_row1_col3 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_d14aa_row2_col0 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_d14aa_row2_col1 {
#   background-color: #288a47;
#   color: #f1f1f1;
# }
# #T_d14aa_row2_col2 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_d14aa_row2_col3, #T_d14aa_row5_col1 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_d14aa_row3_col0, #T_d14aa_row7_col0 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_d14aa_row3_col1 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_d14aa_row3_col2 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_d14aa_row3_col3 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_d14aa_row4_col0 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_d14aa_row4_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_d14aa_row4_col2 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_d14aa_row4_col3 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_d14aa_row5_col0 {
#   background-color: #005f34;
#   color: #f1f1f1;
# }
# #T_d14aa_row5_col2 {
#   background-color: #369d54;
#   color: #f1f1f1;
# }
# #T_d14aa_row5_col3 {
#   background-color: #208242;
#   color: #f1f1f1;
# }
# #T_d14aa_row6_col0, #T_d14aa_row9_col0 {
#   background-color: #0a703a;
#   color: #f1f1f1;
# }
# #T_d14aa_row6_col1 {
#   background-color: #1d7f41;
#   color: #f1f1f1;
# }
# #T_d14aa_row6_col2 {
#   background-color: #258745;
#   color: #f1f1f1;
# }
# #T_d14aa_row6_col3 {
#   background-color: #2f944e;
#   color: #f1f1f1;
# }
# #T_d14aa_row7_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_d14aa_row7_col2 {
#   background-color: #2d914b;
#   color: #f1f1f1;
# }
# #T_d14aa_row7_col3 {
#   background-color: #68be71;
#   color: #000000;
# }
# #T_d14aa_row8_col0 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_d14aa_row8_col1 {
#   background-color: #30954f;
#   color: #f1f1f1;
# }
# #T_d14aa_row8_col2 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_d14aa_row8_col3 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_d14aa_row9_col1 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_d14aa_row9_col2 {
#   background-color: #14783e;
#   color: #f1f1f1;
# }
# #T_d14aa_row9_col3 {
#   background-color: #bde496;
#   color: #000000;
# }
# </style>
# <table id="T_d14aa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_d14aa_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_d14aa_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_d14aa_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_d14aa_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d14aa_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_d14aa_row0_col0" class="data row0 col0" >0.8428</td>
#       <td id="T_d14aa_row0_col1" class="data row0 col1" >0.8181</td>
#       <td id="T_d14aa_row0_col2" class="data row0 col2" >0.8247</td>
#       <td id="T_d14aa_row0_col3" class="data row0 col3" >0.7919</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_d14aa_row1_col0" class="data row1 col0" >0.8238</td>
#       <td id="T_d14aa_row1_col1" class="data row1 col1" >0.7867</td>
#       <td id="T_d14aa_row1_col2" class="data row1 col2" >0.7778</td>
#       <td id="T_d14aa_row1_col3" class="data row1 col3" >0.7737</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_d14aa_row2_col0" class="data row2 col0" >0.8292</td>
#       <td id="T_d14aa_row2_col1" class="data row2 col1" >0.8104</td>
#       <td id="T_d14aa_row2_col2" class="data row2 col2" >0.7981</td>
#       <td id="T_d14aa_row2_col3" class="data row2 col3" >0.7885</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_d14aa_row3_col0" class="data row3 col0" >0.8090</td>
#       <td id="T_d14aa_row3_col1" class="data row3 col1" >0.7802</td>
#       <td id="T_d14aa_row3_col2" class="data row3 col2" >0.7699</td>
#       <td id="T_d14aa_row3_col3" class="data row3 col3" >0.7581</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_d14aa_row4_col0" class="data row4 col0" >0.7396</td>
#       <td id="T_d14aa_row4_col1" class="data row4 col1" >0.7234</td>
#       <td id="T_d14aa_row4_col2" class="data row4 col2" >0.7260</td>
#       <td id="T_d14aa_row4_col3" class="data row4 col3" >0.7478</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_d14aa_row5_col0" class="data row5 col0" >0.8313</td>
#       <td id="T_d14aa_row5_col1" class="data row5 col1" >0.7886</td>
#       <td id="T_d14aa_row5_col2" class="data row5 col2" >0.8034</td>
#       <td id="T_d14aa_row5_col3" class="data row5 col3" >0.8140</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_d14aa_row6_col0" class="data row6 col0" >0.8235</td>
#       <td id="T_d14aa_row6_col1" class="data row6 col1" >0.8154</td>
#       <td id="T_d14aa_row6_col2" class="data row6 col2" >0.8120</td>
#       <td id="T_d14aa_row6_col3" class="data row6 col3" >0.8066</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_d14aa_row7_col0" class="data row7 col0" >0.8091</td>
#       <td id="T_d14aa_row7_col1" class="data row7 col1" >0.7968</td>
#       <td id="T_d14aa_row7_col2" class="data row7 col2" >0.8079</td>
#       <td id="T_d14aa_row7_col3" class="data row7 col3" >0.7873</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_d14aa_row8_col0" class="data row8 col0" >0.8166</td>
#       <td id="T_d14aa_row8_col1" class="data row8 col1" >0.8060</td>
#       <td id="T_d14aa_row8_col2" class="data row8 col2" >0.7937</td>
#       <td id="T_d14aa_row8_col3" class="data row8 col3" >0.7772</td>
#     </tr>
#     <tr>
#       <th id="T_d14aa_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_d14aa_row9_col0" class="data row9 col0" >0.8237</td>
#       <td id="T_d14aa_row9_col1" class="data row9 col1" >0.7950</td>
#       <td id="T_d14aa_row9_col2" class="data row9 col2" >0.8192</td>
#       <td id="T_d14aa_row9_col3" class="data row9 col3" >0.7630</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Mid-price path vs model predictions
#
# The mid-price over the most active stretch of the test period, with **true**
# up/down regimes shaded (green = up, red = down, white = flat). Each strip below is
# one model's predicted label over the same windows — you can see directly *where*
# each model catches or misses the moves. Change `seg_len`/`start` to zoom.

# %%
LAB_CMAP = ListedColormap(["#d62728", "#e8e8e8", "#2ca02c"])  # down / flat / up


def plot_price_predictions(k, seg_len=600, start=None):
    tags = [t for t in MODELS if (t, k) in RESULTS]
    m = META.get(k)
    if not tags or m is None:
        return
    y_true = RESULTS[(tags[0], k)]["y_true"]
    tr = np.nan_to_num(m["trend"])
    seg_len = min(seg_len, len(y_true))
    if start is None:  # auto-pick the stretch with the most |trend| mass
        act = np.convolve(np.abs(tr), np.ones(seg_len), "valid")
        start = int(act.argmax())
    sl = slice(start, start + seg_len)
    idx = np.arange(start, start + seg_len)
    price = m["mid"][m["centres"][sl]]
    yt_seg = y_true[sl]

    lanes = [("true", yt_seg)] + [
        (DISPLAY[t], RESULTS[(t, k)]["y_pred"][sl]) for t in tags
    ]
    fig, axes = plt.subplots(
        1 + len(lanes),
        1,
        figsize=(12, 3.4 + 0.42 * len(lanes)),
        sharex=True,
        gridspec_kw={"height_ratios": [7] + [1] * len(lanes)},
    )
    ax = axes[0]
    ax.plot(idx, price, lw=0.9, color="black")
    lo, hi = price.min(), price.max()
    pad = 0.03 * (hi - lo + 1e-9)
    ax.fill_between(
        idx,
        lo - pad,
        hi + pad,
        where=yt_seg == 2,
        color="#2ca02c",
        alpha=0.14,
        step="mid",
    )
    ax.fill_between(
        idx,
        lo - pad,
        hi + pad,
        where=yt_seg == 0,
        color="#d62728",
        alpha=0.14,
        step="mid",
    )
    ax.set_ylim(lo - pad, hi + pad)
    ax.set_ylabel("mid")
    ax.set_title(
        f"Mid price with true up/down regimes vs predictions — "
        f"k={k}, windows {start}–{start + seg_len}"
    )
    for axl, (name, lab) in zip(axes[1:], lanes):
        axl.imshow(
            lab[None, :],
            aspect="auto",
            cmap=LAB_CMAP,
            vmin=0,
            vmax=2,
            extent=[idx[0], idx[-1], 0, 1],
            interpolation="nearest",
        )
        axl.set_yticks([])
        axl.set_ylabel(name, rotation=0, ha="right", va="center", fontsize=7)
    axes[-1].set_xlabel("test window (time order)")
    fig.tight_layout(h_pad=0.15)
    plt.show()


for k in HORIZONS:
    plot_price_predictions(k)

# %%
def plot_capture(k):
    tags = [t for t in MODELS if (t, k) in RESULTS]
    m = META.get(k)
    if not tags or m is None:
        return
    tr = np.nan_to_num(m["trend"])
    cmap = plt.get_cmap("tab10")
    fig, ax = plt.subplots(figsize=(10, 4))
    for i, tag in enumerate(tags):
        cap = _positions(RESULTS[(tag, k)]["y_pred"]) * tr
        ax.plot(np.cumsum(cap) * 1e4, color=cmap(i % 10), lw=1.1, label=DISPLAY[tag])
    ax.plot(
        np.cumsum(np.abs(tr)) * 1e4,
        "k--",
        lw=1.0,
        alpha=0.6,
        label="oracle (always right)",
    )
    ax.axhline(0, color="grey", lw=0.6)
    ax.set_xlabel("test window (time order)")
    ax.set_ylabel("cumulative captured trend (bp)")
    ax.set_title(
        f"Cumulative directional capture — k={k} (cost-free, no trading costs)"
    )
    ax.grid(alpha=0.3)
    ax.legend(fontsize=8)
    fig.tight_layout()
    plt.show()


for k in HORIZONS:
    plot_capture(k)

# %% [markdown]
# ### Calibration & confidence gating
#
# Left — reliability: mean accuracy per confidence decile vs the diagonal (a
# calibrated model can be *sized* by its probability). Middle/right — trade only when
# `p_max ≥ τ` **and** the call is directional: per-signal hit rate and capture (bp) as
# the confidence gate tightens. A model whose hit rate and capture rise with τ gives a
# usable filter for the later trading simulation.

# %%
def plot_calibration_gating(k, n_bins=10):
    tags = [t for t in MODELS if (t, k) in RESULTS]
    m = META.get(k)
    if not tags or m is None:
        return
    tr = np.nan_to_num(m["trend"])
    taus = np.linspace(0.34, 0.90, 15)
    cmap = plt.get_cmap("tab10")
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    for i, tag in enumerate(tags):
        r = RESULTS[(tag, k)]
        conf = r["probs"].max(1)
        correct = (r["y_true"] == r["y_pred"]).astype(float)
        edges = np.quantile(conf, np.linspace(0, 1, n_bins + 1))
        edges[-1] += 1e-9
        bi = np.clip(np.digitize(conf, edges) - 1, 0, n_bins - 1)
        xs = [
            conf[bi == b].mean() if (bi == b).any() else np.nan for b in range(n_bins)
        ]
        ys = [
            correct[bi == b].mean() if (bi == b).any() else np.nan
            for b in range(n_bins)
        ]
        axes[0].plot(xs, ys, "o-", ms=3, color=cmap(i % 10), label=DISPLAY[tag])
        pos = _positions(r["y_pred"])
        hit, cap = [], []
        for tau in taus:
            sel = (pos != 0) & (conf >= tau)
            hit.append((np.sign(tr[sel]) == pos[sel]).mean() if sel.any() else np.nan)
            cap.append((pos[sel] * tr[sel]).mean() * 1e4 if sel.any() else np.nan)
        axes[1].plot(taus, hit, "o-", ms=3, color=cmap(i % 10))
        axes[2].plot(taus, cap, "o-", ms=3, color=cmap(i % 10))
    axes[0].plot([1 / 3, 1], [1 / 3, 1], "k--", lw=0.8, alpha=0.6)
    axes[0].set_xlabel("mean confidence (p_max)")
    axes[0].set_ylabel("accuracy")
    axes[0].set_title(f"Reliability — k={k}")
    axes[0].legend(fontsize=7)
    axes[1].set_xlabel("confidence threshold τ")
    axes[1].set_ylabel("directional hit rate")
    axes[1].set_title("Hit rate vs confidence gate")
    axes[2].set_xlabel("confidence threshold τ")
    axes[2].set_ylabel("capture per signal (bp)")
    axes[2].set_title("Per-signal capture vs confidence gate")
    for ax in axes:
        ax.grid(alpha=0.3)
    fig.tight_layout()
    plt.show()


for k in HORIZONS:
    plot_calibration_gating(k)

# %% [markdown]
# ## 7c. Robustness under injected input noise
#
# The headline metrics average over a test set that is mostly *calm*, which dilutes the
# one thing the diffusion models were built for. Here we test that property directly:
# take **clean** test windows and inject increasing noise ourselves, identically for every
# model, then watch how macro-F1 falls off.
#
# Four corruptions, all at overall scale `σ` (features are z-scored, so `σ≈1` is heavy):
# - **gaussian** — `x + σ·ξ` (light-tailed baseline).
# - **jump** — the JumpGateLOB training kernel: a Gaussian scale mixture `x + √W·ξ`,
#   `W = σ² + Σ Gamma jumps`, `N ~ Poisson(σ)` (discrete, jump-like).
# - **student_t** — heavy-tailed `x + σ·t_ν` (Student-t, ν=3, standardised to unit
#   variance). This is **neither** diffusion model's training kernel, so it is the
#   fairest *unseen heavy-tail* stress test.
# - **alpha_stable** — the AlphaStableLOB training kernel: subordinated-Gaussian
#   α-stable `x + √W·ξ`, `W = σ²·A`, `A ~ PositiveStable(α/2)` (α=1.7, clipped) —
#   genuine power-law tails.
#
# The claim to test: JumpGateLOB / AlphaStableLOB curves should stay **flatter** as `σ`
# grows, even if they start lower at `σ=0` — most tellingly under `student_t` (unseen by
# both) and each model's own kernel (`jump` / `alpha_stable`). **Fair-test caveat:** the
# diffusion models trained on heavy-tailed kernels while DLA/CTABL/DeepLOB never saw
# injected noise, so a win here is real *robustness to input corruption* but partly a
# training-augmentation effect — read it as "does corruption-aware training buy deployment
# robustness," not "is the architecture inherently better."

# %%
from torch.utils.data import Subset  # noqa: E402

# --- noise sweep config (reduce ROBUST_N / ROBUST_SIGMAS if too slow) ---------
ROBUST_N = 2500  # test windows subsampled
ROBUST_SIGMAS = [0.0, 0.15, 0.3, 0.5, 0.75, 1.0]  # overall noise scale σ
ROBUST_KINDS = ["gaussian", "jump", "student_t", "alpha_stable"]
SIGMA_FOCUS = 0.5  # σ at which calibration / probs are inspected
JUMP = {"rate": 1.0, "shape": 1.0, "scale": 1.0}  # JumpGateLOB levy kernel
STUDENT_NU = 3.0  # Student-t degrees of freedom (heavier as ν→2); var = ν/(ν-2)
ASTABLE_ALPHA = 1.7  # α-stable stability index (α<2 ⇒ power-law tails)
ASTABLE_CLIP_Q = 0.999  # clip the (infinite-mean) subordinator for stability


def perturb(x, sigma, kind, seed):
    """Deterministic input corruption (identical across models given the seed).

    gaussian     — x + σ·ξ                       (light-tailed baseline)
    jump         — x + √W·ξ, W=σ²+ΣGamma jumps   (JumpGateLOB kernel; discrete)
    student_t    — x + σ·t_ν  (ν=3, unit-var)    (heavy-tailed; *neither* kernel)
    alpha_stable — x + √W·ξ, W=σ²·A, A~S⁺_{α/2}  (AlphaStableLOB kernel; power-law)
    """
    torch.manual_seed(seed)  # reproducible randn + _standard_gamma
    eps = torch.randn_like(x)
    if sigma == 0.0 or kind == "gaussian":
        return x + sigma * eps
    v = (-1,) + (1,) * (x.dim() - 1)

    if kind == "jump":
        b = x.shape[0]
        W = torch.full((b,), sigma * sigma)
        N = torch.poisson(torch.full((b,), JUMP["rate"] * sigma))
        m = N > 0
        if m.any():
            W = W.clone()
            W[m] = W[m] + torch._standard_gamma(N[m] * JUMP["shape"]) * JUMP["scale"]
        return x + W.sqrt().view(v) * eps

    if kind == "student_t":
        # standardised Student-t (unit variance for ν>2) → comparable to gaussian σ
        chi2 = torch._standard_gamma(torch.full_like(x, STUDENT_NU / 2.0)) * 2.0
        t = eps / (chi2 / STUDENT_NU).sqrt()
        t = t * ((STUDENT_NU - 2.0) / STUDENT_NU) ** 0.5
        return x + sigma * t

    if kind == "alpha_stable":
        # positive (β=α/2)-stable subordinator A via Kanter (1975); W = σ²·A
        b = x.shape[0]
        beta = ASTABLE_ALPHA / 2.0
        U = torch.rand(b).clamp(1e-7, 1 - 1e-7) * float(np.pi)
        E = (-torch.log(torch.rand(b).clamp_min(1e-12))).clamp_min(1e-12)
        t1 = torch.sin(beta * U) / torch.sin(U).clamp_min(1e-12).pow(1.0 / beta)
        t2 = (torch.sin((1 - beta) * U) / E).clamp_min(1e-30).pow((1 - beta) / beta)
        A = (t1 * t2).clamp_min(1e-12)
        A = A.clamp_max(torch.quantile(A, ASTABLE_CLIP_Q))
        W = (sigma * sigma) * A
        return x + W.sqrt().view(v) * eps

    raise ValueError(f"unknown kind {kind!r}")


@torch.no_grad()
def run_robust_sweep():
    """macro-F1 vs σ for every (model, horizon, kind); stash probs at SIGMA_FOCUS."""
    rows, probs = [], {}
    for k in HORIZONS:
        try:
            test_ds, _, _ = test_set(k)
        except Exception as e:
            print(f"  k={k}: no test set ({e}) — skipped")
            continue
        rng = np.random.default_rng(k)
        idx = np.sort(
            rng.choice(len(test_ds), min(ROBUST_N, len(test_ds)), replace=False)
        )
        sub = Subset(test_ds, idx.tolist())
        for tag in MODELS:
            path = CHECKPOINTS.get(tag, {}).get(k)
            if not path or not Path(path).exists():
                continue
            model = build_model(tag, load_ckpt(path))
            for kind in ROBUST_KINDS:
                loader = DataLoader(sub, batch_size=BATCH, shuffle=False)
                for sig in ROBUST_SIGMAS:
                    yt, yp, prc = [], [], []
                    for bi, b in enumerate(loader):
                        x = b["x"].float()
                        seed = (
                            int(sig * 1000) + bi * 7 + ROBUST_KINDS.index(kind) * 100003
                        )
                        xp = perturb(x, sig, kind, seed)
                        logits = model.predict({"x": xp, "label": b["label"]}, DEVICE)
                        yp.append(logits.argmax(1).cpu().numpy())
                        yt.append(b["label"].numpy())
                        if kind == "jump" and abs(sig - SIGMA_FOCUS) < 1e-9:
                            prc.append(Fn.softmax(logits, 1).cpu().numpy())
                    yt, yp = np.concatenate(yt), np.concatenate(yp)
                    rows.append(
                        {
                            "model": DISPLAY[tag],
                            "k": k,
                            "kind": kind,
                            "sigma": sig,
                            "macro_f1": f1_score(
                                yt,
                                yp,
                                average="macro",
                                labels=[0, 1, 2],
                                zero_division=0,
                            ),
                        }
                    )
                    if prc:
                        probs[(tag, k)] = (yt, yp, np.concatenate(prc))
            del model
            if DEVICE.type == "cuda":
                torch.cuda.empty_cache()
        n_k = len({r["model"] for r in rows if r["k"] == k})
        print(f"  k={k}: swept {n_k} models")
    return pd.DataFrame(rows), probs


print(
    f"running noise sweep — {ROBUST_N} windows × {len(ROBUST_SIGMAS)} σ × "
    f"{len(ROBUST_KINDS)} kinds (gaussian/jump/student_t/alpha_stable)…"
)
robust_df, ROBUST_PROBS = run_robust_sweep()
print(f"done — {len(robust_df)} rows")
robust_df.head()
# Out:
# running noise sweep — 2500 windows × 6 σ × 4 kinds (gaussian/jump/student_t/alpha_stable)…
#   k=10: swept 10 models
#   k=20: swept 10 models
#   k=50: swept 10 models
#   k=100: swept 10 models
# done — 960 rows
#        model   k      kind  sigma  macro_f1
# 0  dla + ofi  10  gaussian 0.0000    0.6852
# 1  dla + ofi  10  gaussian 0.1500    0.6116
# 2  dla + ofi  10  gaussian 0.3000    0.5270
# 3  dla + ofi  10  gaussian 0.5000    0.4606
# 4  dla + ofi  10  gaussian 0.7500    0.4163

# %%
# macro-F1 vs injected noise σ — one figure per horizon, one panel per noise kind
def plot_robust_sweep(k):
    if robust_df.empty or "k" not in robust_df.columns:
        return
    sub = robust_df[robust_df["k"] == k]
    if sub.empty:
        return
    cmap = plt.get_cmap("tab10")
    present = [DISPLAY[m] for m in MODELS if DISPLAY[m] in set(sub["model"])]
    n = len(ROBUST_KINDS)
    fig, axes = plt.subplots(1, n, figsize=(3.6 * n, 4.4), sharey=True)
    axes = np.atleast_1d(axes)
    for ax, kind in zip(axes, ROBUST_KINDS):
        d = sub[sub["kind"] == kind]
        for i, name in enumerate(present):
            m = d[d["model"] == name].sort_values("sigma")
            ax.plot(
                m["sigma"], m["macro_f1"], "o-", ms=4, color=cmap(i % 10), label=name
            )
        ax.set_xlabel("injected noise σ")
        ax.set_title(f"{kind} corruption")
        ax.grid(alpha=0.3)
    axes[0].set_ylabel("macro-F1")
    axes[-1].legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)
    fig.suptitle(
        f"Robustness to injected input noise — horizon k={k} (flatter = more robust)",
        y=1.03,
    )
    fig.tight_layout()
    plt.show()


for k in HORIZONS:
    plot_robust_sweep(k)

# retention = F1(σ_max)/F1(0) per corruption (mean over horizons); higher = more robust
if not robust_df.empty:
    hi = robust_df["sigma"].max()
    base = (
        robust_df[robust_df["sigma"] == 0.0]
        .groupby(["model", "kind"])["macro_f1"]
        .mean()
    )
    top = (
        robust_df[robust_df["sigma"] == hi]
        .groupby(["model", "kind"])["macro_f1"]
        .mean()
    )
    ret = (top / base.clip(lower=1e-9)).rename("retention").reset_index()
    order = [DISPLAY[m] for m in MODELS if DISPLAY[m] in set(ret["model"])]
    piv = ret.pivot(index="model", columns="kind", values="retention").reindex(order)
    piv = piv[[k for k in ROBUST_KINDS if k in piv.columns]]
    piv["mean"] = piv.mean(axis=1)
    print(
        f"\nRetention  F1(σ={hi})/F1(0)  by corruption, mean over horizons "
        f"(higher = more robust):"
    )
    display(
        piv.sort_values("mean", ascending=False)
        .style.background_gradient(cmap="YlGn", axis=None)
        .format("{:.3f}")
    )
# Out:
# Retention  F1(σ=1.0)/F1(0)  by corruption, mean over horizons (higher = more robust):
# <style type="text/css">
# #T_543d2_row0_col0 {
#   background-color: #00482a;
#   color: #f1f1f1;
# }
# #T_543d2_row0_col1 {
#   background-color: #006435;
#   color: #f1f1f1;
# }
# #T_543d2_row0_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_543d2_row0_col3 {
#   background-color: #00532f;
#   color: #f1f1f1;
# }
# #T_543d2_row0_col4 {
#   background-color: #00512e;
#   color: #f1f1f1;
# }
# #T_543d2_row1_col0 {
#   background-color: #1f8142;
#   color: #f1f1f1;
# }
# #T_543d2_row1_col1 {
#   background-color: #3ba358;
#   color: #f1f1f1;
# }
# #T_543d2_row1_col2 {
#   background-color: #1d7f41;
#   color: #f1f1f1;
# }
# #T_543d2_row1_col3 {
#   background-color: #238443;
#   color: #f1f1f1;
# }
# #T_543d2_row1_col4 {
#   background-color: #278946;
#   color: #f1f1f1;
# }
# #T_543d2_row2_col0 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_543d2_row2_col1 {
#   background-color: #58b669;
#   color: #f1f1f1;
# }
# #T_543d2_row2_col2 {
#   background-color: #2f934d;
#   color: #f1f1f1;
# }
# #T_543d2_row2_col3 {
#   background-color: #3da559;
#   color: #f1f1f1;
# }
# #T_543d2_row2_col4 {
#   background-color: #3ca458;
#   color: #f1f1f1;
# }
# #T_543d2_row3_col0 {
#   background-color: #349a52;
#   color: #f1f1f1;
# }
# #T_543d2_row3_col1 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_543d2_row3_col2 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_543d2_row3_col3, #T_543d2_row3_col4, #T_543d2_row4_col2 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_543d2_row4_col0 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_543d2_row4_col1 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_543d2_row4_col3 {
#   background-color: #4fb264;
#   color: #f1f1f1;
# }
# #T_543d2_row4_col4 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_543d2_row5_col0, #T_543d2_row5_col4 {
#   background-color: #68be71;
#   color: #000000;
# }
# #T_543d2_row5_col1 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_543d2_row5_col2 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_543d2_row5_col3, #T_543d2_row6_col0 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_543d2_row6_col1, #T_543d2_row7_col2 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_543d2_row6_col2 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_543d2_row6_col3 {
#   background-color: #70c275;
#   color: #000000;
# }
# #T_543d2_row6_col4 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_543d2_row7_col0 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_543d2_row7_col1 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_543d2_row7_col3, #T_543d2_row7_col4, #T_543d2_row8_col4 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_543d2_row8_col0 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_543d2_row8_col1 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_543d2_row8_col2 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_543d2_row8_col3 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_543d2_row9_col0 {
#   background-color: #fdfeda;
#   color: #000000;
# }
# #T_543d2_row9_col1, #T_543d2_row9_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_543d2_row9_col3 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_543d2_row9_col4 {
#   background-color: #feffde;
#   color: #000000;
# }
# </style>
# <table id="T_543d2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >kind</th>
#       <th id="T_543d2_level0_col0" class="col_heading level0 col0" >gaussian</th>
#       <th id="T_543d2_level0_col1" class="col_heading level0 col1" >jump</th>
#       <th id="T_543d2_level0_col2" class="col_heading level0 col2" >student_t</th>
#       <th id="T_543d2_level0_col3" class="col_heading level0 col3" >alpha_stable</th>
#       <th id="T_543d2_level0_col4" class="col_heading level0 col4" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_543d2_level0_row0" class="row_heading level0 row0" >jumpgatelob + ofi</th>
#       <td id="T_543d2_row0_col0" class="data row0 col0" >0.886</td>
#       <td id="T_543d2_row0_col1" class="data row0 col1" >0.841</td>
#       <td id="T_543d2_row0_col2" class="data row0 col2" >0.893</td>
#       <td id="T_543d2_row0_col3" class="data row0 col3" >0.868</td>
#       <td id="T_543d2_row0_col4" class="data row0 col4" >0.872</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row1" class="row_heading level0 row1" >logreg + ofi</th>
#       <td id="T_543d2_row1_col0" class="data row1 col0" >0.783</td>
#       <td id="T_543d2_row1_col1" class="data row1 col1" >0.729</td>
#       <td id="T_543d2_row1_col2" class="data row1 col2" >0.785</td>
#       <td id="T_543d2_row1_col3" class="data row1 col3" >0.774</td>
#       <td id="T_543d2_row1_col4" class="data row1 col4" >0.768</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_543d2_row2_col0" class="data row2 col0" >0.734</td>
#       <td id="T_543d2_row2_col1" class="data row2 col1" >0.692</td>
#       <td id="T_543d2_row2_col2" class="data row2 col2" >0.753</td>
#       <td id="T_543d2_row2_col3" class="data row2 col3" >0.725</td>
#       <td id="T_543d2_row2_col4" class="data row2 col4" >0.726</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row3" class="row_heading level0 row3" >linvar + ofi</th>
#       <td id="T_543d2_row3_col0" class="data row3 col0" >0.741</td>
#       <td id="T_543d2_row3_col1" class="data row3 col1" >0.685</td>
#       <td id="T_543d2_row3_col2" class="data row3 col2" >0.735</td>
#       <td id="T_543d2_row3_col3" class="data row3 col3" >0.719</td>
#       <td id="T_543d2_row3_col4" class="data row3 col4" >0.720</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row4" class="row_heading level0 row4" >alphastablelob_1.5 + ofi</th>
#       <td id="T_543d2_row4_col0" class="data row4 col0" >0.704</td>
#       <td id="T_543d2_row4_col1" class="data row4 col1" >0.653</td>
#       <td id="T_543d2_row4_col2" class="data row4 col2" >0.720</td>
#       <td id="T_543d2_row4_col3" class="data row4 col3" >0.702</td>
#       <td id="T_543d2_row4_col4" class="data row4 col4" >0.695</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row5" class="row_heading level0 row5" >ofsatnet + ofi</th>
#       <td id="T_543d2_row5_col0" class="data row5 col0" >0.675</td>
#       <td id="T_543d2_row5_col1" class="data row5 col1" >0.640</td>
#       <td id="T_543d2_row5_col2" class="data row5 col2" >0.712</td>
#       <td id="T_543d2_row5_col3" class="data row5 col3" >0.673</td>
#       <td id="T_543d2_row5_col4" class="data row5 col4" >0.675</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row6" class="row_heading level0 row6" >dla + ofi</th>
#       <td id="T_543d2_row6_col0" class="data row6 col0" >0.673</td>
#       <td id="T_543d2_row6_col1" class="data row6 col1" >0.628</td>
#       <td id="T_543d2_row6_col2" class="data row6 col2" >0.686</td>
#       <td id="T_543d2_row6_col3" class="data row6 col3" >0.666</td>
#       <td id="T_543d2_row6_col4" class="data row6 col4" >0.663</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row7" class="row_heading level0 row7" >tlob + ofi</th>
#       <td id="T_543d2_row7_col0" class="data row7 col0" >0.611</td>
#       <td id="T_543d2_row7_col1" class="data row7 col1" >0.580</td>
#       <td id="T_543d2_row7_col2" class="data row7 col2" >0.628</td>
#       <td id="T_543d2_row7_col3" class="data row7 col3" >0.606</td>
#       <td id="T_543d2_row7_col4" class="data row7 col4" >0.606</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row8" class="row_heading level0 row8" >binctabl + ofi</th>
#       <td id="T_543d2_row8_col0" class="data row8 col0" >0.608</td>
#       <td id="T_543d2_row8_col1" class="data row8 col1" >0.574</td>
#       <td id="T_543d2_row8_col2" class="data row8 col2" >0.631</td>
#       <td id="T_543d2_row8_col3" class="data row8 col3" >0.610</td>
#       <td id="T_543d2_row8_col4" class="data row8 col4" >0.606</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row9" c

# %% [markdown]
# ### Calibration under noise
#
# Reliability curves computed on **jump-corrupted** inputs (`σ = SIGMA_FOCUS`). A robust
# model keeps its probabilities meaningful when the input degrades — accuracy still tracks
# confidence along the diagonal. A brittle one becomes *confidently wrong* (points fall
# well below the diagonal at high confidence), which is the dangerous failure mode for a
# confidence-gated trading rule.

# %%
def plot_calibration_under_noise(k, n_bins=10):
    tags = [t for t in MODELS if (t, k) in ROBUST_PROBS]
    if not tags:
        return
    cmap = plt.get_cmap("tab10")
    fig, ax = plt.subplots(figsize=(6.2, 5))
    for i, tag in enumerate(tags):
        yt, yp, pr = ROBUST_PROBS[(tag, k)]
        conf = pr.max(1)
        correct = (yt == yp).astype(float)
        edges = np.quantile(conf, np.linspace(0, 1, n_bins + 1))
        edges[-1] += 1e-9
        bi = np.clip(np.digitize(conf, edges) - 1, 0, n_bins - 1)
        xs = [
            conf[bi == b].mean() if (bi == b).any() else np.nan for b in range(n_bins)
        ]
        ys = [
            correct[bi == b].mean() if (bi == b).any() else np.nan
            for b in range(n_bins)
        ]
        # expected calibration error (bin-weighted |acc − conf|)
        ece = np.nansum(
            [
                (bi == b).mean() * abs(np.nan_to_num(ys[b]) - np.nan_to_num(xs[b]))
                for b in range(n_bins)
            ]
        )
        ax.plot(
            xs,
            ys,
            "o-",
            ms=4,
            color=cmap(i % 10),
            label=f"{DISPLAY[tag]} (ECE={ece:.3f})",
        )
    ax.plot([1 / 3, 1], [1 / 3, 1], "k--", lw=0.8, alpha=0.6)
    ax.set_xlabel("mean confidence (p_max)")
    ax.set_ylabel("accuracy")
    ax.set_title(f"Reliability under jump noise σ={SIGMA_FOCUS} — k={k}")
    ax.legend(fontsize=7)
    ax.grid(alpha=0.3)
    fig.tight_layout()
    plt.show()


for k in HORIZONS:
    plot_calibration_under_noise(k)

# %% [markdown]
# ### Bootstrap confidence intervals on macro-F1
#
# The test set is short (~22 days, one asset), so small macro-F1 gaps may be noise. We
# resample the **clean** test windows with replacement (1000×) and report the 95%
# interval per model. Overlapping intervals ⇒ the models are statistically
# indistinguishable — which reframes "diffusion models rank lower" as "within noise of the
# baselines."

# %%
def bootstrap_f1(yt, yp, n=1000, seed=0):
    rng = np.random.default_rng(seed)
    N = len(yt)
    vals = np.empty(n)
    for i in range(n):
        idx = rng.integers(0, N, N)
        vals[i] = f1_score(
            yt[idx], yp[idx], average="macro", labels=[0, 1, 2], zero_division=0
        )
    return vals.mean(), np.percentile(vals, 2.5), np.percentile(vals, 97.5)


boot_rows = []
for (tag, k), r in RESULTS.items():
    mean, lo, hi = bootstrap_f1(r["y_true"], r["y_pred"])
    boot_rows.append({"model": DISPLAY[tag], "k": k, "mean": mean, "lo": lo, "hi": hi})
boot_df = pd.DataFrame(boot_rows)

# forest plot: macro-F1 ± 95% CI per model, one panel per horizon
present = [DISPLAY[m] for m in MODELS if DISPLAY[m] in set(boot_df["model"])]
fig, axes = plt.subplots(
    1, len(HORIZONS), figsize=(4 * len(HORIZONS), 3.6), sharey=True
)
axes = np.atleast_1d(axes)
cmap = plt.get_cmap("tab10")
for ax, k in zip(axes, HORIZONS):
    d = boot_df[boot_df["k"] == k].set_index("model").reindex(present).dropna()
    y = np.arange(len(d))
    ax.errorbar(
        d["mean"],
        y,
        xerr=[d["mean"] - d["lo"], d["hi"] - d["mean"]],
        fmt="o",
        color="black",
        ecolor="grey",
        capsize=3,
        ms=5,
    )
    ax.set_yticks(y, d.index if k == HORIZONS[0] else [""] * len(d), fontsize=8)
    ax.set_title(f"k={k}")
    ax.set_xlabel("macro-F1 (95% CI)")
    ax.grid(alpha=0.3, axis="x")
fig.suptitle(
    "Bootstrap 95% CI on macro-F1 — overlapping bars = indistinguishable", y=1.03
)
fig.tight_layout()
plt.show()
boot_df.pivot(index="model", columns="k", values="mean").reindex(present)
# Out:
# k                           10     20     50     100
# model
# dla + ofi                0.6954 0.6385 0.6148 0.5707
# tlob + ofi               0.6800 0.6099 0.5749 0.5629
# ctabl + ofi              0.6886 0.6254 0.5895 0.5693
# binctabl + ofi           0.6661 0.6074 0.5777 0.5581
# deeplob + ofi            0.6310 0.5584 0.4851 0.5234
# alphastablelob_1.5 + ofi 0.6873 0.6159 0.5889 0.5765
# linvar + ofi             0.6706 0.6224 0.5994 0.5718
# logreg + ofi             0.6595 0.6112 0.5895 0.5568
# jumpgatelob + ofi        0.6779 0.6277 0.5842 0.5454
# ofsatnet + ofi           0.6830 0.6135 0.6014 0.5396

# %% [markdown]
# ## 8. Final model comparison table
#
# Mean macro-F1 across horizons (overall, calm, extreme) plus the financial
# aggregates (mean MCC / capture ratio). `robustness` = extreme / calm.

# %%
if RESULTS:
    agg = metrics_df.groupby("model")["macro_f1"].mean().rename("macro_f1_mean")
    parts = [agg]
    if not fin_df.empty:
        parts.append(fin_df.groupby("model")[["mcc", "capture_ratio"]].mean())
    ex = extreme_df.groupby("model")[["f1_calm", "f1_extreme"]].mean()
    parts.append(ex)
    summary = pd.concat(parts, axis=1)
    summary["robustness"] = summary["f1_extreme"] / summary["f1_calm"].clip(lower=1e-9)
    summary = summary.sort_values("macro_f1_mean", ascending=False)
    grad_cols = [
        c
        for c in ["macro_f1_mean", "mcc", "capture_ratio", "f1_calm", "f1_extreme"]
        if c in summary.columns
    ]
    display(
        summary.style.background_gradient(cmap="YlGn", subset=grad_cols).format(
            "{:.4f}"
        )
    )
else:
    print("No results — populate CHECKPOINTS in section 2 and re-run.")
# Out:
# <style type="text/css">
# #T_3fdff_row0_col0, #T_3fdff_row0_col1, #T_3fdff_row0_col3, #T_3fdff_row1_col2, #T_3fdff_row2_col4 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_3fdff_row0_col2 {
#   background-color: #005b32;
#   color: #f1f1f1;
# }
# #T_3fdff_row0_col4 {
#   background-color: #005830;
#   color: #f1f1f1;
# }
# #T_3fdff_row1_col0 {
#   background-color: #066d39;
#   color: #f1f1f1;
# }
# #T_3fdff_row1_col1 {
#   background-color: #006737;
#   color: #f1f1f1;
# }
# #T_3fdff_row1_col3, #T_3fdff_row4_col2 {
#   background-color: #0a703a;
#   color: #f1f1f1;
# }
# #T_3fdff_row1_col4 {
#   background-color: #004c2c;
#   color: #f1f1f1;
# }
# #T_3fdff_row2_col0 {
#   background-color: #096f3a;
#   color: #f1f1f1;
# }
# #T_3fdff_row2_col1, #T_3fdff_row3_col1 {
#   background-color: #177b3f;
#   color: #f1f1f1;
# }
# #T_3fdff_row2_col2 {
#   background-color: #026a38;
#   color: #f1f1f1;
# }
# #T_3fdff_row2_col3 {
#   background-color: #0e743c;
#   color: #f1f1f1;
# }
# #T_3fdff_row3_col0, #T_3fdff_row3_col3 {
#   background-color: #0c723b;
#   color: #f1f1f1;
# }
# #T_3fdff_row3_col2, #T_3fdff_row7_col2 {
#   background-color: #004d2c;
#   color: #f1f1f1;
# }
# #T_3fdff_row3_col4, #T_3fdff_row5_col0 {
#   background-color: #268846;
#   color: #f1f1f1;
# }
# #T_3fdff_row4_col0, #T_3fdff_row5_col1 {
#   background-color: #248644;
#   color: #f1f1f1;
# }
# #T_3fdff_row4_col1, #T_3fdff_row6_col2 {
#   background-color: #1f8142;
#   color: #f1f1f1;
# }
# #T_3fdff_row4_col3 {
#   background-color: #238443;
#   color: #f1f1f1;
# }
# #T_3fdff_row4_col4, #T_3fdff_row7_col3 {
#   background-color: #349a52;
#   color: #f1f1f1;
# }
# #T_3fdff_row5_col2 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_3fdff_row5_col3 {
#   background-color: #288a47;
#   color: #f1f1f1;
# }
# #T_3fdff_row5_col4 {
#   background-color: #10743c;
#   color: #f1f1f1;
# }
# #T_3fdff_row6_col0 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_3fdff_row6_col1 {
#   background-color: #278946;
#   color: #f1f1f1;
# }
# #T_3fdff_row6_col3 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_3fdff_row6_col4 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_3fdff_row7_col0 {
#   background-color: #339951;
#   color: #f1f1f1;
# }
# #T_3fdff_row7_col1, #T_3fdff_row8_col3 {
#   background-color: #369d54;
#   color: #f1f1f1;
# }
# #T_3fdff_row7_col4 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_3fdff_row8_col0 {
#   background-color: #39a056;
#   color: #f1f1f1;
# }
# #T_3fdff_row8_col1 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_3fdff_row8_col2 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_3fdff_row8_col4 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_3fdff_row9_col0, #T_3fdff_row9_col1, #T_3fdff_row9_col2, #T_3fdff_row9_col3, #T_3fdff_row9_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_3fdff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fdff_level0_col0" class="col_heading level0 col0" >macro_f1_mean</th>
#       <th id="T_3fdff_level0_col1" class="col_heading level0 col1" >mcc</th>
#       <th id="T_3fdff_level0_col2" class="col_heading level0 col2" >capture_ratio</th>
#       <th id="T_3fdff_level0_col3" class="col_heading level0 col3" >f1_calm</th>
#       <th id="T_3fdff_level0_col4" class="col_heading level0 col4" >f1_extreme</th>
#       <th id="T_3fdff_level0_col5" class="col_heading level0 col5" >robustness</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fdff_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_3fdff_row0_col0" class="data row0 col0" >0.6299</td>
#       <td id="T_3fdff_row0_col1" class="data row0 col1" >0.4401</td>
#       <td id="T_3fdff_row0_col2" class="data row0 col2" >0.6228</td>
#       <td id="T_3fdff_row0_col3" class="data row0 col3" >0.6275</td>
#       <td id="T_3fdff_row0_col4" class="data row0 col4" >0.6501</td>
#       <td id="T_3fdff_row0_col5" class="data row0 col5" >1.0359</td>
#     </tr>
#     <tr>
#       <th id="T_3fdff_level0_row1" class="row_heading level0 row1" >ctabl + ofi</th>
#       <td id="T_3fdff_row1_col0" class="data row1 col0" >0.6182</td>
#       <td id="T_3fdff_row1_col1" class="data row1 col1" >0.4272</td>
#       <td id="T_3fdff_row1_col2" class="data row1 col2" >0.6318</td>
#       <td id="T_3fdff_row1_col3" class="data row1 col3" >0.6142</td>
#       <td id="T_3fdff_row1_col4" class="data row1 col4" >0.6531</td>
#       <td id="T_3fdff_row1_col5" class="data row1 col5" >1.0633</td>
#     </tr>
#     <tr>
#       <th id="T_3fdff_level0_row2" class="row_heading level0 row2" >alphastablelob_1.5 + ofi</th>
#       <td id="T_3fdff_row2_col0" class="data row2 col0" >0.6171</td>
#       <td id="T_3fdff_row2_col1" class="data row2 col1" >0.4183</td>
#       <td id="T_3fdff_row2_col2" class="data row2 col2" >0.6168</td>
#       <td id="T_3fdff_row2_col3" class="data row2 col3" >0.6128</td>
#       <td id="T_3fdff_row2_col4" class="data row2 col4" >0.6549</td>
#       <td id="T_3fdff_row2_col5" class="data row2 col5" >1.0687</td>
#     </tr>
#     <tr>
#       <th id="T_3fdff_level0_row3" class="row_heading level0 row3" >linvar + ofi</th>
#       <td id="T_3fdff_row3_col0" class="data row3 col0" >0.6160</td>
#       <td id="T_3fdff_row3_col1" class="data row3 col1" >0.4184</td>
#       <td id="T_3fdff_row3_col2" class="data row3 col2" >0.6283</td>
#       <td id="T_3fdff_row3_col3" class="data row3 col3" >0.6136</td>
#       <td id="T_3fdff_row3_col4" class="data row3 col4" >0.6369</td>
#       <td id="T_3fdff_row3_col5" class="data row3 col5" >1.0380</td>
#     </tr>
#     <tr>
#       <th id="T_3fdff_level0_row4" class="row_heading level0 row4" >ofsatnet + ofi</th>
#       <td id="T_3fdff_row4_col0" class="data row4 col0" >0.6094</td>
#       <td id="T_3fdff_row4_col1" class="data row4 col1" >0.4157</td>
#       <td id="T_3fdff_row4_col2" class="data row4 col2" >0.6137</td>
#       <td id="T_3fdff_row4_col3" class="data row4 col3" >0.6067</td>
#       <td id="T_3fdff_row4_col4" class="data row4 col4" >0.6329</td>
#       <td id="T_3fdff_row4_col5" class="data row4 col5" >1.0433</td>
#     </tr>
#     <tr>
#       <th id="T_3fdff_level0_row5" class="row_heading level0 row5" >jumpgatelob + ofi</th>
#       <td id="T_3fdff_row5_col0" class="data row5 col0" >0.6088</td>
#       <td id="T_3fdff_row5_col1" class="data row5 col1" >0.4134</td>
#       <td id="T_3fdff_row5_col2" class="data row5 col2" >0.6157</td>
#       <td id="T_3fdff_row5_col3" class="data row5 col3" >0.6050</td>
#       <td id="T_3fdff_row5_col4" class="data row5 col4" >0.6426</td>
#       <td id="T_3fdff_row5_col5" class="data row5 col5" >1.0621</td>
#     </tr>
#     <tr>
#       <th id="T_3fdff_level0_row6" class="row_heading level0 row6" >tlob + ofi</th>
#       <td id="T_3fdff_row6_col0" class="data row6 col0" >0.6069</td>
#       <td id="T_3fdff_row6_col1" class="data row6 col1" >0.4125</td>
#       <td id="T_3fdff_row6_col2" class="data row6 col2" >0.6052</td>
#       <td id="T_3fdff_row6_col3" class="data row6 col3" >0.6042</td>
#       <td id="T_3fdff_row6_col4" class="data row6 col4" >0.6300</td>
#       <td id="T_3fdff_row6_col5" class="data row6 col5" >1.0427</td>
#     </tr>
#     <tr>
#       <th id="T_3fdff_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_3fdff_row7_col0" class="data row7 col0" >0.6042</td>
#       <td id="T_3fdff_row7_col1" class="data row7 col1" >0.4057</td>
#       <td id="T_3fdff_row7_col2" class="data row7 col2" >0.6285</td>
#       <td id="T_3fdff_row7_col3" class="data row7 col3" >0.6010</td>
#       <td id="T_3fdff_row7_col4" class="data row7 col4" >0.6317</td>
#       <td id="T_3fdff_row7_col5" class="data row7 col5" >1.0511</td>
#     </tr>
#     <tr>
#       <th id="T_3fdff_level0_row8" class="row_heading level0 row8" >binctabl + ofi</th>
#       <td id="T_3fdff_row8_col0" class="data row8 col0" >0.6023</td>
#       <td id="T_3fdff_row8_col1" class="data row8 co

# %% [markdown]
# ### 9.0 Config

# %%
# Global knobs for the significance battery. It runs on EVERY (model, horizon)
# in RESULTS — no single target to pick.
H_FWD = None  # forward-return horizon in *windows*; None -> that pair's k
FLAT_THRESHOLD = 0.0  # |score| <= thr counts as "no directional call"
COST_BPS = 5.0  # round-trip cost: half-spread + fees + adverse selection
N_BOOT = 2000  # block-bootstrap resamples
CI = 0.95  # two-sided bootstrap coverage
MEAN_BURN = 250  # burn-in windows before the prevailing mean is trusted
RHO_GRID = [0.0, 0.5, 0.9, 0.95, 0.99]  # AR(1) values swept for breadth deflation
N_REL_BINS = 10  # reliability-diagram / Murphy bins
REL_FOCUS_K = None  # horizon for the reliability-diagram panel; None -> first
print(
    f"significance battery over {len(RESULTS)} (model, horizon) pairs, cost={COST_BPS}bp"
)
# Out:
# significance battery over 40 (model, horizon) pairs, cost=5.0bp

# %% [markdown]
# ### 9.1 Data-loading stub
#
# `build_eval_frame` assembles the per-decision-point dataframe the tests consume,
# straight from this notebook's `RESULTS`/`META`. Columns match the spec:
# `ts, score, pred_class, p_down/p_flat/p_up, r_hat, r_fwd, cost`, plus the two
# baselines `r_mean` (prevailing-mean, *nested*) and `r_rw` (persistence,
# *non-nested*). **To score an external model**, replace the body of this function
# with your own dataframe — the rest of the section only touches these columns.

# %%
from scipy import stats  # noqa: E402


def _forward_return(mid, centres, h):
    """Log forward mid return over h windows; NaN where the horizon runs off the end."""
    mid = np.asarray(mid, float)
    nxt = centres + h
    ok = nxt < len(mid)
    r = np.full(len(centres), np.nan)
    r[ok] = np.log(mid[nxt[ok]]) - np.log(mid[centres[ok]])
    return r


def build_eval_frame(tag, k, h=None, flat_thr=0.0, cost_bps=COST_BPS):
    """Per-decision-point frame for (tag, k). See section header for column spec.

    r_hat: these are *classifiers* with no native return forecast, so the score
    s = P(up)-P(down) is mapped to return units by a single fixed scale matched to
    the realized-return dispersion (monotone, in-sample). Drop in a genuine model
    point-forecast here if you have one.
    """
    r, m = RESULTS[(tag, k)], META[k]
    h = k if h is None else h
    pr = r["probs"]
    score = pr[:, 2] - pr[:, 0]
    r_fwd = _forward_return(m["mid"], m["centres"], h)
    ss, sr = np.nanstd(score), np.nanstd(r_fwd)
    r_hat = score * (sr / ss if ss > 0 else 0.0)
    ts = np.asarray(m["ts"])[m["centres"]] if "ts" in m else np.arange(len(score))
    df = pd.DataFrame(
        {
            "ts": ts,
            "score": score,
            "pred_class": r["y_pred"],
            "p_down": pr[:, 0],
            "p_flat": pr[:, 1],
            "p_up": pr[:, 2],
            "r_hat": r_hat,
            "r_fwd": r_fwd,
            "cost": cost_bps / 1e4,
        }
    )
    # nested baseline: expanding (out-of-sample) prevailing mean of r_fwd
    rf = df["r_fwd"].to_numpy()
    csum = np.nancumsum(rf)
    cnt = np.cumsum(~np.isnan(rf))
    prev = np.full(len(rf), np.nan)
    prev[1:] = csum[:-1] / np.clip(cnt[:-1], 1, None)
    prev[cnt < MEAN_BURN] = np.nan
    df["r_mean"] = prev
    # non-nested baseline: persistence (previous window's realized fwd return)
    df["r_rw"] = df["r_fwd"].shift(1)
    df["dir_call"] = np.where(
        np.abs(df["score"]) <= flat_thr, 0, np.sign(df["score"])
    ).astype(int)
    return df


def integrated_ac_time(x, max_lag=200):
    """Integrated autocorr time tau = 1 + 2*sum_{l>=1} rho_l (positive part, Sokal).

    Ties the HAC lag and the bootstrap block length to the signal's own memory.
    """
    x = np.asarray(x, float)
    x = x[~np.isnan(x)]
    x = x - x.mean()
    n = len(x)
    denom = np.dot(x, x)
    if denom <= 0 or n < 5:
        return 1.0
    tau, max_lag = 1.0, min(max_lag, n - 1)
    for lag in range(1, max_lag + 1):
        rho = np.dot(x[lag:], x[:-lag]) / denom
        if rho <= 0:  # stop at first non-positive lag
            break
        tau += 2 * rho
    return float(max(tau, 1.0))


# Build one eval frame per (model, horizon), plus its own HAC lag / block length
# (each series gets a lag tied to ITS autocorrelation time and forward horizon).
FRAMES, HACP = {}, {}
for tag, k in RESULTS:
    if META.get(k) is None:
        continue
    fr = build_eval_frame(tag, k, H_FWD, FLAT_THRESHOLD, COST_BPS)
    h_eff = k if H_FWD is None else H_FWD
    ac = int(np.ceil(integrated_ac_time(fr["score"])))
    FRAMES[(tag, k)] = fr
    HACP[(tag, k)] = {
        "h_eff": h_eff,
        "hac_L": int(max(ac, h_eff - 1, 1)),
        "block": int(max(ac, h_eff, 1)),
    }
print(f"built {len(FRAMES)} eval frames")
if FRAMES:
    ex = next(iter(FRAMES))
    print(
        f"example {ex}: rows={len(FRAMES[ex])}  "
        f"usable r_fwd={int(FRAMES[ex]['r_fwd'].notna().sum())}  "
        f"HAC_L={HACP[ex]['hac_L']}  block={HACP[ex]['block']}"
    )
    display(FRAMES[ex].head())
# Out:
# built 40 eval frames
# example ('dla', 10): rows=31932  usable r_fwd=31932  HAC_L=9  block=10
#                  ts   score  pred_class  p_down  p_flat   p_up   r_hat  \
# 0  1783661640000000 -0.4868           0  0.6876  0.1115 0.2008 -0.0006
# 1  1783661650000000 -0.3510           0  0.5945  0.1621 0.2435 -0.0004
# 2  1783661660000000  0.0493           1  0.2791  0.3926 0.3284  0.0001
# 3  1783661690000000  0.9628           2  0.0089  0.0193 0.9718  0.0012
# 4  1783661690000000  0.9591           2  0.0104  0.0201 0.9695  0.0012
#
#     r_fwd   cost  r_mean    r_rw  dir_call
# 0  0.0009 0.0005     NaN     NaN        -1
# 1  0.0021 0.0005     NaN  0.0009        -1
# 2  0.0021 0.0005     NaN  0.0021         1
# 3 -0.0000 0.0005     NaN  0.0021         1
# 4 -0.0000 0.0005     NaN -0.0000         1

# %% [markdown]
# ### 9.2 Statistical skill
#
# Directional and forecast-comparison tests. `hac_lrv` is the shared Newey–West
# long-run variance used by DM and CW; the lag `HAC_L` is tied to the signal's
# autocorrelation time so both dependence corrections are consistent.

# %%
def hac_lrv(x, L):
    """Newey-West (Bartlett) long-run variance of one observation of x.

    gamma_0 + 2 * sum_{l=1..L} (1 - l/(L+1)) gamma_l. Shared by DM and CW so their
    SEs reflect the heavy serial correlation of tick-level loss differentials.
    """
    x = np.asarray(x, float)
    x = x[~np.isnan(x)]
    n = len(x)
    if n < 2:
        return np.nan
    x = x - x.mean()
    lrv = np.dot(x, x) / n
    for lag in range(1, min(L, n - 1) + 1):
        w = 1.0 - lag / (L + 1.0)
        lrv += 2.0 * w * np.dot(x[lag:], x[:-lag]) / n
    return max(lrv, 1e-24)


def hac_se_mean(x, L):
    """HAC standard error of the sample mean of x."""
    x = np.asarray(x, float)
    x = x[~np.isnan(x)]
    return np.sqrt(hac_lrv(x, L) / len(x))


def pesaran_timmermann(pred_sign, real_ret):
    """PT (1992) directional-accuracy test. pred_sign in {-1,0,+1}; flats dropped."""
    mask = ~np.isnan(real_ret) & (pred_sign != 0)
    x = (pred_sign[mask] > 0).astype(float)  # predicted up
    y = (real_ret[mask] > 0).astype(float)  # realized up
    n = len(y)
    if n < 10:
        return {"hit": np.nan, "benchmark": np.nan, "stat": np.nan, "p": np.nan, "n": n}
    P = float(np.mean(x == y))  # hit rate = sign agreement
    Py, Px = y.mean(), x.mean()
    Pstar = Py * Px + (1 - Py) * (1 - Px)  # independence benchmark
    var_P = Pstar * (1 - Pstar) / n
    var_Pstar = (
        ((2 * Py - 1) ** 2) * Px * (1 - Px) / n
        + ((2 * Px - 1) ** 2) * Py * (1 - Py) / n
        + 4 * Py * Px * (1 - Py) * (1 - Px) / n**2
    )
    denom = var_P - var_Pstar
    stat = (P - Pstar) / np.sqrt(denom) if denom > 0 else np.nan
    p = float(1 - stats.norm.cdf(stat)) if np.isfinite(stat) else np.nan
    return {"hit": P, "benchmark": Pstar, "stat": stat, "p": p, "n": n}


def henriksson_merton(pred_sign, real_ret):
    """HM market-timing skill: p_up + p_down - 1, hypergeometric significance."""
    mask = ~np.isnan(real_ret) & (pred_sign != 0)
    ps, rr = pred_sign[mask], real_ret[mask]
    up, dn = rr > 0, rr < 0
    n1, n2 = int(up.sum()), int(dn.sum())
    if n1 < 5 or n2 < 5:
        return {
            "skill": np.nan,
            "p_up": np.nan,
            "p_down": np.nan,
            "stat": np.nan,
            "p": np.nan,
        }
    p_up = float(np.mean(ps[up] > 0))  # correct given up
    p_dn = float(np.mean(ps[dn] < 0))  # correct given down
    n = n1 + n2
    N1 = int((ps > 0).sum())  # predicted up
    n11 = int(((ps > 0) & up).sum())  # correct up
    E = N1 * n1 / n
    V = N1 * n1 * (n - N1) * (n - n1) / (n**2 * (n - 1))
    stat = (n11 - E) / np.sqrt(V) if V > 0 else np.nan
    p = float(1 - stats.norm.cdf(stat)) if np.isfinite(stat) else np.nan
    return {
        "skill": p_up + p_dn - 1,
        "p_up": p_up,
        "p_down": p_dn,
        "stat": stat,
        "p": p,
    }


def diebold_mariano(r, f1, f2, L, h=1):
    """DM squared-error test, model f1 vs NON-NESTED baseline f2, HAC SE + HLN fix.

    d = e1^2 - e2^2; a significantly negative mean => model f1 has lower loss.
    """
    m = ~np.isnan(r) & ~np.isnan(f1) & ~np.isnan(f2)
    e1, e2 = r[m] - f1[m], r[m] - f2[m]
    d = e1**2 - e2**2
    n = len(d)
    if n < 10:
        return {"dbar": np.nan, "stat": np.nan, "p": np.nan, "n": n}
    se = hac_se_mean(d, L)
    stat = d.mean() / se if se > 0 else np.nan
    stat *= np.sqrt((n + 1 - 2 * h + h * (h - 1) / n) / n)  # Harvey-Leybourne-Newbold
    p = float(2 * (1 - stats.norm.cdf(abs(stat)))) if np.isfinite(stat) else np.nan
    return {"dbar": float(d.mean()), "stat": stat, "p": p, "n": n}


def clark_west(r, f_unrestr, f_restr, L):
    """CW test, model f_unrestr vs NESTED baseline f_restr (e.g. prevailing mean).

    f = (r - f_restr)^2 - [(r - f_unrestr)^2 - (f_restr - f_unrestr)^2]. The last
    term strips the estimation-noise penalty that biases plain DM against the
    larger model. One-sided: fbar>0 => the extra structure earns its keep OOS.
    """
    m = ~np.isnan(r) & ~np.isnan(f_unrestr) & ~np.isnan(f_restr)
    r_, fu, fr = r[m], f_unrestr[m], f_restr[m]
    f = (r_ - fr) ** 2 - ((r_ - fu) ** 2 - (fr - fu) ** 2)
    n = len(f)
    if n < 10:
        return {"fbar": np.nan, "stat": np.nan, "p": np.nan, "n": n}
    se = hac_se_mean(f, L)
    stat = f.mean() / se if se > 0 else np.nan
    p = float(1 - stats.norm.cdf(stat)) if np.isfinite(stat) else np.nan
    return {"fbar": float(f.mean()), "stat": stat, "p": p, "n": n}


def campbell_thompson_r2(r, f_model, f_mean):
    """OOS R^2 vs the prevailing mean; positive => model beats the running mean."""
    m = ~np.isnan(r) & ~np.isnan(f_model) & ~np.isnan(f_mean)
    num = np.sum((r[m] - f_model[m]) ** 2)
    den = np.sum((r[m] - f_mean[m]) ** 2)
    return float(1 - num / den) if den > 0 else np.nan

# %% [markdown]
# ### 9.3 Economic value
#
# Information coefficient, Fundamental Law with breadth deflation, conditional
# separation, break-even cost, and calibration. Bootstrap CIs use circular blocks
# of length `BLOCK_LEN` (the same autocorrelation time that set `HAC_L`).

# %%
def block_bootstrap_ci(func, arrays, block, n_boot=None, ci=None, seed=0):
    """Circular-block-bootstrap CI for a statistic of one or more aligned arrays."""
    n_boot = N_BOOT if n_boot is None else n_boot
    ci = CI if ci is None else ci
    rng = np.random.default_rng(seed)
    arrays = [np.asarray(a, float) for a in arrays]
    n = len(arrays[0])
    nb = int(np.ceil(n / block))
    vals = []
    for _ in range(n_boot):
        starts = rng.integers(0, n, nb)
        idx = np.concatenate([(np.arange(s, s + block) % n) for s in starts])[:n]
        v = func(*[a[idx] for a in arrays])
        if np.isfinite(v):
            vals.append(v)
    vals = np.array(vals)
    lo, hi = np.percentile(vals, [100 * (1 - ci) / 2, 100 * (1 + ci) / 2])
    return float(np.mean(vals)), float(lo), float(hi)


def boot_group_diff(a, b, block, n_boot=None, ci=None, seed=3):
    """Block-bootstrap CI for mean(a) - mean(b) (each group resampled separately)."""
    n_boot = N_BOOT if n_boot is None else n_boot
    ci = CI if ci is None else ci
    rng = np.random.default_rng(seed)
    a, b = np.asarray(a, float), np.asarray(b, float)
    if len(a) < 2 or len(b) < 2:
        return np.nan, np.nan, np.nan

    def bmean(x):
        n = len(x)
        nb = int(np.ceil(n / block))
        s = rng.integers(0, n, nb)
        idx = np.concatenate([(np.arange(t, t + block) % n) for t in s])[:n]
        return x[idx].mean()

    d = np.array([bmean(a) - bmean(b) for _ in range(n_boot)])
    lo, hi = np.percentile(d, [100 * (1 - ci) / 2, 100 * (1 + ci) / 2])
    return float(d.mean()), float(lo), float(hi)


def _pearson(a, b):
    m = ~np.isnan(a) & ~np.isnan(b)
    return float(np.corrcoef(a[m], b[m])[0, 1]) if m.sum() > 2 else np.nan


def _spearman(a, b):
    m = ~np.isnan(a) & ~np.isnan(b)
    return float(stats.spearmanr(a[m], b[m]).correlation) if m.sum() > 2 else np.nan


def jonckheere_terpstra(groups):
    """JT trend test for monotone increase across ordered groups (normal approx)."""
    groups = [np.asarray(g, float) for g in groups]
    groups = [g[~np.isnan(g)] for g in groups]
    ns = np.array([len(g) for g in groups])
    N = ns.sum()
    JT = 0.0
    for i in range(len(groups)):
        for j in range(i + 1, len(groups)):
            diff = groups[j][:, None] - groups[i][None, :]  # Mann-Whitney count
            JT += np.sum(diff > 0) + 0.5 * np.sum(diff == 0)
    mu = (N**2 - np.sum(ns**2)) / 4.0
    var = (N**2 * (2 * N + 3) - np.sum(ns**2 * (2 * ns + 3))) / 72.0
    z = (JT - mu) / np.sqrt(var) if var > 0 else np.nan
    p = float(1 - stats.norm.cdf(z)) if np.isfinite(z) else np.nan  # one-sided (up)
    return {"JT": float(JT), "z": float(z) if np.isfinite(z) else np.nan, "p": p}


def brier_multiclass(probs, y):
    oh = np.eye(probs.shape[1])[y]
    return float(np.mean(np.sum((probs - oh) ** 2, axis=1)))


def murphy_decomposition(f, o, n_bins=None):
    """Binary Brier = Reliability - Resolution + Uncertainty (Murphy 1973).

    f = forecast prob, o in {0,1}. reliability lower is better; resolution higher.
    """
    n_bins = N_REL_BINS if n_bins is None else n_bins
    edges = np.linspace(0, 1, n_bins + 1)
    edges[-1] += 1e-9
    b = np.clip(np.digitize(f, edges) - 1, 0, n_bins - 1)
    obar = o.mean()
    rel = res = 0.0
    xs, ys, ns = [], [], []
    for k in range(n_bins):
        mask = b == k
        nk = int(mask.sum())
        if nk == 0:
            continue
        fk, ok = f[mask].mean(), o[mask].mean()
        rel += nk * (fk - ok) ** 2
        res += nk * (ok - obar) ** 2
        xs.append(fk)
        ys.append(ok)
        ns.append(nk)
    n = len(f)
    return {
        "reliability": rel / n,
        "resolution": res / n,
        "uncertainty": float(obar * (1 - obar)),
        "brier": float(np.mean((f - o) ** 2)),
        "bins": (np.array(xs), np.array(ys), np.array(ns)),
    }

# %%
# Run every statistical + economic metric on every (model, horizon). Results land
# in SIG[(tag, k)] (full dicts) and SIG_ROWS (one tidy record per pair).
def run_significance(tag, k):
    F = FRAMES[(tag, k)]
    hp = HACP[(tag, k)]
    L, block, h = hp["hac_L"], hp["block"], hp["h_eff"]
    ps, rf = F["dir_call"].to_numpy(), F["r_fwd"].to_numpy()
    rhat, rrw, rmean = (
        F["r_hat"].to_numpy(),
        F["r_rw"].to_numpy(),
        F["r_mean"].to_numpy(),
    )
    out = {}
    out["PT"] = pesaran_timmermann(ps, rf)
    out["HM"] = henriksson_merton(ps, rf)
    out["DM_rw"] = diebold_mariano(rf, rhat, rrw, L, h=h)
    out["CW"] = clark_west(rf, rhat, rmean, L)
    out["CT_R2"] = campbell_thompson_r2(rf, rhat, rmean)

    sc = F["score"].to_numpy()
    m = ~np.isnan(sc) & ~np.isnan(rf)
    sc_, rf_ = sc[m], rf[m]
    out["IC_pearson"] = (
        _pearson(sc_, rf_),
        *block_bootstrap_ci(_pearson, (sc_, rf_), block, seed=1)[1:],
    )
    out["IC_spearman"] = (
        _spearman(sc_, rf_),
        *block_bootstrap_ci(_spearman, (sc_, rf_), block, seed=2)[1:],
    )
    ic0 = _pearson(sc_, rf_)
    rho_hat = _pearson(sc_[1:], sc_[:-1])
    flam_rows = []
    for rho in sorted(set(RHO_GRID + [round(float(rho_hat), 3)])):
        defl = (1 - rho) / (1 + rho)
        br_eff = len(sc_) * defl
        flam_rows.append(
            {
                "rho": rho,
                "breadth_defl": defl,
                "BR_eff": br_eff,
                "IR": ic0 * np.sqrt(max(br_eff, 0.0)),
            }
        )
    out["FLAM"] = {
        "ic": ic0,
        "rho_hat": float(rho_hat),
        "table": pd.DataFrame(flam_rows),
    }

    pc = F["pred_class"].to_numpy()
    grp = {c: rf[(pc == c) & ~np.isnan(rf)] for c in (0, 1, 2)}
    edge = boot_group_diff(grp[2], grp[0], block)
    out["SEP"] = {
        "means_bp": {
            c: float(np.nanmean(grp[c]) * 1e4) if len(grp[c]) else np.nan for c in grp
        },
        "edge_bp": (edge[0] * 1e4, edge[1] * 1e4, edge[2] * 1e4),
        "JT": jonckheere_terpstra([grp[0], grp[1], grp[2]]),
    }

    c = float(F["cost"].iloc[0])
    dcall = F["dir_call"].to_numpy()
    dmask = (dcall != 0) & ~np.isnan(rf)
    pnl = dcall[dmask] * rf[dmask]
    up_mask = (pc == 2) & ~np.isnan(rf)
    up_move = float(np.nanmean(rf[up_mask])) if up_mask.any() else np.nan
    rhat_mag = np.abs(rhat[dmask])
    clears = float(np.mean(rhat_mag > c)) if len(rhat_mag) else np.nan
    wins, losses = pnl[pnl > 0], -pnl[pnl < 0]
    W = wins.mean() if len(wins) else np.nan
    Lm = losses.mean() if len(losses) else np.nan
    p_star = (Lm + c) / (W + Lm) if np.isfinite(W + Lm) and (W + Lm) > 0 else np.nan
    out["BE"] = {
        "up_move_bp": up_move * 1e4,
        "cost_bp": c * 1e4,
        "frac_clears": clears,
        "W_bp": W * 1e4,
        "L_bp": Lm * 1e4,
        "p_star": float(p_star) if np.isfinite(p_star) else np.nan,
        "hit": float(np.mean(pnl > 0)) if len(pnl) else np.nan,
    }

    probs = RESULTS[(tag, k)]["probs"]
    yv = RESULTS[(tag, k)]["y_true"]
    out["BRIER_MC"] = brier_multiclass(probs, yv)
    out["MURPHY"] = murphy_decomposition(probs[:, 2], (yv == 2).astype(float))
    return out


SIG, SIG_ROWS = {}, []
for tag, k in sorted(RESULTS, key=lambda tk: (tk[1], tk[0])):
    if (tag, k) not in FRAMES:
        continue
    r = run_significance(tag, k)
    SIG[(tag, k)] = r
    SIG_ROWS.append(
        {
            "model": DISPLAY[tag],
            "k": k,
            "pt_hit": r["PT"]["hit"],
            "pt_p": r["PT"]["p"],
            "hm_skill": r["HM"]["skill"],
            "hm_p": r["HM"]["p"],
            "dm_dbar": r["DM_rw"]["dbar"],
            "dm_p": r["DM_rw"]["p"],
            "cw_fbar": r["CW"]["fbar"],
            "cw_p": r["CW"]["p"],
            "ct_r2_pct": r["CT_R2"] * 100,
            "ic_pearson": r["IC_pearson"][0],
            "ic_spearman": r["IC_spearman"][0],
            "ir_rho_hat": float(
                r["FLAM"]["table"].iloc[
                    (r["FLAM"]["table"]["rho"] - r["FLAM"]["rho_hat"]).abs().idxmin()
                ]["IR"]
            ),
            "rho_hat": r["FLAM"]["rho_hat"],
            "edge_bp": r["SEP"]["edge_bp"][0],
            "jt_p": r["SEP"]["JT"]["p"],
            "be_pstar": r["BE"]["p_star"],
            "be_hit": r["BE"]["hit"],
            "frac_clears": r["BE"]["frac_clears"],
            "brier_mc": r["BRIER_MC"],
            "reliability": r["MURPHY"]["reliability"],
            "resolution": r["MURPHY"]["resolution"],
        }
    )
sig_df = pd.DataFrame(SIG_ROWS)
print(f"scored {len(SIG)} (model, horizon) pairs")
sig_df
# Out:
# scored 40 (model, horizon) pairs
#                        model    k  pt_hit   pt_p  hm_skill   hm_p  dm_dbar  \
# 0   alphastablelob_1.5 + ofi   10  0.5245 0.0000    0.0526 1.0000   0.0000
# 1             binctabl + ofi   10  0.5179 0.0000    0.0358 1.0000   0.0000
# 2                ctabl + ofi   10  0.5170 0.0000    0.0388 1.0000   0.0000
# 3              deeplob + ofi   10  0.5438 0.0000    0.0721 0.3096   0.0000
# 4                  dla + ofi   10  0.5284 0.0000    0.0511 1.0000   0.0000
# 5          jumpgatelob + ofi   10  0.5286 0.0000    0.0555 1.0000   0.0000
# 6               linvar + ofi   10  0.5280 0.0000    0.0517 1.0000   0.0000
# 7               logreg + ofi   10  0.5322 0.0000    0.0581 1.0000   0.0000
# 8             ofsatnet + ofi   10  0.5276 0.0000    0.0495 1.0000   0.0000
# 9                 tlob + ofi   10  0.5241 0.0000    0.0401 1.0000   0.0000
# 10  alphastablelob_1.5 + ofi   20  0.5161 0.0000    0.0233 0.7671   0.0000
# 11            binctabl + ofi   20  0.5170 0.0000    0.0278 0.6621   0.0000
# 12               ctabl + ofi   20  0.5235 0.0000    0.0407 0.0284   0.0000
# 13             deeplob + ofi   20  0.5273 0.0000    0.0572 0.0004   0.0000
# 14                 dla + ofi   20  0.5096 0.0002    0.0201 0.9990   0.0000
# 15         jumpgatelob + ofi   20  0.5218 0.0000    0.0343 0.1074   0.0000
# 16              linvar + ofi   20  0.5220 0.0000    0.0375 0.0853   0.0000
# 17              logreg + ofi   20  0.5205 0.0000    0.0367 0.2065   0.0000
# 18            ofsatnet + ofi   20  0.5283 0.0000    0.0507 0.0001   0.0000
# 19                tlob + ofi   20  0.5203 0.0000    0.0318 0.2576   0.0000
# 20  alphastablelob_1.5 + ofi   50  0.5179 0.0000    0.0348 0.0000   0.0000
# 21            binctabl + ofi   50  0.5175 0.0000    0.0351 0.0000   0.0000
# 22               ctabl + ofi   50  0.5100 0.0004    0.0181 0.0132   0.0000
# 23             deeplob + ofi   50  0.5448 0.0000    0.0798 0.0000   0.0000
# 24                 dla + ofi   50  0.5013 0.2257    0.0045 0.6863   0.0000
# 25         jumpgatelob + ofi   50  0.5208 0.0000    0.0419 0.0000   0.0000
# 26              linvar + ofi   50  0.5092 0.0008    0.0173 0.0232   0.0000
# 27              logreg + ofi   50  0.5095 0.0006    0.0188 0.0180   0.0000
# 28            ofsatnet + ofi   50  0.5047 0.0210    0.0113 0.2145   0.0000
# 29                tlob + ofi   50  0.5172 0.0000    0.0263 0.0001   0.0000
# 30  alphastablelob_1.5 + ofi  100  0.5124 0.0000    0.0264 0.0000   0.0000
# 31            binctabl + ofi  100  0.5077 0.0022    0.0155 0.0050   0.0000
# 32               ctabl + ofi  100  0.5094 0.0007    0.0188 0.0017   0.0000
# 33             deeplob + ofi  100  0.5025 0.0227    0.0119 0.0450   0.0000
# 34                 dla + ofi  100  0.5022 0.0569    0.0095 0.0991   0.0000
# 35         jumpgatelob + ofi  100  0.5117 0.0000    0.0258 0.0000   0.0000
# 36              linvar + ofi  100  0.5065 0.0099    0.0141 0.0195   0.0000
# 37              logreg + ofi  100  0.5181 0.0000    0.0374 0.0000   0.0000
# 38            ofsatnet + ofi  100  0.5011 0.3090    0.0036 0.4102   0.0000
# 39                tlob + ofi  100  0.5087 0.0544    0.0097 0.0834   0.0000
#
#      dm_p  cw_fbar   cw_p  ...  ir_rho_hat  rho_hat  edge_bp   jt_p  be_pstar  \
# 0  0.0000  -0.0000 0.9944  ...     -1.9525   0.8616  -0.8961 1.0000    1.1873
# 1  0.0000  -0.0000 0.9984  ...     -2.3485   0.8393  -0.7050 1.0000    1.1866
# 2  0.0000  -0.0000 0.9972  ...     -2.2556   0.8416  -0.8985 1.0000    1.1817
# 3  0.0000   0.0000 0.2902  ...      0.3065   0.9120  -0.0414 0.0114    1.1690
# 4  0.0000  -0.0000 0.9997  ...     -2.6175   0.8437  -1.2071 1.0000    1.1892
# 5  0.0000  -0.0000 0.9934  ...     -1.8541   0.8712  -0.8489 1.0000    1.1843
# 6  0.0000  -0.0000 1.0000  ...     -3.8704   0.8399  -0.8125 1.0000    1.1890
# 7  0.0000  -0.0000 0.9999  ...     -3.0992   0.8379  -0.6748 1.0000    1.1834
# 8  0.0000  -0.0000 0.9999  ...     -2.9780   0.8537  -0.9845 1.0000    1.1906
# 9  0.0000  -0.0000 0.9999  ...     -2.8441   0.8341  -1.0107 1.0000    1.1876
# 10 0.0000  -0.0000 0.5962  ...     -0.2348   0.9417  -0.3174 1.0000    0.9772
# 11 0.0000  -0.0000 0.6128  ...     -0.3465   0.9102  -0.4065 1.0000    0.9802
# 12 0.0000  -0.0000 0.8746  ...     -0.9564   0.9202  -0.7534 1.0000    0.9847
# 13 0.0000   0.0000 0.0060  ...      1.5440   0.9410   0.6183 0.0000    0.9624
# 14 0.0000  -0.0000 0.8767  ...     -0.8977   0.9274  -1.0608 1.0000    0.9867
# 15 0.0000  -0.0000 0.8847  ...     -0.9276   0.9269  -0.9699 1.0000    0.9904
# 16 0.0000  -0.0000 0.9788  ...     -1.6687   0.9158  -0.5739 1.0000    0.9938
# 17 0.0000  -0.0000 0.9166  ...     -1.1763   0.9149  -0.4995 1.0000    0.9876
# 18 0.0000   0.0000 0.4599  ...     -0.0032   0.9215  -0.0362 0.6820    0.9754
# 19 0.0000   0.0000 0.3179  ...      0.2802   0.9111  -0.1496 0.9821    0.9704
# 20 0.0000   0.0000 0.0398  ...      1.1244   0.9725   1.7097 0.0000    0.7808
# 21 0.0000   0.0000 0.0316  ...      1.9849   0.9321   1.3021 0.0000    0.7848
# 22 0.0000   0.0000 0.1853  ...      0.7010   0.9610   0.5565 0.0327    0.7905
# 23 0.0000   0.0000 0.0002  ...      1.6210   0.9865   2.4382 0.0000    0.7800
# 24 0.0000   0.0000 0.1427  ...      0.6808   0.9716   0.9936 0.0000    0.7830
# 25 0.0000   0.0000 0.0118  ...      1.4211   0.9736   1.7340 0.0000    0.7822
# 26 0.0000   0.0000 0.2792  ...      0.4398   0.9623   0.6987 0.0011    0.7932
# 27 0.0000   0.0000 0.0952  ...      0.9432   0.9645   1.2358 0.0000    0.7839
# 28 0.0000   0.0000 0.1264  ...      0.8607   0.9640   1.0922 0.0126    0.7766
# 29 0.0000   0.0000 0.0371  ...      1.5898   0.9462   1.0489 0.0000    0.7880
# 30 0.0000   0.0000 0.4405  ...      0.0973   0.9887   1.2795 0.0000    0.7052
# 31 0.0000   0.0000 0.4132  ...      0.3661   0.9333   1.1808 0.0000    0.7175
# 32 0.0000   0.0000 0.4394  ...      0.1910   0.9616   0.7734 0.0002    0.7106
# 33 0.0000   0.0000 0.2777  ...      0.3403   0.9901   0.7585 0.0727    0.7013
# 34 0.0000  -0.0000 0.6479  ...     -0.2513   0.9791   0.0422 0.8963    0.7116
# 35 0.0000   0.0000 0.4021  ...      0.1850   0.9838   0.9646 0.0002    0.7056
# 36 0.0000  -0.0000 0.6074  ...     -0.1920   0.9759   0.0788 0.9191    0.7165
# 37 0.0000   0.0000 0.3501  ...      0.3079   0.9779   1.0447 0.0000    0.7118
# 38 0.0000  -0.0000 0.5620  ...     -0.0549   0.9739   0.0501 0.6953    0.7129
# 39 0.0000   0.0000 0.4879  ...      0.2303   0.9560  -0.1335 0.2437    0.7178
#
#     be_hit  frac_clears  brier_mc  reliability  resolution
# 0   0.4821       0.4164    0.4412       0.0032      0.0769
# 1   0.4740       0.4003    0.4623       0.0038      0.0716
# 2   0.4758       0.4228    0.4426       0.0042      0.0775
# 3   0.4884       0.4018    0.4960       0.0015      0.0558
# 4   0.4804       0.4247    0.4343       0.0014      0.0793
# 5   0.4833       0.4191    0.4509       0.0027      0.0745
# 6   0.4802       0.3685    0.4747       0.0045      0.0719
# 7   0.4831       0.3729    0.4794       0.0037      0.0700
# 8   0.4796       0.4217    0.4455       0.0024      0.0767
# 9   0.4747       0.4112    0.4481       0.0007      0.0735
# 10  0.4928       0.5495    0.5044       0.0069      0.0640
# 11  0.4951       0.5190    0.5163       0.0030      0.0590
# 12  0.5014       0.5042    0.5007       0.0034      0.0652
# 13  0.5092       0.5340    0.5562       0.0030      0.0411
# 14  0.4913       0.5205    0.4852       0.0037      0.0678
# 15  0.4984       0.5074    0.4951       0.0007      0.0633
# 16  0.4998       0.5140    0.5140       0.0050      0.0632
# 17  0.4995       0.5178    0.5140       0.0043      0.0625
# 18  0.5060       0.5568    0.5065       0.0067      0.0660
# 19  0.4973       0.5369    0.5134       0.0013      0.0617
# 20  0.5143       0.6912    0.5205       0.0045      0.0591
# 21  0.5135       0.6919    0.5369       0.0057      0.0508
# 22  0.5060       0.6977    0.5215       0.0071      0.0610
# 23  0.5400       0.7632    0.6093       0.0018      0.0388
# 24  0.4982       0.7093    0.5110       0.0068      0.0617
# 25  0.5173       0.7203    0.5260       0.0081      0.0561
# 26  0.5055       0.6937    0.5226       0.0068      0.0606
# 27  0.5063       0.6917    0.5218       0.0066      0.0604
# 28  0.5014       0.6755    0.5137       0.0043      0.0569
# 29  0.5129       0.7095    0.5395       0.0009      0.0552
# 30  0.5121       0.7686    0.5413       0.0043      0.0467
# 31  0.5066       0.7793    0.5548       0.0058      0.0409
# 32  0.5090       0.7905    0.5357       0.0070      0.0508
# 33  0.5022       0.8036    0.5902       0.0132      0.0378
# 34  0.5018       0.7840    0.5428       0.0107      0.0516
# 35  0.5113       0.7839    0.5604       0.0141      0.0482
# 36  0.5062       0.7822    0.5358       0.0071      0.0530
# 37  0.5178       0.7824    0.5420       0.0073      0.0505
# 38  0.5008       0.8091    0.5559       0.0141      0.0485
# 39  0.5082       0.7817    0.5519       0.0012      0.0479
#
# [40 rows x 23 columns]

# %% [markdown]
# > **On the tiny $R^2_{\text{OOS}}$.** At LOB frequency a Campbell–Thompson
# > $R^2$ below ~1% is *expected*, not a failure: forward mid returns are almost
# > pure noise, so even a real edge explains little variance. What matters is
# > whether that sliver is (a) statistically robust (DM/CW above) and (b)
# > economically large after the trade multiplier — quantified in the economic
# > layer next.

# %% [markdown]
# > **Calibration is only load-bearing if you size on probabilities.** If the
# > strategy just acts on the argmax class, skip the Brier / Murphy block; it
# > matters when `p_up` drives position size, where a well-resolved, low-reliability
# > forecast can be scaled and a miscalibrated one cannot.

# %%
# Reliability diagrams (up-vs-rest) — one panel per model at a focus horizon.
# Only meaningful for probability-sized strategies.
if SIG:
    ks = sorted({k for _, k in SIG})
    focus_k = REL_FOCUS_K if REL_FOCUS_K in ks else ks[0]
    tags = [t for t in MODELS if (t, focus_k) in SIG]
    if tags:
        ncol = min(4, len(tags))
        nrow = int(np.ceil(len(tags) / ncol))
        fig, axes = plt.subplots(
            nrow, ncol, figsize=(3.4 * ncol, 3.4 * nrow), squeeze=False
        )
        for ax in axes.flat:
            ax.axis("off")
        for ax, tag in zip(axes.flat, tags):
            ax.axis("on")
            mp = SIG[(tag, focus_k)]["MURPHY"]
            xs, ys, ns = mp["bins"]
            ax.plot([0, 1], [0, 1], "k--", lw=1)
            if len(ns):
                ax.scatter(
                    xs, ys, s=15 + 200 * (ns / ns.max()), color="#1f77b4", zorder=3
                )
            ax.set_title(
                f"{DISPLAY[tag]}\nrel={mp['reliability']:.4f} "
                f"res={mp['resolution']:.4f}",
                fontsize=8,
            )
            ax.set_xlim(0, 1)
            ax.set_ylim(0, 1)
            ax.set_xlabel("forecast P(up)", fontsize=8)
            ax.set_ylabel("emp. freq(up)", fontsize=8)
        fig.suptitle(f"Reliability (up-vs-rest) — horizon k={focus_k}", y=1.02)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### 9.4 Summary tables (all models × horizons)
#
# One pivot per headline metric (rows = model, cols = horizon). Statistical tests
# also print a companion p-value pivot so significance is read alongside the point
# estimate.

# %%
if not sig_df.empty:
    order = [DISPLAY[m] for m in MODELS if DISPLAY[m] in set(sig_df["model"])]

    def pivot(col, fmt="{:.4f}", cmap="YlGn"):
        piv = sig_df.pivot(index="model", columns="k", values=col).reindex(order)
        return piv.style.background_gradient(cmap=cmap, axis=None).format(fmt)

    # value + p-value pairs for the statistical tests
    stat_specs = [
        ("Pesaran-Timmermann hit rate", "pt_hit", "pt_p"),
        ("Henriksson-Merton skill", "hm_skill", "hm_p"),
        ("Diebold-Mariano dbar (vs persistence)", "dm_dbar", "dm_p"),
        ("Clark-West fbar (vs prev-mean)", "cw_fbar", "cw_p"),
    ]
    for title, vcol, pcol in stat_specs:
        print(f"\n=== {title} — value (rows=model, cols=k) ===")
        display(pivot(vcol))
        print("    p-value")
        display(
            sig_df.pivot(index="model", columns="k", values=pcol)
            .reindex(order)
            .style.background_gradient(cmap="Reds_r", axis=None, vmin=0, vmax=0.1)
            .format("{:.4g}")
        )

    # single-table economic / directional metrics
    econ_specs = [
        ("Campbell-Thompson OOS R^2 (%)", "ct_r2_pct"),
        ("IC Pearson", "ic_pearson"),
        ("IC Spearman", "ic_spearman"),
        ("Implied IR @ rho_hat (breadth-deflated)", "ir_rho_hat"),
        ("Edge E[r|up]-E[r|down] (bp)", "edge_bp"),
        ("Jonckheere-Terpstra p (monotone)", "jt_p"),
        ("Break-even hit p*", "be_pstar"),
        ("Realized directional hit rate", "be_hit"),
        ("Frac predictions clearing cost", "frac_clears"),
        ("Brier reliability (lower better)", "reliability"),
        ("Brier resolution (higher better)", "resolution"),
    ]
    for title, col in econ_specs:
        print(f"\n=== {title} (rows=model, cols=k) ===")
        cmap = "Reds_r" if col == "jt_p" else "YlGn"
        fmt = "{:.4g}" if col in ("jt_p",) else "{:.4f}"
        display(pivot(col, fmt=fmt, cmap=cmap))
else:
    print("No results — run the sections above first.")
# Out:
# === Pesaran-Timmermann hit rate — value (rows=model, cols=k) ===
# <style type="text/css">
# #T_7b08d_row0_col0, #T_7b08d_row9_col1 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_7b08d_row0_col1, #T_7b08d_row7_col2 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_7b08d_row0_col2 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_7b08d_row0_col3 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_7b08d_row1_col0 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_7b08d_row1_col1 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_7b08d_row1_col2 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_7b08d_row1_col3 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_7b08d_row2_col0, #T_7b08d_row3_col1 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_7b08d_row2_col1 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_7b08d_row2_col2 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_7b08d_row2_col3 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_7b08d_row3_col0, #T_7b08d_row5_col2 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_7b08d_row3_col2 {
#   background-color: #aedd8e;
#   color: #000000;
# }
# #T_7b08d_row3_col3 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_7b08d_row4_col0 {
#   background-color: #004a2b;
#   color: #f1f1f1;
# }
# #T_7b08d_row4_col1 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_7b08d_row4_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_7b08d_row4_col3 {
#   background-color: #fdfeda;
#   color: #000000;
# }
# #T_7b08d_row5_col0 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_7b08d_row5_col1 {
#   background-color: #b9e294;
#   color: #000000;
# }
# #T_7b08d_row5_col3 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_7b08d_row6_col0 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_7b08d_row6_col1 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_7b08d_row6_col2 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_7b08d_row6_col3 {
#   background-color: #f7fcba;
#   color: #000000;
# }
# #T_7b08d_row7_col0 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_7b08d_row7_col1 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_7b08d_row7_col3 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_7b08d_row8_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_7b08d_row8_col1 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_7b08d_row8_col2 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_7b08d_row8_col3 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_7b08d_row9_col0 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_7b08d_row9_col2 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_7b08d_row9_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_7b08d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_7b08d_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_7b08d_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_7b08d_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_7b08d_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b08d_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_7b08d_row0_col0" class="data row0 col0" >0.5284</td>
#       <td id="T_7b08d_row0_col1" class="data row0 col1" >0.5096</td>
#       <td id="T_7b08d_row0_col2" class="data row0 col2" >0.5013</td>
#       <td id="T_7b08d_row0_col3" class="data row0 col3" >0.5022</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_7b08d_row1_col0" class="data row1 col0" >0.5241</td>
#       <td id="T_7b08d_row1_col1" class="data row1 col1" >0.5203</td>
#       <td id="T_7b08d_row1_col2" class="data row1 col2" >0.5172</td>
#       <td id="T_7b08d_row1_col3" class="data row1 col3" >0.5087</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_7b08d_row2_col0" class="data row2 col0" >0.5170</td>
#       <td id="T_7b08d_row2_col1" class="data row2 col1" >0.5235</td>
#       <td id="T_7b08d_row2_col2" class="data row2 col2" >0.5100</td>
#       <td id="T_7b08d_row2_col3" class="data row2 col3" >0.5094</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_7b08d_row3_col0" class="data row3 col0" >0.5179</td>
#       <td id="T_7b08d_row3_col1" class="data row3 col1" >0.5170</td>
#       <td id="T_7b08d_row3_col2" class="data row3 col2" >0.5175</td>
#       <td id="T_7b08d_row3_col3" class="data row3 col3" >0.5077</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_7b08d_row4_col0" class="data row4 col0" >0.5438</td>
#       <td id="T_7b08d_row4_col1" class="data row4 col1" >0.5273</td>
#       <td id="T_7b08d_row4_col2" class="data row4 col2" >0.5448</td>
#       <td id="T_7b08d_row4_col3" class="data row4 col3" >0.5025</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_7b08d_row5_col0" class="data row5 col0" >0.5245</td>
#       <td id="T_7b08d_row5_col1" class="data row5 col1" >0.5161</td>
#       <td id="T_7b08d_row5_col2" class="data row5 col2" >0.5179</td>
#       <td id="T_7b08d_row5_col3" class="data row5 col3" >0.5124</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_7b08d_row6_col0" class="data row6 col0" >0.5280</td>
#       <td id="T_7b08d_row6_col1" class="data row6 col1" >0.5220</td>
#       <td id="T_7b08d_row6_col2" class="data row6 col2" >0.5092</td>
#       <td id="T_7b08d_row6_col3" class="data row6 col3" >0.5065</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_7b08d_row7_col0" class="data row7 col0" >0.5322</td>
#       <td id="T_7b08d_row7_col1" class="data row7 col1" >0.5205</td>
#       <td id="T_7b08d_row7_col2" class="data row7 col2" >0.5095</td>
#       <td id="T_7b08d_row7_col3" class="data row7 col3" >0.5181</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_7b08d_row8_col0" class="data row8 col0" >0.5286</td>
#       <td id="T_7b08d_row8_col1" class="data row8 col1" >0.5218</td>
#       <td id="T_7b08d_row8_col2" class="data row8 col2" >0.5208</td>
#       <td id="T_7b08d_row8_col3" class="data row8 col3" >0.5117</td>
#     </tr>
#     <tr>
#       <th id="T_7b08d_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_7b08d_row9_col0" class="data row9 col0" >0.5276</td>
#       <td id="T_7b08d_row9_col1" class="data row9 col1" >0.5283</td>
#       <td id="T_7b08d_row9_col2" class="data row9 col2" >0.5047</td>
#       <td id="T_7b08d_row9_col3" class="data row9 col3" >0.5011</td>
#     </tr>
#   </tbody>
# </table>
#     p-value
# <style type="text/css">
# #T_6a751_row0_col0, #T_6a751_row0_col1, #T_6a751_row1_col0, #T_6a751_row1_col1, #T_6a751_row1_col2, #T_6a751_row2_col0, #T_6a751_row2_col1, #T_6a751_row2_col2, #T_6a751_row3_col0, #T_6a751_row3_col1, #T_6a751_row3_col2, #T_6a751_row4_col0, #T_6a751_row4_col1, #T_6a751_row4_col2, #T_6a751_row5_col0, #T_6a751_row5_col1, #T_6a751_row5_col2, #T_6a751_row5_col3, #T_6a751_row6_col0, #T_6a751_row6_col1, #T_6a751_row7_col0, #T_6a751_row7_col1, #T_6a751_row7_col3, #T_6a751_row8_col0, #T_6a751_row8_col1, #T_6a751_row8_col2, #T_6a751_row8_col3, #T_6a751_row9_col0, #T_6a751_row9_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6a751_row0_col2, #T_6a751_row9_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_6a751_row0_col3 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_6a751_row1_col3 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_6a751_row2_col3, #T_6a751_row7_col2 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_6a751_row3_col3 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_6a751_row4_col3 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_6a751_row6_col2 {
#   background-color: #6b010e;
#   color: #f1f1f1;
# }
# #T_6a751_row6_col3 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_6a751_row9_col2 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a751">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_6a751_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_6a751_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_6a751_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_6a751_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a751_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_6a751_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6a751_row0_col1" class="data row0 col1" >0.0001583</td>
#       <td id="T_6a751_row0_col2" class="data row0 col2" >0.2257</td>
#       <td id="T_6a751_row0_col3" class="data row0 col3" >0.0569</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_6a751_row1_col0" class="data row1 col0" >2.22e-16</td>
#       <td id="T_6a751_row1_col1" class="data row1 col1" >2.047e-11</td>
#       <td id="T_6a751_row1_col2" class="data row1 col2" >6.701e-07</td>
#       <td id="T_6a751_row1_col3" class="data row1 col3" >0.05443</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_6a751_row2_col0" class="data row2 col0" >8.873e-13</td>
#       <td id="T_6a751_row2_col1" class="data row2 col1" >1.11e-16</td>
#       <td id="T_6a751_row2_col2" class="data row2 col2" >0.0003903</td>
#       <td id="T_6a751_row2_col3" class="data row2 col3" >0.0006902</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_6a751_row3_col0" class="data row3 col0" >1.134e-12</td>
#       <td id="T_6a751_row3_col1" class="data row3 col1" >8.543e-10</td>
#       <td id="T_6a751_row3_col2" class="data row3 col2" >6.515e-11</td>
#       <td id="T_6a751_row3_col3" class="data row3 col3" >0.002233</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_6a751_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_6a751_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_6a751_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_6a751_row4_col3" class="data row4 col3" >0.0227</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_6a751_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_6a751_row5_col1" class="data row5 col1" >1.589e-09</td>
#       <td id="T_6a751_row5_col2" class="data row5 col2" >2.912e-10</td>
#       <td id="T_6a751_row5_col3" class="data row5 col3" >2.678e-06</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_6a751_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_6a751_row6_col1" class="data row6 col1" >8.882e-15</td>
#       <td id="T_6a751_row6_col2" class="data row6 col2" >0.0008344</td>
#       <td id="T_6a751_row6_col3" class="data row6 col3" >0.009863</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_6a751_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_6a751_row7_col1" class="data row7 col1" >6.017e-13</td>
#       <td id="T_6a751_row7_col2" class="data row7 col2" >0.0005857</td>
#       <td id="T_6a751_row7_col3" class="data row7 col3" >3.788e-11</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_6a751_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_6a751_row8_col1" class="data row8 col1" >1.277e-13</td>
#       <td id="T_6a751_row8_col2" class="data row8 col2" >4.541e-14</td>
#       <td id="T_6a751_row8_col3" class="data row8 col3" >4.126e-06</td>
#     </tr>
#     <tr>
#       <th id="T_6a751_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_6a751_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_6a751_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_6a751_row9_col2" class="data row9 col2" >0.02101</td>
#       <td id="T_6a751_row9_col3" class="data row9 col3" >0.309</td>
#     </tr>
#   </tbody>
# </table>
# === Henriksson-Merton skill — value (rows=model, cols=k) ===
# <style type="text/css">
# #T_2fb9a_row0_col0 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_2fb9a_row0_col1 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_2fb9a_row0_col2 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_2fb9a_row0_col3 {
#   background-color: #fafdcb;
#   color: #000000;
# }
# #T_2fb9a_row1_col0 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_2fb9a_row1_col1 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_2fb9a_row1_col2, #T_2fb9a_row5_col3 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_2fb9a_row1_col3 {
#   background-color: #fafdc9;
#   color: #000000;
# }
# #T_2fb9a_row2_col0 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_2fb9a_row2_col1 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_2fb9a_row2_col2 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_2fb9a_row2_col3 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_2fb9a_row3_col0 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_2fb9a_row3_col1 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_2fb9a_row3_col2 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_2fb9a_row3_col3 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_2fb9a_row4_col0 {
#   background-color: #006034;
#   color: #f1f1f1;
# }
# #T_2fb9a_row4_col1 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_2fb9a_row4_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_2fb9a_row4_col3 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_2fb9a_row5_col0 {
#   background-color: #3da559;
#   color: #f1f1f1;
# }
# #T_2fb9a_row5_col1 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_2fb9a_row5_col2 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_2fb9a_row6_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_2fb9a_row6_col1, #T_2fb9a_row7_col3 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_2fb9a_row6_col2 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_2fb9a_row6_col3 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_2fb9a_row7_col0 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_2fb9a_row7_col1 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_2fb9a_row7_col2 {
#   background-color: #e6f5ac;
#   color: #000000;
# }
# #T_2fb9a_row8_col0 {
#   background-color: #339951;
#   color: #f1f1f1;
# }
# #T_2fb9a_row8_col1 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_2fb9a_row8_col2 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_2fb9a_row8_col3 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_2fb9a_row9_col0 {
#   background-color: #4ab062;
#   color: #f1f1f1;
# }
# #T_2fb9a_row9_col1 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_2fb9a_row9_col2 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_2fb9a_row9_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_2fb9a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_2fb9a_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_2fb9a_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_2fb9a_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_2fb9a_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fb9a_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_2fb9a_row0_col0" class="data row0 col0" >0.0511</td>
#       <td id="T_2fb9a_row0_col1" class="data row0 col1" >0.0201</td>
#       <td id="T_2fb9a_row0_col2" class="data row0 col2" >0.0045</td>
#       <td id="T_2fb9a_row0_col3" class="data row0 col3" >0.0095</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_2fb9a_row1_col0" class="data row1 col0" >0.0401</td>
#       <td id="T_2fb9a_row1_col1" class="data row1 col1" >0.0318</td>
#       <td id="T_2fb9a_row1_col2" class="data row1 col2" >0.0263</td>
#       <td id="T_2fb9a_row1_col3" class="data row1 col3" >0.0097</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_2fb9a_row2_col0" class="data row2 col0" >0.0388</td>
#       <td id="T_2fb9a_row2_col1" class="data row2 col1" >0.0407</td>
#       <td id="T_2fb9a_row2_col2" class="data row2 col2" >0.0181</td>
#       <td id="T_2fb9a_row2_col3" class="data row2 col3" >0.0188</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_2fb9a_row3_col0" class="data row3 col0" >0.0358</td>
#       <td id="T_2fb9a_row3_col1" class="data row3 col1" >0.0278</td>
#       <td id="T_2fb9a_row3_col2" class="data row3 col2" >0.0351</td>
#       <td id="T_2fb9a_row3_col3" class="data row3 col3" >0.0155</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_2fb9a_row4_col0" class="data row4 col0" >0.0721</td>
#       <td id="T_2fb9a_row4_col1" class="data row4 col1" >0.0572</td>
#       <td id="T_2fb9a_row4_col2" class="data row4 col2" >0.0798</td>
#       <td id="T_2fb9a_row4_col3" class="data row4 col3" >0.0119</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_2fb9a_row5_col0" class="data row5 col0" >0.0526</td>
#       <td id="T_2fb9a_row5_col1" class="data row5 col1" >0.0233</td>
#       <td id="T_2fb9a_row5_col2" class="data row5 col2" >0.0348</td>
#       <td id="T_2fb9a_row5_col3" class="data row5 col3" >0.0264</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_2fb9a_row6_col0" class="data row6 col0" >0.0517</td>
#       <td id="T_2fb9a_row6_col1" class="data row6 col1" >0.0375</td>
#       <td id="T_2fb9a_row6_col2" class="data row6 col2" >0.0173</td>
#       <td id="T_2fb9a_row6_col3" class="data row6 col3" >0.0141</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_2fb9a_row7_col0" class="data row7 col0" >0.0581</td>
#       <td id="T_2fb9a_row7_col1" class="data row7 col1" >0.0367</td>
#       <td id="T_2fb9a_row7_col2" class="data row7 col2" >0.0188</td>
#       <td id="T_2fb9a_row7_col3" class="data row7 col3" >0.0374</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_2fb9a_row8_col0" class="data row8 col0" >0.0555</td>
#       <td id="T_2fb9a_row8_col1" class="data row8 col1" >0.0343</td>
#       <td id="T_2fb9a_row8_col2" class="data row8 col2" >0.0419</td>
#       <td id="T_2fb9a_row8_col3" class="data row8 col3" >0.0258</td>
#     </tr>
#     <tr>
#       <th id="T_2fb9a_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_2fb9a_row9_col0" class="data row9 col0" >0.0495</td>
#       <td id="T_2fb9a_row9_col1" class="data row9 col1" >0.0507</td>
#       <td id="T_2fb9a_row9_col2" class="data row9 col2" >0.0113</td>
#       <td id="T_2fb9a_row9_col3" class="data row9 col3" >0.0036</td>
#     </tr>
#   </tbody>
# </table>
#     p-value
# <style type="text/css">
# #T_71c92_row0_col0, #T_71c92_row0_col1, #T_71c92_row0_col2, #T_71c92_row1_col0, #T_71c92_row1_col1, #T_71c92_row2_col0, #T_71c92_row3_col0, #T_71c92_row3_col1, #T_71c92_row4_col0, #T_71c92_row5_col0, #T_71c92_row5_col1, #T_71c92_row6_col0, #T_71c92_row7_col0, #T_71c92_row7_col1, #T_71c92_row8_col0, #T_71c92_row8_col1, #T_71c92_row9_col0, #T_71c92_row9_col2, #T_71c92_row9_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_71c92_row0_col3 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_71c92_row1_col2, #T_71c92_row3_col2, #T_71c92_row4_col2, #T_71c92_row5_col2, #T_71c92_row5_col3, #T_71c92_row7_col3, #T_71c92_row8_col2, #T_71c92_row8_col3, #T_71c92_row9_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_71c92_row1_col3 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_71c92_row2_col1 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_71c92_row2_col2 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_71c92_row2_col3 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_71c92_row3_col3 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_71c92_row4_col1 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_71c92_row4_col3 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_71c92_row6_col1 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_71c92_row6_col2 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_71c92_row6_col3 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_71c92_row7_col2 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_71c92">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_71c92_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_71c92_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_71c92_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_71c92_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71c92_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_71c92_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_71c92_row0_col1" class="data row0 col1" >0.999</td>
#       <td id="T_71c92_row0_col2" class="data row0 col2" >0.6863</td>
#       <td id="T_71c92_row0_col3" class="data row0 col3" >0.09912</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_71c92_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_71c92_row1_col1" class="data row1 col1" >0.2576</td>
#       <td id="T_71c92_row1_col2" class="data row1 col2" >5.09e-05</td>
#       <td id="T_71c92_row1_col3" class="data row1 col3" >0.08343</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_71c92_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_71c92_row2_col1" class="data row2 col1" >0.0284</td>
#       <td id="T_71c92_row2_col2" class="data row2 col2" >0.01321</td>
#       <td id="T_71c92_row2_col3" class="data row2 col3" >0.001654</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_71c92_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_71c92_row3_col1" class="data row3 col1" >0.6621</td>
#       <td id="T_71c92_row3_col2" class="data row3 col2" >8.566e-08</td>
#       <td id="T_71c92_row3_col3" class="data row3 col3" >0.005037</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_71c92_row4_col0" class="data row4 col0" >0.3096</td>
#       <td id="T_71c92_row4_col1" class="data row4 col1" >0.000443</td>
#       <td id="T_71c92_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_71c92_row4_col3" class="data row4 col3" >0.04505</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_71c92_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_71c92_row5_col1" class="data row5 col1" >0.7671</td>
#       <td id="T_71c92_row5_col2" class="data row5 col2" >2.07e-07</td>
#       <td id="T_71c92_row5_col3" class="data row5 col3" >9.296e-06</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_71c92_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_71c92_row6_col1" class="data row6 col1" >0.08529</td>
#       <td id="T_71c92_row6_col2" class="data row6 col2" >0.02317</td>
#       <td id="T_71c92_row6_col3" class="data row6 col3" >0.01951</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_71c92_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_71c92_row7_col1" class="data row7 col1" >0.2065</td>
#       <td id="T_71c92_row7_col2" class="data row7 col2" >0.01802</td>
#       <td id="T_71c92_row7_col3" class="data row7 col3" >2.137e-10</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_71c92_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_71c92_row8_col1" class="data row8 col1" >0.1074</td>
#       <td id="T_71c92_row8_col2" class="data row8 col2" >1.63e-10</td>
#       <td id="T_71c92_row8_col3" class="data row8 col3" >1.431e-05</td>
#     </tr>
#     <tr>
#       <th id="T_71c92_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_71c92_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_71c92_row9_col1" class="data row9 col1" >0.0001022</td>
#       <td id="T_71c92_row9_col2" class="data row9 col2" >0.2145</td>
#       <td id="T_71c92_row9_col3" class="data row9 col3" >0.4102</td>
#     </tr>
#   </tbody>
# </table>
# === Diebold-Mariano dbar (vs persistence) — value (rows=model, cols=k) ===
# <style type="text/css">
# #T_1c8c5_row0_col0, #T_1c8c5_row1_col0, #T_1c8c5_row2_col0, #T_1c8c5_row3_col0, #T_1c8c5_row5_col0, #T_1c8c5_row7_col0, #T_1c8c5_row9_col0 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_1c8c5_row0_col1, #T_1c8c5_row2_col1, #T_1c8c5_row8_col1 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_1c8c5_row0_col2, #T_1c8c5_row1_col2, #T_1c8c5_row9_col2 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_1c8c5_row0_col3 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_1c8c5_row1_col1, #T_1c8c5_row9_col1 {
#   background-color: #f7fcba;
#   color: #000000;
# }
# #T_1c8c5_row1_col3, #T_1c8c5_row6_col3 {
#   background-color: #00472a;
#   color: #f1f1f1;
# }
# #T_1c8c5_row2_col2 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_1c8c5_row2_col3, #T_1c8c5_row8_col3 {
#   background-color: #004e2d;
#   color: #f1f1f1;
# }
# #T_1c8c5_row3_col1, #T_1c8c5_row5_col1 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_1c8c5_row3_col2 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_1c8c5_row3_col3, #T_1c8c5_row4_col3 {
#   background-color: #004f2d;
#   color: #f1f1f1;
# }
# #T_1c8c5_row4_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_1c8c5_row4_col1 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_1c8c5_row4_col2, #T_1c8c5_row8_col2 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_1c8c5_row5_col2 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_1c8c5_row5_col3 {
#   background-color: #004d2c;
#   color: #f1f1f1;
# }
# #T_1c8c5_row6_col0 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_1c8c5_row6_col1 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_1c8c5_row6_col2 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_1c8c5_row7_col1 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_1c8c5_row7_col2 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_1c8c5_row7_col3 {
#   background-color: #00502d;
#   color: #f1f1f1;
# }
# #T_1c8c5_row8_col0 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_1c8c5_row9_col3 {
#   background-color: #00492b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1c8c5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_1c8c5_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_1c8c5_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_1c8c5_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_1c8c5_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c8c5_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_1c8c5_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_1c8c5_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_1c8c5_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_1c8c5_row0_col3" class="data row0 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_1c8c5_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_1c8c5_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_1c8c5_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_1c8c5_row1_col3" class="data row1 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_1c8c5_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_1c8c5_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_1c8c5_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_1c8c5_row2_col3" class="data row2 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_1c8c5_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_1c8c5_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_1c8c5_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_1c8c5_row3_col3" class="data row3 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_1c8c5_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_1c8c5_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_1c8c5_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_1c8c5_row4_col3" class="data row4 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_1c8c5_row5_col0" class="data row5 col0" >0.0000</td>
#       <td id="T_1c8c5_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_1c8c5_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_1c8c5_row5_col3" class="data row5 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_1c8c5_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_1c8c5_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_1c8c5_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_1c8c5_row6_col3" class="data row6 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_1c8c5_row7_col0" class="data row7 col0" >0.0000</td>
#       <td id="T_1c8c5_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_1c8c5_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_1c8c5_row7_col3" class="data row7 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_1c8c5_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_1c8c5_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_1c8c5_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_1c8c5_row8_col3" class="data row8 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1c8c5_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_1c8c5_row9_col0" class="data row9 col0" >0.0000</td>
#       <td id="T_1c8c5_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_1c8c5_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_1c8c5_row9_col3" class="data row9 col3" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#     p-value
# <style type="text/css">
# #T_e5aa8_row0_col0, #T_e5aa8_row0_col1, #T_e5aa8_row0_col2, #T_e5aa8_row0_col3, #T_e5aa8_row1_col0, #T_e5aa8_row1_col1, #T_e5aa8_row1_col2, #T_e5aa8_row1_col3, #T_e5aa8_row2_col0, #T_e5aa8_row2_col1, #T_e5aa8_row2_col2, #T_e5aa8_row2_col3, #T_e5aa8_row3_col0, #T_e5aa8_row3_col1, #T_e5aa8_row3_col2, #T_e5aa8_row3_col3, #T_e5aa8_row4_col0, #T_e5aa8_row4_col1, #T_e5aa8_row4_col2, #T_e5aa8_row4_col3, #T_e5aa8_row5_col0, #T_e5aa8_row5_col1, #T_e5aa8_row5_col2, #T_e5aa8_row5_col3, #T_e5aa8_row6_col0, #T_e5aa8_row6_col1, #T_e5aa8_row6_col2, #T_e5aa8_row6_col3, #T_e5aa8_row7_col0, #T_e5aa8_row7_col1, #T_e5aa8_row7_col2, #T_e5aa8_row7_col3, #T_e5aa8_row8_col0, #T_e5aa8_row8_col1, #T_e5aa8_row8_col2, #T_e5aa8_row8_col3, #T_e5aa8_row9_col0, #T_e5aa8_row9_col1, #T_e5aa8_row9_col2, #T_e5aa8_row9_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e5aa8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_e5aa8_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_e5aa8_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_e5aa8_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_e5aa8_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5aa8_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_e5aa8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_e5aa8_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_e5aa8_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_e5aa8_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_e5aa8_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_e5aa8_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_e5aa8_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_e5aa8_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_e5aa8_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_e5aa8_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_e5aa8_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_e5aa8_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_e5aa8_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_e5aa8_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_e5aa8_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_e5aa8_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_e5aa8_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_e5aa8_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_e5aa8_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_e5aa8_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_e5aa8_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_e5aa8_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_e5aa8_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_e5aa8_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_e5aa8_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_e5aa8_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_e5aa8_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_e5aa8_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_e5aa8_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_e5aa8_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_e5aa8_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_e5aa8_row7_col3" class="data row7 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_e5aa8_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_e5aa8_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_e5aa8_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_e5aa8_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5aa8_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_e5aa8_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_e5aa8_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_e5aa8_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_e5aa8_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#   </tbody>
# </table>
# === Clark-West fbar (vs prev-mean) — value (rows=model, cols=k) ===
# <style type="text/css">
# #T_c7114_row0_col0 {
#   background-color: #f8fdc1;
#   color: #000000;
# }
# #T_c7114_row0_col1, #T_c7114_row2_col0 {
#   background-color: #f7fcbc;
#   color: #000000;
# }
# #T_c7114_row0_col2 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_c7114_row0_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_c7114_row1_col0, #T_c7114_row7_col1 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_c7114_row1_col1 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_c7114_row1_col2 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_c7114_row1_col3 {
#   background-color: #e2f4aa;
#   color: #000000;
# }
# #T_c7114_row2_col1, #T_c7114_row3_col0, #T_c7114_row8_col1, #T_c7114_row9_col3 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_c7114_row2_col2 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_c7114_row2_col3 {
#   background-color: #d0ec9f;
#   color: #000000;
# }
# #T_c7114_row3_col1 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_c7114_row3_col2 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_c7114_row3_col3 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_c7114_row4_col0 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_c7114_row4_col1 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_c7114_row4_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_c7114_row4_col3 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_c7114_row5_col0, #T_c7114_row8_col0 {
#   background-color: #f7fcba;
#   color: #000000;
# }
# #T_c7114_row5_col1 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_c7114_row5_col2 {
#   background-color: #4fb264;
#   color: #f1f1f1;
# }
# #T_c7114_row5_col3 {
#   background-color: #cfec9e;
#   color: #000000;
# }
# #T_c7114_row6_col0 {
#   background-color: #fbfed0;
#   color: #000000;
# }
# #T_c7114_row6_col1 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_c7114_row6_col2, #T_c7114_row8_col3 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_c7114_row6_col3 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_c7114_row7_col0, #T_c7114_row9_col0 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_c7114_row7_col2 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_c7114_row7_col3 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_c7114_row8_col2 {
#   background-color: #2d914b;
#   color: #f1f1f1;
# }
# #T_c7114_row9_col1 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_c7114_row9_col2 {
#   background-color: #8bce81;
#   color: #000000;
# }
# </style>
# <table id="T_c7114">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_c7114_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_c7114_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_c7114_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_c7114_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7114_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_c7114_row0_col0" class="data row0 col0" >-0.0000</td>
#       <td id="T_c7114_row0_col1" class="data row0 col1" >-0.0000</td>
#       <td id="T_c7114_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_c7114_row0_col3" class="data row0 col3" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_c7114_row1_col0" class="data row1 col0" >-0.0000</td>
#       <td id="T_c7114_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_c7114_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_c7114_row1_col3" class="data row1 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_c7114_row2_col0" class="data row2 col0" >-0.0000</td>
#       <td id="T_c7114_row2_col1" class="data row2 col1" >-0.0000</td>
#       <td id="T_c7114_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_c7114_row2_col3" class="data row2 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_c7114_row3_col0" class="data row3 col0" >-0.0000</td>
#       <td id="T_c7114_row3_col1" class="data row3 col1" >-0.0000</td>
#       <td id="T_c7114_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_c7114_row3_col3" class="data row3 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_c7114_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_c7114_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_c7114_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_c7114_row4_col3" class="data row4 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_c7114_row5_col0" class="data row5 col0" >-0.0000</td>
#       <td id="T_c7114_row5_col1" class="data row5 col1" >-0.0000</td>
#       <td id="T_c7114_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_c7114_row5_col3" class="data row5 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_c7114_row6_col0" class="data row6 col0" >-0.0000</td>
#       <td id="T_c7114_row6_col1" class="data row6 col1" >-0.0000</td>
#       <td id="T_c7114_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_c7114_row6_col3" class="data row6 col3" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_c7114_row7_col0" class="data row7 col0" >-0.0000</td>
#       <td id="T_c7114_row7_col1" class="data row7 col1" >-0.0000</td>
#       <td id="T_c7114_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_c7114_row7_col3" class="data row7 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_c7114_row8_col0" class="data row8 col0" >-0.0000</td>
#       <td id="T_c7114_row8_col1" class="data row8 col1" >-0.0000</td>
#       <td id="T_c7114_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_c7114_row8_col3" class="data row8 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c7114_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_c7114_row9_col0" class="data row9 col0" >-0.0000</td>
#       <td id="T_c7114_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_c7114_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_c7114_row9_col3" class="data row9 col3" >-0.0000</td>
#     </tr>
#   </tbody>
# </table>
#     p-value
# <style type="text/css">
# #T_ab87a_row0_col0, #T_ab87a_row0_col1, #T_ab87a_row0_col2, #T_ab87a_row0_col3, #T_ab87a_row1_col0, #T_ab87a_row1_col1, #T_ab87a_row1_col3, #T_ab87a_row2_col0, #T_ab87a_row2_col1, #T_ab87a_row2_col2, #T_ab87a_row2_col3, #T_ab87a_row3_col0, #T_ab87a_row3_col1, #T_ab87a_row3_col3, #T_ab87a_row4_col0, #T_ab87a_row4_col3, #T_ab87a_row5_col0, #T_ab87a_row5_col1, #T_ab87a_row5_col3, #T_ab87a_row6_col0, #T_ab87a_row6_col1, #T_ab87a_row6_col2, #T_ab87a_row6_col3, #T_ab87a_row7_col0, #T_ab87a_row7_col1, #T_ab87a_row7_col3, #T_ab87a_row8_col0, #T_ab87a_row8_col1, #T_ab87a_row8_col3, #T_ab87a_row9_col0, #T_ab87a_row9_col1, #T_ab87a_row9_col2, #T_ab87a_row9_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ab87a_row1_col2 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_ab87a_row3_col2 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_ab87a_row4_col1 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_ab87a_row4_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ab87a_row5_col2 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_ab87a_row7_col2 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_ab87a_row8_col2 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab87a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_ab87a_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_ab87a_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_ab87a_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_ab87a_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab87a_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_ab87a_row0_col0" class="data row0 col0" >0.9997</td>
#       <td id="T_ab87a_row0_col1" class="data row0 col1" >0.8767</td>
#       <td id="T_ab87a_row0_col2" class="data row0 col2" >0.1427</td>
#       <td id="T_ab87a_row0_col3" class="data row0 col3" >0.6479</td>
#     </tr>
#     <tr>
#       <th id="T_ab87a_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_ab87a_row1_col0" class="data row1 col0" >0.9999</td>
#       <td id="T_ab87a_row1_col1" class="data row1 col1" >0.3179</td>
#       <td id="T_ab87a_row1_col2" class="data row1 col2" >0.03711</td>
#       <td id="T_ab87a_row1_col3" class="data row1 col3" >0.4879</td>
#     </tr>
#     <tr>
#       <th id="T_ab87a_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
# ...
#       <td id="T_a664f_row5_col3" class="data row5 col3" >0.7686</td>
#     </tr>
#     <tr>
#       <th id="T_a664f_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_a664f_row6_col0" class="data row6 col0" >0.3685</td>
#       <td id="T_a664f_row6_col1" class="data row6 col1" >0.5140</td>
#       <td id="T_a664f_row6_col2" class="data row6 col2" >0.6937</td>
#       <td id="T_a664f_row6_col3" class="data row6 col3" >0.7822</td>
#     </tr>
#     <tr>
#       <th id="T_a664f_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_a664f_row7_col0" class="data row7 col0" >0.3729</td>
#       <td id="T_a664f_row7_col1" class="data row7 col1" >0.5178</td>
#       <td id="T_a664f_row7_col2" class="data row7 col2" >0.6917</td>
#       <td id="T_a664f_row7_col3" class="data row7 col3" >0.7824</td>
#     </tr>
#     <tr>
#       <th id="T_a664f_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_a664f_row8_col0" class="data row8 col0" >0.4191</td>
#       <td id="T_a664f_row8_col1" class="data row8 col1" >0.5074</td>
#       <td id="T_a664f_row8_col2" class="data row8 col2" >0.7203</td>
#       <td id="T_a664f_row8_col3" class="data row8 col3" >0.7839</td>
#     </tr>
#     <tr>
#       <th id="T_a664f_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_a664f_row9_col0" class="data row9 col0" >0.4217</td>
#       <td id="T_a664f_row9_col1" class="data row9 col1" >0.5568</td>
#       <td id="T_a664f_row9_col2" class="data row9 col2" >0.6755</td>
#       <td id="T_a664f_row9_col3" class="data row9 col3" >0.8091</td>
#     </tr>
#   </tbody>
# </table>
# === Brier reliability (lower better) (rows=model, cols=k) ===
# <style type="text/css">
# #T_61446_row0_col0 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_61446_row0_col1, #T_61446_row7_col0 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_61446_row0_col2, #T_61446_row6_col2 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_61446_row0_col3 {
#   background-color: #248644;
#   color: #f1f1f1;
# }
# #T_61446_row1_col0, #T_61446_row8_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_61446_row1_col1 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_61446_row1_col2 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_61446_row1_col3 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_61446_row2_col0 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_61446_row2_col1 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_61446_row2_col2 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_61446_row2_col3 {
#   background-color: #84cb7e;
#   color: #000000;
# }
# #T_61446_row3_col0 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_61446_row3_col1 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_61446_row3_col2 {
#   background-color: #aedd8e;
#   color: #000000;
# }
# #T_61446_row3_col3 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_61446_row4_col0 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_61446_row4_col1 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_61446_row4_col2 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_61446_row4_col3 {
#   background-color: #005830;
#   color: #f1f1f1;
# }
# #T_61446_row5_col0 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_61446_row5_col1 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_61446_row5_col2 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_61446_row5_col3, #T_61446_row7_col1, #T_61446_row9_col2 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_61446_row6_col0 {
#   background-color: #ceeb9e;
#   color: #000000;
# }
# #T_61446_row6_col1 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_61446_row6_col3 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_61446_row7_col2 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_61446_row7_col3 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_61446_row8_col0 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_61446_row8_col2 {
#   background-color: #61bb6d;
#   color: #f1f1f1;
# }
# #T_61446_row8_col3, #T_61446_row9_col3 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_61446_row9_col0 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_61446_row9_col1 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# </style>
# <table id="T_61446">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_61446_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_61446_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_61446_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_61446_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61446_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_61446_row0_col0" class="data row0 col0" >0.0014</td>
#       <td id="T_61446_row0_col1" class="data row0 col1" >0.0037</td>
#       <td id="T_61446_row0_col2" class="data row0 col2" >0.0068</td>
#       <td id="T_61446_row0_col3" class="data row0 col3" >0.0107</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_61446_row1_col0" class="data row1 col0" >0.0007</td>
#       <td id="T_61446_row1_col1" class="data row1 col1" >0.0013</td>
#       <td id="T_61446_row1_col2" class="data row1 col2" >0.0009</td>
#       <td id="T_61446_row1_col3" class="data row1 col3" >0.0012</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_61446_row2_col0" class="data row2 col0" >0.0042</td>
#       <td id="T_61446_row2_col1" class="data row2 col1" >0.0034</td>
#       <td id="T_61446_row2_col2" class="data row2 col2" >0.0071</td>
#       <td id="T_61446_row2_col3" class="data row2 col3" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_61446_row3_col0" class="data row3 col0" >0.0038</td>
#       <td id="T_61446_row3_col1" class="data row3 col1" >0.0030</td>
#       <td id="T_61446_row3_col2" class="data row3 col2" >0.0057</td>
#       <td id="T_61446_row3_col3" class="data row3 col3" >0.0058</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_61446_row4_col0" class="data row4 col0" >0.0015</td>
#       <td id="T_61446_row4_col1" class="data row4 col1" >0.0030</td>
#       <td id="T_61446_row4_col2" class="data row4 col2" >0.0018</td>
#       <td id="T_61446_row4_col3" class="data row4 col3" >0.0132</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_61446_row5_col0" class="data row5 col0" >0.0032</td>
#       <td id="T_61446_row5_col1" class="data row5 col1" >0.0069</td>
#       <td id="T_61446_row5_col2" class="data row5 col2" >0.0045</td>
#       <td id="T_61446_row5_col3" class="data row5 col3" >0.0043</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_61446_row6_col0" class="data row6 col0" >0.0045</td>
#       <td id="T_61446_row6_col1" class="data row6 col1" >0.0050</td>
#       <td id="T_61446_row6_col2" class="data row6 col2" >0.0068</td>
#       <td id="T_61446_row6_col3" class="data row6 col3" >0.0071</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_61446_row7_col0" class="data row7 col0" >0.0037</td>
#       <td id="T_61446_row7_col1" class="data row7 col1" >0.0043</td>
#       <td id="T_61446_row7_col2" class="data row7 col2" >0.0066</td>
#       <td id="T_61446_row7_col3" class="data row7 col3" >0.0073</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_61446_row8_col0" class="data row8 col0" >0.0027</td>
#       <td id="T_61446_row8_col1" class="data row8 col1" >0.0007</td>
#       <td id="T_61446_row8_col2" class="data row8 col2" >0.0081</td>
#       <td id="T_61446_row8_col3" class="data row8 col3" >0.0141</td>
#     </tr>
#     <tr>
#       <th id="T_61446_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_61446_row9_col0" class="data row9 col0" >0.0024</td>
#       <td id="T_61446_row9_col1" class="data row9 col1" >0.0067</td>
#       <td id="T_61446_row9_col2" class="data row9 col2" >0.0043</td>
#       <td id="T_61446_row9_col3" class="data row9 col3" >0.0141</td>
#     </tr>
#   </tbody>
# </table>
# === Brier resolution (higher better) (rows=model, cols=k) ===
# <style type="text/css">
# #T_048ee_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_048ee_row0_col1 {
#   background-color: #298c48;
#   color: #f1f1f1;
# }
# #T_048ee_row0_col2, #T_048ee_row1_col1 {
#   background-color: #56b568;
#   color: #f1f1f1;
# }
# #T_048ee_row0_col3 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_048ee_row1_col0 {
#   background-color: #036b38;
#   color: #f1f1f1;
# }
# #T_048ee_row1_col2 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_048ee_row1_col3 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_048ee_row2_col0 {
#   background-color: #00502d;
#   color: #f1f1f1;
# }
# #T_048ee_row2_col1 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_048ee_row2_col2 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_048ee_row2_col3, #T_048ee_row3_col2 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_048ee_row3_col0 {
#   background-color: #11753d;
#   color: #f1f1f1;
# }
# #T_048ee_row3_col1 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_048ee_row3_col3 {
#   background-color: #fafdcb;
#   color: #000000;
# }
# #T_048ee_row4_col0 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_048ee_row4_col1 {
#   background-color: #fafdc9;
#   color: #000000;
# }
# #T_048ee_row4_col2 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_048ee_row4_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_048ee_row5_col0 {
#   background-color: #00542f;
#   color: #f1f1f1;
# }
# #T_048ee_row5_col1 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_048ee_row5_col2 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_048ee_row5_col3 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_048ee_row6_col0 {
#   background-color: #0e743c;
#   color: #f1f1f1;
# }
# #T_048ee_row6_col1, #T_048ee_row8_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_048ee_row6_col2 {
#   background-color: #62bb6e;
#   color: #f1f1f1;
# }
# #T_048ee_row6_col3 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_048ee_row7_col0 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_048ee_row7_col1 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_048ee_row7_col2 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_048ee_row7_col3 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_048ee_row8_col0 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_048ee_row8_col2 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_048ee_row8_col3 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_048ee_row9_col0 {
#   background-color: #005530;
#   color: #f1f1f1;
# }
# #T_048ee_row9_col1 {
#   background-color: #339951;
#   color: #f1f1f1;
# }
# #T_048ee_row9_col2 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_048ee_row9_col3 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# </style>
# <table id="T_048ee">
#   <thead>
#     <tr>
#       <th class="index_name level0" >k</th>
#       <th id="T_048ee_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_048ee_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_048ee_level0_col2" class="col_heading level0 col2" >50</th>
#       <th id="T_048ee_level0_col3" class="col_heading level0 col3" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_048ee_level0_row0" class="row_heading level0 row0" >dla + ofi</th>
#       <td id="T_048ee_row0_col0" class="data row0 col0" >0.0793</td>
#       <td id="T_048ee_row0_col1" class="data row0 col1" >0.0678</td>
#       <td id="T_048ee_row0_col2" class="data row0 col2" >0.0617</td>
#       <td id="T_048ee_row0_col3" class="data row0 col3" >0.0516</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row1" class="row_heading level0 row1" >tlob + ofi</th>
#       <td id="T_048ee_row1_col0" class="data row1 col0" >0.0735</td>
#       <td id="T_048ee_row1_col1" class="data row1 col1" >0.0617</td>
#       <td id="T_048ee_row1_col2" class="data row1 col2" >0.0552</td>
#       <td id="T_048ee_row1_col3" class="data row1 col3" >0.0479</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row2" class="row_heading level0 row2" >ctabl + ofi</th>
#       <td id="T_048ee_row2_col0" class="data row2 col0" >0.0775</td>
#       <td id="T_048ee_row2_col1" class="data row2 col1" >0.0652</td>
#       <td id="T_048ee_row2_col2" class="data row2 col2" >0.0610</td>
#       <td id="T_048ee_row2_col3" class="data row2 col3" >0.0508</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row3" class="row_heading level0 row3" >binctabl + ofi</th>
#       <td id="T_048ee_row3_col0" class="data row3 col0" >0.0716</td>
#       <td id="T_048ee_row3_col1" class="data row3 col1" >0.0590</td>
#       <td id="T_048ee_row3_col2" class="data row3 col2" >0.0508</td>
#       <td id="T_048ee_row3_col3" class="data row3 col3" >0.0409</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row4" class="row_heading level0 row4" >deeplob + ofi</th>
#       <td id="T_048ee_row4_col0" class="data row4 col0" >0.0558</td>
#       <td id="T_048ee_row4_col1" class="data row4 col1" >0.0411</td>
#       <td id="T_048ee_row4_col2" class="data row4 col2" >0.0388</td>
#       <td id="T_048ee_row4_col3" class="data row4 col3" >0.0378</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row5" class="row_heading level0 row5" >alphastablelob_1.5 + ofi</th>
#       <td id="T_048ee_row5_col0" class="data row5 col0" >0.0769</td>
#       <td id="T_048ee_row5_col1" class="data row5 col1" >0.0640</td>
#       <td id="T_048ee_row5_col2" class="data row5 col2" >0.0591</td>
#       <td id="T_048ee_row5_col3" class="data row5 col3" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row6" class="row_heading level0 row6" >linvar + ofi</th>
#       <td id="T_048ee_row6_col0" class="data row6 col0" >0.0719</td>
#       <td id="T_048ee_row6_col1" class="data row6 col1" >0.0632</td>
#       <td id="T_048ee_row6_col2" class="data row6 col2" >0.0606</td>
#       <td id="T_048ee_row6_col3" class="data row6 col3" >0.0530</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row7" class="row_heading level0 row7" >logreg + ofi</th>
#       <td id="T_048ee_row7_col0" class="data row7 col0" >0.0700</td>
#       <td id="T_048ee_row7_col1" class="data row7 col1" >0.0625</td>
#       <td id="T_048ee_row7_col2" class="data row7 col2" >0.0604</td>
#       <td id="T_048ee_row7_col3" class="data row7 col3" >0.0505</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row8" class="row_heading level0 row8" >jumpgatelob + ofi</th>
#       <td id="T_048ee_row8_col0" class="data row8 col0" >0.0745</td>
#       <td id="T_048ee_row8_col1" class="data row8 col1" >0.0633</td>
#       <td id="T_048ee_row8_col2" class="data row8 col2" >0.0561</td>
#       <td id="T_048ee_row8_col3" class="data row8 col3" >0.0482</td>
#     </tr>
#     <tr>
#       <th id="T_048ee_level0_row9" class="row_heading level0 row9" >ofsatnet + ofi</th>
#       <td id="T_048ee_row9_col0" class="data row9 col0" >0.0767</td>
#       <td id="T_048ee_row9_col1" class="data row9 col1" >0.0660</td>
#       <td id="T_048ee_row9_col2" class="data row9 col2" >0.0569</td>
#       <td id="T_048ee_row9_col3" class="data row9 col3" >0.0485</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 9.5 What a pass looks like — per metric
#
# Each line states the pass condition and the claim it licenses.
#
# - **Pesaran–Timmermann** — *pass:* `p < 0.05` and hit > benchmark. *Claim:* the
#   predicted direction and the realized sign are dependent — genuine directional
#   information, not the marginal class mix.
# - **Henriksson–Merton** — *pass:* skill `> 0` with `p < 0.05`. *Claim:* the model
#   times **both** sides (its up-hit and down-hit rates jointly beat coin-flipping),
#   not just one lucky regime.
# - **Diebold–Mariano** — *pass:* `dbar < 0` with `p < 0.05`. *Claim:* the model's
#   squared forecast error is reliably below the persistence baseline's — lower loss
#   than a non-nested competitor, beyond sampling noise.
# - **Clark–West** — *pass:* `fbar > 0` with one-sided `p < 0.05`. *Claim:* the
#   model beats the nested prevailing-mean forecast out-of-sample *after* removing
#   the estimation-noise advantage — the extra structure earns its keep, not
#   overfitting.
# - **Campbell–Thompson OOS $R^2$** — *pass:* `> 0` (even ~0.1–1%). *Claim:* the
#   model adds predictive information over the running mean; magnitude is expected
#   to be tiny at LOB frequency — economic size is judged below, not here.
# - **Information coefficient** — *pass:* CI excludes 0. *Claim:* score and forward
#   return are monotonically related (Spearman) / linearly related (Pearson) beyond
#   autocorrelation-inflated noise.
# - **Fundamental Law (IR)** — *pass:* deflated IR stays economically meaningful
#   (rule-of-thumb `> 0.5`) at the *estimated* `rho_hat`, not just at `rho=0`.
#   *Claim:* after honestly discounting breadth for signal persistence, the implied
#   information ratio is still worth harvesting.
# - **Conditional separation / Jonckheere–Terpstra** — *pass:* edge CI excludes 0
#   **and** JT `p < 0.05`. *Claim:* mean forward return increases monotonically
#   down→flat→up — the classes sort future returns in the right order.
# - **Break-even cost** — *pass:* realized hit `> p*` and a non-trivial fraction of
#   calls clear the cost hurdle. *Claim:* the edge survives the round-trip cost —
#   the signal is tradeable, not just correlated.
# - **Calibration (Brier / Murphy)** — *pass:* low reliability, positive resolution,
#   reliability curve near the diagonal. *Claim:* `p_up` can be trusted for position
#   **sizing**, not only for its argmax label.
